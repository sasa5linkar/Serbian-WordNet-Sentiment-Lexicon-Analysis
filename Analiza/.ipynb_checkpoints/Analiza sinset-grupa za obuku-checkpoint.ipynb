# %%
import sys
sys.path.append('../')
from srpskiwordnet import SrbWordNetReader
from srppolsets import PolaritySets, syn2gloss

# %%
RES_DIR = "..\\resources\\"
MOD_DIR = "..\\ml_models\\"
swordnet = SrbWordNetReader("F:\Serbian Corpora\wnsrp30","wnsrp30.xml")
# Out:
# Synset ENG30-07010821-n lacks literals 24612

# %%
swordnet.load_lexicon(RES_DIR + "lexiconPOSlat")

# %%
Synset_Sentiment_set_1 = PolaritySets(swordnet, 0)

# %%
Synset_Sentiment_set_1.addWNopAll()

# %%
defi = Synset_Sentiment_set_1.getDef()
defi
# Out:
# {'POS': [{'ID': 'ENG30-14538472-n',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'sigurnost',
#    'Definicija': 'Stanje u kome je neko siguran da neki uzrok neće izazvati štetne efekte pod definisanim uslovima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00474017-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'ugladiti,rafinirati',
#    'Definicija': 'Poboljšati glačanjem ili kresanjem.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07528470-n',
#    'POS': 0.25,
#    'NEG': 0.25,
#    'Lemme': 'nalet,juriš,naboj,uzbuđenje,ushićenje,stimulacija',
#    'Definicija': 'brzo oslobađanje zalihe uticajne sile',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04814238-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'veličanstvenost,briljantnost',
#    'Definicija': 'Osobina nekoga ko je veličanstven, briljantan',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01123148-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'častan,dobar,pouzdan',
#    'Definicija': 'imati poželjne ili pozitivne kvalitete, posebno one koji su pogodni za određenu stvar',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01375831-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slavan,poznat,čuven,značajan,renomiran,priznat,proslavljen',
#    'Definicija': 'opšte prihvaćen i uvažen',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01816431-v',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'usrećiti',
#    'Definicija': 'usrećiti ili zadovoljiti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02397637-v',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'unaprediti,promovisati,promaknuti',
#    'Definicija': 'Dodeliti viši položaj.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14474052-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'prosperitet,uspešnost',
#    'Definicija': 'Stanje kada je neko prosperitetan i uspešan.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00925490-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'čuditi se,oduševiti se',
#    'Definicija': 'diviti se i čuditi nečemu',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00228645-a',
#    'POS': 0.5,
#    'NEG': 0.0,
#    'Lemme': 'optimalan',
#    'Definicija': 'koji je najpoželjniji pod datim uslovima ili ograničenjima',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04849241-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'dobrota',
#    'Definicija': 'Moralna izvanrednost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00473799-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'obnoviti,doterati,uglancati,uljuditi',
#    'Definicija': 'Ostalo je još samo da se doteraju neke finese u igri plavih.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07289588-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'čudo',
#    'Definicija': 'nešto što izaziva osećanje čuđenja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00518395-v',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'olakšati,potpomoći',
#    'Definicija': 'Učiniti lakšim.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01129977-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'častan,dobar,primeran,ugledan',
#    'Definicija': 'moralno primeran',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00362467-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'uveseljavajući',
#    'Definicija': 'koji je pun pozitivne energije i širi dobro raspoloženje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14491625-n',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'izobilje',
#    'Definicija': 'Veliko bogatstvo.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02036934-a',
#    'POS': 0.00075,
#    'NEG': 0.0,
#    'Lemme': 'dobar,moralan,pravedan',
#    'Definicija': 'onaj koji poseduje moralne kvalitete;',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01817938-v',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'bodriti,osokoliti,obodriti,ohrabriti',
#    'Definicija': 'dati ohrabrenje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01821423-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'zainteresovati,zaintrigirati',
#    'Definicija': 'pobuditi nečiju radoznalost; podstaći nečije interesovanje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00064095-v',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'olakšati,ublažiti,utažiti',
#    'Definicija': 'Omogućiti olakšanje od fizičkog bola.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07357388-n',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'napredak,progres,unapređenje',
#    'Definicija': 'Promena nabolje, napredak u razvoju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00093483-n',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'spas,izbavljenje',
#    'Definicija': 'Oporavak ili način čuvanja od gubitka ili opasnosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01676517-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'fantastičan,veličanstven,izvanredan,sjajan,izvrstan,izuzetan,predivan,čdesan',
#    'Definicija': 'izuzetno dobar; ove reči se koriste za naglašavanje značenja drugih reči',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14546844-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ispravnost,korektnost',
#    'Definicija': 'stanje bez oštećenja ili propadanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07509996-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'čuđenje,zaćuđenost',
#    'Definicija': 'osećanje izazvano nečim čudnim i iznenađujućim',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07491981-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'polet,oduševljenje,slast',
#    'Definicija': 'energično i oduševljeno uživanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00248659-v',
#    'POS': 0.5,
#    'NEG': 0.0,
#    'Lemme': 'napredovati,ići',
#    'Definicija': 'razvijati se u pozitivnom smeru',
#    'Vrsta': 'v'}],
#  'NEG': [{'ID': 'ENG30-01230387-a',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'beznadežan',
#    'Definicija': 'koji je označen beznadežnošću ili ispoljava beznadežnost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00364881-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'deprimirajući,tmuran,sumoran',
#    'Definicija': 'koji izaziva potištenost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00796976-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odbaciti,odbacivati,odbijati,odbiti,prezirati,prezreti',
#    'Definicija': 'odbiti s gnušanjem',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00402539-v',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'komplikovati,zamrsiti',
#    'Definicija': 'Učiniti složenijim.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01770501-v',
#    'POS': 0.25,
#    'NEG': 0.375,
#    'Lemme': 'uznemiriti,uzrujati',
#    'Definicija': 'Duboko dirnuti.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01792567-v',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'nauditi,naškoditi',
#    'Definicija': 'uzrokovati bol, unesrećiti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07532440-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'tuga,žalost',
#    'Definicija': 'Osećanja koja se javljaju kada osoba nije u srećnom stanju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02466111-a',
#    'POS': 0.0,
#    'NEG': 0.00075,
#    'Lemme': 'nepouzdan',
#    'Definicija': 'onaj kojem se ne može ukazati poverenje, u koga se ne možemo pouzdati',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01619929-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uništavati,uništiti,upropaštavati,upropastiti',
#    'Definicija': 'ukinuti, čega uništenje ili opoziv uzrokovati',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04709253-n',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'teškoća',
#    'Definicija': 'Osobina onoga što je teško.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14408086-n',
#    'POS': 0.0,
#    'NEG': 0.25,
#    'Lemme': 'teškoća,neprilika',
#    'Definicija': 'Stanje stvari koje je skoro izvan nečije mogućnosti da je reši i zahteva veliki napor da se reši ili prevaziđe.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07533877-n',
#    'POS': 0.0,
#    'NEG': 0.5,
#    'Lemme': 'patnja,paćeništvo',
#    'Definicija': 'intenzivna ojađenost',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09369169-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gnezdo',
#    'Definicija': 'Struktura u kojoj životinje ležu jaja i legu svoje mlade.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00220956-a',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'ružan',
#    'Definicija': 'Koji je moralno odbojan ili neugodan za čula.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02463582-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ciničan,mizantropski,mizantropičan',
#    'Definicija': 'koji misli najgore o ljudskoj prirodi i motivima; koji ima podrugljivu nevericu u, npr. u nesebičnost drugih',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00223983-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanica,klanje,krvoproliće,masakr,pokolj',
#    'Definicija': 'divljačko i prekomerno ubijanje mnogih ljudi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04834605-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sebičnost',
#    'Definicija': 'škrtost koja proizilazi iz brige za sopstvenu dobrobit i nepoštovanje drugih',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00220522-n',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'ubistvo',
#    'Definicija': 'Nezakonito ubijanje s predumišljajem jednog čoveka od strane drugog.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00735936-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nepristojnost',
#    'Definicija': 'nedolično ili nemoralno ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07427060-n',
#    'POS': 0.0,
#    'NEG': 0.5,
#    'Lemme': 'atrofiranje',
#    'Definicija': 'Slabljenje ili degeneracije, posebno usled nekorišćenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13990675-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'krivica',
#    'Definicija': 'Stanje kada je učinjen prekršaj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01327301-v',
#    'POS': 0.0,
#    'NEG': 0.5,
#    'Lemme': 'likvidirati,ucmekati,skembati',
#    'Definicija': 'Otarasiti se nekoga ubistvom.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14365741-n',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'atrofija',
#    'Definicija': 'smanjenje u veličini organa usled bolesti ili nekorišćenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00838043-v',
#    'POS': 0.0,
#    'NEG': 0.25,
#    'Lemme': 'praviti se,činiti se,izmotavati se',
#    'Definicija': 'Simulirati.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00736786-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'impulsivnost,raspojasanost,razuzdanost',
#    'Definicija': 'bučno i neobuzdano ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00193480-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'užasavajući',
#    'Definicija': 'koji izaziva osećanje užasa',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14213199-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'muka,fizička patnja',
#    'Definicija': 'stanje bola ili patnje zbog lošeg zdravlja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07536245-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'krivica,osećanje krivice',
#    'Definicija': 'griža savesti kada se neko oseća krivim za prekršaj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02482425-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ubiti,ukloniti s ovog sveta',
#    'Definicija': 'Usmrtiti namerno i sa predumišljajem.',
#    'Vrsta': 'v'}],
#  'OBJ': [{'ID': 'ENG30-02117955-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'uhvatiti',
#    'Definicija': 'Osetiti čulima brzo, iznenada ili trenutno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02982599-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'reza,rajber',
#    'Definicija': 'pričvrščivaač za zatvaranje vrata ili prozora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07323922-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'postanje,postanak,prapočetak',
#    'Definicija': 'Događaj koji predstavlja početak; prvi deo ili stadijum potonjih događaja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01993926-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'primaknuti,prineti,približiti',
#    'Definicija': 'Učiniti da nešto bude pomaknuto prema napred.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02150948-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gledati,motriti,opaziti,osmatrati,pogledati,posmatrati,pratiti,promatrati,spaziti,ugledati,videti',
#    'Definicija': 'videti ili posmatrati',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02121620-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prava mačka',
#    'Definicija': 'Životinja iz porodice mačaka koja ima debelo meko krzno i može da reži: domaće mačke i divlje mačke.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07206887-n',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'kontradikcija',
#    'Definicija': 'u logici, iskaz koji je uvek netačan',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08717209-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Kamerun,Republika Kamerun',
#    'Definicija': 'država na zapadnoj obali centralne Afrike, stekla nezavisnost 1960',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07270179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'znak,beleg',
#    'Definicija': 'Prepoznatljiv simbol.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05976948-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stoicizam',
#    'Definicija': '(filozofija) filozofski sistem stoika zasnovan na učenjima drevnog grčkog filozofa Zenona',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10518602-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'redovnik',
#    'Definicija': 'Član monaškog reda koji se zakleo na siromaštvo, poslušnost i krepost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07154330-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'idiom,fraza',
#    'Definicija': 'Izraz čije značenje ne može da se zaključi iz značenja reči koje ga sačinjavaju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00001740-a',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'sposoban,kadar',
#    'Definicija': 'Koji ima potrebne sposobnosti, veštinu ili znanje da nešto uradi.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00002452-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Odvojen i zaokružni objekat.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07197021-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ispit,ispitno pitanje,test',
#    'Definicija': 'Skup pitanja ili vežbanja kojim se procenjuje veština ili znanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02991048-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'elektrohemijska ćelija',
#    'Definicija': 'uređaj koji isporučuje električnu struju kao rezultat hemijske reakcije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03014705-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kovčeg,sanduk,škrinja',
#    'Definicija': 'kutija sa poklopcem, korišćena za skladištenje, obično velika i čvrsta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02071294-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kit ubica,kosatka,Orcinus orca',
#    'Definicija': 'Grabljivi crnobeli kit sa zubima sa velikim leđnim perajem; živi u hladnim vodama.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13729902-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'realni broj',
#    'Definicija': 'svaki racionalan ili iracionalan broj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02228031-v',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'ostaviti',
#    'Definicija': 'Rešiti se nečega.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03781787-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'monitor',
#    'Definicija': 'deo elektronske opreme koji kontinuirano prati operacije sistema i upozorava na probleme',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00471613-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bejzbol',
#    'Definicija': 'utakmica sa palicom i loptom između dve ekipe od 9 igrača; ekipe se smenjuju pokušavajući da pomoću palice ostvare pogodak',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00901476-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kompjuterizovana tomografija,aksijalna tomografija,CT,skener,računarska tomografija',
#    'Definicija': 'savremena metoda ispitivanja, koja se zasniva na nekim starim metodama (upotreba X zraka, tehnika tomografskog snimanja) i nekim savremenim tehničkim dostignućima (upotreba računara), pri čemu se dobijaju snimci u jednoj osi u slojevima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00625393-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvaran,realan,materijalan',
#    'Definicija': 'koji postoji u stvarnosti, uzet iz života',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07930554-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'punč',
#    'Definicija': 'rashlađeno mešano piće koje često sadrži alkohol i priprema se za više serviranja; servira se u činiji punč',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06751974-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uslov',
#    'Definicija': 'jedan od koncepata koji se poredi ili povezuje u logičkoj propoziciji',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01211699-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'manipulisati',
#    'Definicija': 'držati nešto u rukama i pomerati ga',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00158222-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'porasti',
#    'Definicija': 'Rasti po ceni ili nivou.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01635432-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zamišljati,zamisliti,dočaravati,dočarati,predočiti',
#    'Definicija': 'Zamisliti, videti u mislima.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-12143676-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kukuruz,Zea Mays',
#    'Definicija': 'Visoka jednogodišnja žitarica koja nosi klip na velikim ušima; široko rasprostranjena u Americi sa raznim varijetetima; osnovna žitarica u Meksiku i Centralnoj i Južnoj Americi pre Kolumba.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13375891-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'avans,predujam',
#    'Definicija': 'Iznos koji se plaća pre nego što se zaradi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09078231-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Havaji',
#    'Definicija': 'Savezna država SAD-a u centralnom Pacifiku na Havajskim ostrvima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08897065-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Egipat,Misir,Arapska Republika Egipat',
#    'Definicija': 'država na severoistoku Afrike, nalazi se na mestu drevne civilizacije čiji je procvat bio od 2600 do 30 p.n.e',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02733524-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'luk',
#    'Definicija': 'Građevinska konstrukcija (obično zakrivljena) koja služi da premosti otvor (arhitektura).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03094404-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'imperativni',
#    'Definicija': 'odnosi se na glagolski način kojim se izražava naredba',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-13873502-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kružnica',
#    'Definicija': 'elipsa kod koje su dve ose iste dužine; kriva u ravni koja se dobija kretanjem tačke na stalnom rastojanju od jedne fiksne tačke',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04424218-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Neka ljudska tvorevina.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00692329-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'apstrahovati,teoretisati',
#    'Definicija': 'razmišljati o kakvom konceptu nemajući na umu konkretan primer, razmotriti nešto na abstraktan i teoretski način',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04127904-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jedro',
#    'Definicija': 'Veliki komad tkanine, na primer platna, pomoću koga se koristi vetar za pokretanje jedrenjaka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02778669-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lopta,loptica',
#    'Definicija': 'okrugli objekat koji se u igrama udara, baca ili šutira',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02842042-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'semantički',
#    'Definicija': 'koji se odnosi na proučavanje značenja i promena značenja',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-13661273-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dolar',
#    'Definicija': 'osnovna nočana jedinica u mnogim zemljama; vrednost joj je 100 centi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05671325-n',
#    'POS': 0.125,
#    'NEG': 0.25,
#    'Lemme': 'stvar,posao',
#    'Definicija': 'Neodređeno specifikovana preokupacija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13667908-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'real,brazilski real,BRL',
#    'Definicija': 'osnovna novčana jedinica Brazila',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00795720-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'posao,poduhvat,projekat',
#    'Definicija': 'Neki posao koji preduzet ili se planira.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13333237-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ulog,investicija',
#    'Definicija': 'Novac koji se ulaže uz očekivani profit.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03782190-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'monitor,MONITOR (MONITOR),MONITORSKI UREĐAJ (MONITORING DEVICE)',
#    'Definicija': 'ekran koji se sastoji od uređaja koji preuzima signale sa računara i prikazuje ih na CRT ekranu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00874067-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ocena,procenjivanje,sud',
#    'Definicija': 'Čin procenjivanja ili prosuđivanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02518161-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'držati se,nositi se',
#    'Definicija': 'Ponašati se na određen način.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08101937-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'preci,loza,pedigre',
#    'Definicija': 'Praoci neke osobe.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13769033-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'puna mera',
#    'Definicija': 'Količina koja može da stane u neku mericu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06468951-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sinopsis',
#    'Definicija': 'skica rezimea koja sadrži glavne tačke neke teroije ili ideje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05855004-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Specijalna apstrakcija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01082454-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hvatati',
#    'Definicija': 'biti hvatač (u bejzbolu)',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00845523-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'seksualni odnos,seksualni čin,koitus,kopulacija',
#    'Definicija': 'fizički odnos između muškarca i žene',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04350905-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odelo,garnitura',
#    'Definicija': 'skup odevnih predmeta za nošenje na otvorenom, iste tkanine i boje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07452074-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'svadba',
#    'Definicija': 'Društvena prilika u kojoj se vrši ceremonija sklapanja braka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00761713-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pregovarati',
#    'Definicija': 'raspravljati o uslovima kakvog dogovora',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00378069-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gorenje',
#    'Definicija': 'Čin u kome nešto gori',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07596684-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slatkiš',
#    'Definicija': 'Hrana koja sadrži puno šećera.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02189398-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čuti,načuti,oslušnuti,slušati,uhvatiti',
#    'Definicija': 'opaziti slušajući',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00706243-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izneti predlog',
#    'Definicija': 'dati na razmatranje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08507558-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izvor,početak,poreklo',
#    'Definicija': 'Mesto gde nešto počine, gde nastaje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03165211-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'glavna knjiga',
#    'Definicija': 'Knjigovodstveni dnevnik kao fizički objekat.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02187922-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grgoljiti,žuboriti,romoriti',
#    'Definicija': 'Teći u nepravilnom toku praveći grgoljav zvuk; o vodi.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08358594-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ćelija',
#    'Definicija': 'mala jedinica koja služi kao deo jezgra ili kao jezgro većeg političkog pokreta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05999797-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naučno područje,nauka',
#    'Definicija': 'Određena grana naučnog znanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13802306-n',
#    'POS': 0.25,
#    'NEG': 0.25,
#    'Lemme': 'imperativ,zapovedni način',
#    'Definicija': 'način kojim se izražava želja da se utiče na ponašanje slušaoca',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10235549-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rođak ili svojta',
#    'Definicija': 'osoba u srodstvu po krvi ili braku',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04295881-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stadion',
#    'Definicija': 'Velika konstrukcija za sportove na otvorenom i zabavu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02872752-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čizma',
#    'Definicija': 'Obuća koja pokriva celo stopalo i potkolenicu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02713372-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'štrčati,strčati,stršiti',
#    'Definicija': 'izbijati upadljivo iz nečega',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-13275495-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trošak,izdatak',
#    'Definicija': 'Iznosi plaćeni za robu i usluge za koje je moguć oslobađanje od poreza (nasuprot troškovima kapitala).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01439190-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zgrabiti,ščepati',
#    'Definicija': 'Dokopati se nečega tako da se obustavi njegovo kretanje.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07901587-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'žestoko piće,cuga,cirka',
#    'Definicija': 'nešto pre destilovano nego fermentisano',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08954611-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Korejsko poluostrvo',
#    'Definicija': 'poluostrvo u Aziji koje razdvaja Žuto more od Japanskog mora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01036996-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'venčanje',
#    'Definicija': 'Čin venčanja; bračna ceremonija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02127808-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'velika mačka',
#    'Definicija': 'Neka od više velikih mačaka koje mogu da reže i žive u divljini.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03819595-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pletivo',
#    'Definicija': 'Tkanina od niti, konopca ili žice koji se tkuju zajedno u pravilnim intervalima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01442779-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'preforirati',
#    'Definicija': 'Napraviti rupu u nečemu ili izmedžu nečega da bi se lakše odvajalo.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00138956-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grabljenje,ščepavanje,hvatanje',
#    'Definicija': 'Čin hvatanja predmeta pomoću ruke.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01099436-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ulaganje',
#    'Definicija': 'Čin ulaganja novca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13286801-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'interes',
#    'Definicija': 'Pravedni ili zakoniti deo nečega; finansijska uključenost u nešto.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03602562-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dnevnik',
#    'Definicija': 'knjiga zabeleški kao fizički predmet',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01482330-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'morski pas,ajkula',
#    'Definicija': 'Neka od brojnih morskih riba-mesoždera sa izduženim telom,? i debelom kožom koja je prekrivena malim nazubljenim krljuštima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06402031-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dnevnik',
#    'Definicija': 'dnevno pisane zabeleške (obično ličnih) iskustava i zapažanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07221094-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naracija,priča,pripovest,pripovetka',
#    'Definicija': 'priča o događajima ili dešavanjima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01481154-v',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'obesiti',
#    'Definicija': 'Okačiti nekoga da visi.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03990474-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lonac',
#    'Definicija': 'Metalna ili zemljana posuda za kuvanje, okrugla i duborka, česti ima reučke i poklopac.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01048171-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cvileti,kevtati',
#    'Definicija': 'lajati visokim tonom',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00651991-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odlikovati,praviti razliku',
#    'Definicija': 'Biti distingtivno svojstvo, osobina ili crta; ponekad u veoma pozitivnom smislu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02666943-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanica',
#    'Definicija': 'Zgrada u kojoj se vrši likvidacija životinja radi proizvodnje mesa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03800563-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'muzej',
#    'Definicija': 'Mesto za sakupljanje i prikazivanje predmeta koji imaju naučnu ili istorijsku ili umetničku vrednost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00023271-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'saznanje',
#    'Definicija': 'Psihološki rezultat opažanja i učenja i rezonovanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06267893-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'novina malog formata',
#    'Definicija': 'novina malog formata (400x300 mm)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07968702-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'interesna grupa',
#    'Definicija': 'Obično u množini, društvena grupa čiji članovi kontrolišu neko polje rada i koji imaju zajedničke ciljeve.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03722007-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'marker',
#    'Definicija': 'pribor za pisanje koji služi da se nešto označi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00875806-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'podneti,predložiti',
#    'Definicija': 'Istaći za raspravu ili prihvatanje.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00098346-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'aktivirati sistem,podići sistem,pokrenuti sistem,ponovo aktivirati sistem,ponovo podići sistem,ponovo pokrenuti sistem',
#    'Definicija': 'pokrenuti učitavanje (operativnog sistema) i započeti inicijalne procese',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08050678-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vlast,režim,vlada',
#    'Definicija': 'Organizacija koja je upravljačko telo političke jedinice.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03359137-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'baterijska lampa',
#    'Definicija': 'Mala prenosiva električna lampa koja radi na baterije.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15287830-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ciklus,ritam',
#    'Definicija': 'interval u toku koga se ponavlja sekvencija događaja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02732798-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'primiti,primati',
#    'Definicija': 'imati prostora za nešto, obuhvatiti u svoj prostor',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-15236859-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jesen',
#    'Definicija': 'Godišnje doba kada lišće opada sa drveća.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04922113-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odgoj,vaspitanje',
#    'Definicija': 'osobine stečene kao posledica načina na koji ste bili tretirani kao dijete',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05576194-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jagodica,jabučica',
#    'Definicija': 'Više ili manje zaobljeni deo tela na stopalu ili vrhu palca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10523076-n',
#    'POS': 1.0,
#    'NEG': 0.0,
#    'Lemme': 'istraživač',
#    'Definicija': 'Naučnik koji je posvećen istraživanju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04617289-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nešto',
#    'Definicija': 'Atribut ili kvalitet za koji se smatra da ima sopstvenu egzistenciju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04515129-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'potporanj,podupirač',
#    'Definicija': 'Vertikalni građevinski element, kao stub.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01107206-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'federalni,savezni',
#    'Definicija': 'koji je karakterističan za ili koji odražava takav oblik vlasti u kome je vlast podeljena između jedne centralne i nekoliko regionalnih uprava',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02719009-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'elektrostatički',
#    'Definicija': 'koji se tiče ili koji proizvodi ili koji je izazvan statičkim elektricitetom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05552607-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grudni koš,toraks',
#    'Definicija': 'Deo ljudskog tela između vrata i dijafragme ili odgovarajući deo kod drugih kičmenjaka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13391967-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dolar',
#    'Definicija': 'američki novčić koji vredi jedan dolar',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09376198-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'okean',
#    'Definicija': 'velika vodena površina koji čini glavni deo hidrosfere',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06009086-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'koordinatni početak',
#    'Definicija': 'Tačka preseka koordinatnih osi; gde su sve koordinatne vrednosti nula.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01200095-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'konzistentan,uniforman',
#    'Definicija': 'koji je uvek isti po strukturi ili sastavu',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-06303888-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'termin',
#    'Definicija': 'Reč ili izraz koji se koristi za neku određenu stvar.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00196485-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zamena,supstitucija',
#    'Definicija': 'Stavljanje jedne stvari ili osobe na mesto druge.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09989502-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'plesač',
#    'Definicija': 'Izvođač koji pleše.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01522716-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zaokružiti',
#    'Definicija': 'napraviti krug oko nečega',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06255777-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'list papira,list',
#    'Definicija': 'Koristi se za pisanje ili štampanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03088164-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gumica,higijenska gumica,kondom,kurton,prezervativ,zaštita',
#    'Definicija': 'kontraceptivni uređaj koji se sastoji od tanke gume ili lateksne prevlake koja se nosi preko penisa tokom seksa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13861050-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ravnina',
#    'Definicija': 'neograničen dvodimenzionalan oblik',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03827107-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čvor,klijent,gost',
#    'Definicija': 'u računarstvu, računar koji je povezan na računarsku mrežu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13134947-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'plod',
#    'Definicija': 'Zrelo reproduktivno telo biljke semenjače.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01245637-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'glačati,uglačati',
#    'Definicija': 'Učiniti da površine sijaju.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03306207-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izvoz',
#    'Definicija': 'Dobra ili usluge prodati stranoj zemlji.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15224486-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': '?term',
#    'Definicija': 'Ograničen vremenski period.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02725829-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'federalni,savezni',
#    'Definicija': 'koji se odnosi na centralnu vladu federacije',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07086518-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ritam,takt',
#    'Definicija': 'Osnovna ritmička jedinicaâ\x80\x93 u muzičkom delu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08896831-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Egipatsko carstvo,Egipat',
#    'Definicija': 'drevno carstvo koje je zauzimalo prostor oko reke Nil i kojim su vladali faraoni of Israel; centered on the Nile River and ruled by a Pharaoh; figured in many events described in the Old Testament',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01992503-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ići,prolaziti,odmicati,nastaviti',
#    'Definicija': 'i u metaforičkom značenju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03015254-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'komoda',
#    'Definicija': 'Komad nameštaja sa ladicama za držanje odeće.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06723908-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar,iskaz',
#    'Definicija': 'Iskaz posmatran kao objekat.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02397732-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hot,papren',
#    'Definicija': 'koji jako nadražuje organe ukusa i mirisa',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07584727-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'supa,lonac supe',
#    'Definicija': 'tečnost u kojoj se kuvaju povrće ili meso',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08240169-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grupa,grupacija,krug',
#    'Definicija': 'Nezvanična asocijacija ljudi ili grupa.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02056265-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'verski,duhovan',
#    'Definicija': 'koji se tiče svetih stvari, religije ili crkve',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07289831-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Neki događaj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00136329-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'šutiranje',
#    'Definicija': 'Čin zadavanja udarca nogom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00620424-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanica,mesara,mesarija',
#    'Definicija': 'radnja mesara',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02779435-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lopta',
#    'Definicija': 'okrugao predmet koji se koristi kao igračka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07961016-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grumen,kvrga,gruda',
#    'Definicija': 'Kompaktna masa.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02961258-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poljski',
#    'Definicija': 'koji se tiče Poljske, njenih ljudi i kulture',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-06295235-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oblik množine,oblik plurala,oblik u množini,oblik u pluralu',
#    'Definicija': 'oblik reči koji označava više od jednog objekta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04188179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'krevetski čaršav,lancun',
#    'Definicija': 'deoposteljine koji služi za prekrivanje kreveta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06148148-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'političke nauke,politikologija',
#    'Definicija': 'proučavanje upravnih sistema u državama i drugih političkih jedinica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04612722-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'količina proizvedenih proizvoda,prinos',
#    'Definicija': 'Neka količina proizvoda.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03032811-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'krug,cirkular',
#    'Definicija': 'kružni ili rotirajući mehanizam',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04188643-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'list',
#    'Definicija': 'Ravna tvorevina koja se relativno tanka u odnosu na širinu i dužinu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06669864-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jednačina',
#    'Definicija': 'matematički iskaz da su dva izraza jednaka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01061333-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zahtevanje',
#    'Definicija': 'čin kojim se zahteva',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05578442-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gležanj,članak',
#    'Definicija': 'Zglob koji spaja stopalo i potkoleničnu kost, tarsus.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00497061-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'podignuti,povisiti',
#    'Definicija': 'Podići ili povećati.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04446521-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zahod,nužnik,klozet',
#    'Definicija': 'Vodovodna instalacija za vršenje nužde.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07609840-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'desert,poslastica',
#    'Definicija': 'Jelo koje se poslednje servira u obroku.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01510827-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uključiti',
#    'Definicija': 'Staviti u pogon.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02678438-v',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'zainteresovati se,zanimati se,brinuti',
#    'Definicija': 'biti na nečijem umu',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07906877-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kukuruzni viski',
#    'Definicija': 'viski destilovan iz smeš koja sadrži bar 80 procenata kukuruza',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01124794-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'upravljanje,vladanje',
#    'Definicija': 'Čin upravljanja; sprovođenje vlasti.',
#    'Vrsta': 'n'}],
#  'iteration': 0}

# %%
import pandas as pd

# %%
df_POS = pd.DataFrame(defi["POS"])

# %%
df_POS
# Out:
#                   ID      POS   NEG  \
# 0   ENG30-14538472-n  0.12500  0.00
# 1   ENG30-00474017-v  0.12500  0.00
# 2   ENG30-07528470-n  0.25000  0.25
# 3   ENG30-04814238-n  0.62500  0.00
# 4   ENG30-01123148-a  0.00000  0.00
# 5   ENG30-01375831-a  0.00000  0.00
# 6   ENG30-01816431-v  0.37500  0.00
# 7   ENG30-02397637-v  0.25000  0.00
# 8   ENG30-14474052-n  0.75000  0.00
# 9   ENG30-00925490-v  0.12500  0.00
# 10  ENG30-00228645-a  0.50000  0.00
# 11  ENG30-04849241-n  0.87500  0.00
# 12  ENG30-00473799-v  0.00000  0.00
# 13  ENG30-07289588-n  0.62500  0.00
# 14  ENG30-00518395-v  0.37500  0.00
# 15  ENG30-01129977-a  0.00000  0.00
# 16  ENG30-00362467-a  0.75000  0.00
# 17  ENG30-14491625-n  0.25000  0.00
# 18  ENG30-02036934-a  0.00075  0.00
# 19  ENG30-01817938-v  0.25000  0.00
# 20  ENG30-01821423-v  0.12500  0.00
# 21  ENG30-00064095-v  0.25000  0.00
# 22  ENG30-07357388-n  0.37500  0.00
# 23  ENG30-00093483-n  0.12500  0.00
# 24  ENG30-01676517-a  0.75000  0.00
# 25  ENG30-14546844-n  0.00000  0.00
# 26  ENG30-07509996-n  0.75000  0.00
# 27  ENG30-07491981-n  0.75000  0.00
# 28  ENG30-00248659-v  0.50000  0.00
#
#                                                 Lemme  \
# 0                                           sigurnost
# 1                                 ugladiti,rafinirati
# 2   nalet,juriš,naboj,uzbuđenje,ushićenje,stimulacija
# 3                        veličanstvenost,briljantnost
# 4                                častan,dobar,pouzdan
# 5   slavan,poznat,čuven,značajan,renomiran,priznat...
# 6                                            usrećiti
# 7                   unaprediti,promovisati,promaknuti
# 8                               prosperitet,uspešnost
# 9                              čuditi se,oduševiti se
# 10                                          optimalan
# 11                                            dobrota
# 12               obnoviti,doterati,uglancati,uljuditi
# 13                                               čudo
# 14                                 olakšati,potpomoći
# 15                      častan,dobar,primeran,ugledan
# 16                                     uveseljavajući
# 17                                           izobilje
# 18                             dobar,moralan,pravedan
# 19               bodriti,osokoliti,obodriti,ohrabriti
# 20                       zainteresovati,zaintrigirati
# 21                          olakšati,ublažiti,utažiti
# 22                       napredak,progres,unapređenje
# 23                                   spas,izbavljenje
# 24  fantastičan,veličanstven,izvanredan,sjajan,izv...
# 25                              ispravnost,korektnost
# 26                                 čuđenje,zaćuđenost
# 27                           polet,oduševljenje,slast
# 28                                    napredovati,ići
#
#                                            Definicija Vrsta
# 0   Stanje u kome je neko siguran da neki uzrok ne...     n
# 1                 Poboljšati glačanjem ili kresanjem.     v
# 2               brzo oslobađanje zalihe uticajne sile     n
# 3       Osobina nekoga ko je veličanstven, briljantan     n
# 4   imati poželjne ili pozitivne kvalitete, posebn...     a
# 5                            opšte prihvaćen i uvažen     a
# 6                            usrećiti ili zadovoljiti     v
# 7                              Dodeliti viši položaj.     v
# 8        Stanje kada je neko prosperitetan i uspešan.     n
# 9                           diviti se i čuditi nečemu     v
# 10  koji je najpoželjniji pod datim uslovima ili o...     a
# 11                              Moralna izvanrednost.     n
# 12  Ostalo je još samo da se doteraju neke finese ...     v
# 13                 nešto što izaziva osećanje čuđenja     n
# 14                                    Učiniti lakšim.     v
# 15                                   moralno primeran     a
# 16  koji je pun pozitivne energije i širi dobro ra...     a
# 17                                  Veliko bogatstvo.     n
# 18              onaj koji poseduje moralne kvalitete;     a
# 19                                    dati ohrabrenje     v
# 20  pobuditi nečiju radoznalost; podstaći nečije i...     v
# 21              Omogućiti olakšanje od fizičkog bola.     v
# 22               Promena nabolje, napredak u razvoju.     n
# 23  Oporavak ili način čuvanja od gubitka ili opas...     n
# 24  izuzetno dobar; ove reči se koriste za naglaša...     a
# 25                stanje bez oštećenja ili propadanja     n
# 26     osećanje izazvano nečim čudnim i iznenađujućim     n
# 27                   energično i oduševljeno uživanje     n
# 28                    razvijati se u pozitivnom smeru     v

# %%
df_OBJ = pd.DataFrame(defi["OBJ"])

# %%
df_OBJ
# Out:
#                    ID    POS  NEG  \
# 0    ENG30-02117955-v  0.125  0.0
# 1    ENG30-02982599-n  0.000  0.0
# 2    ENG30-07323922-n  0.000  0.0
# 3    ENG30-01993926-v  0.000  0.0
# 4    ENG30-02150948-v  0.000  0.0
# ..                ...    ...  ...
# 155  ENG30-07609840-n  0.000  0.0
# 156  ENG30-01510827-v  0.000  0.0
# 157  ENG30-02678438-v  0.375  0.0
# 158  ENG30-07906877-n  0.000  0.0
# 159  ENG30-01124794-n  0.000  0.0
#
#                                                  Lemme  \
# 0                                             uhvatiti
# 1                                          reza,rajber
# 2                         postanje,postanak,prapočetak
# 3                        primaknuti,prineti,približiti
# 4    gledati,motriti,opaziti,osmatrati,pogledati,po...
# ..                                                 ...
# 155                                  desert,poslastica
# 156                                          uključiti
# 157              zainteresovati se,zanimati se,brinuti
# 158                                    kukuruzni viski
# 159                               upravljanje,vladanje
#
#                                             Definicija Vrsta
# 0          Osetiti čulima brzo, iznenada ili trenutno.     v
# 1        pričvrščivaač za zatvaranje vrata ili prozora     n
# 2    Događaj koji predstavlja početak; prvi deo ili...     n
# 3        Učiniti da nešto bude pomaknuto prema napred.     v
# 4                                videti ili posmatrati     v
# ..                                                 ...   ...
# 155           Jelo koje se poslednje servira u obroku.     n
# 156                                   Staviti u pogon.     v
# 157                                biti na nečijem umu     v
# 158  viski destilovan iz smeš koja sadrži bar 80 pr...     n
# 159               Čin upravljanja; sprovođenje vlasti.     n
#
# [160 rows x 6 columns]

# %%
df_NEG = pd.DataFrame(defi["NEG"])

# %%
df_NEG
# Out:
#                   ID   POS      NEG  \
# 0   ENG30-01230387-a  0.00  0.37500
# 1   ENG30-00364881-a  0.00  0.62500
# 2   ENG30-00796976-v  0.00  0.00000
# 3   ENG30-00402539-v  0.00  0.12500
# 4   ENG30-01770501-v  0.25  0.37500
# 5   ENG30-01792567-v  0.00  0.37500
# 6   ENG30-07532440-n  0.00  0.75000
# 7   ENG30-02466111-a  0.00  0.00075
# 8   ENG30-01619929-v  0.00  0.00000
# 9   ENG30-04709253-n  0.00  0.12500
# 10  ENG30-14408086-n  0.00  0.25000
# 11  ENG30-07533877-n  0.00  0.50000
# 12  ENG30-09369169-n  0.00  0.00000
# 13  ENG30-00220956-a  0.00  0.37500
# 14  ENG30-02463582-a  0.00  0.62500
# 15  ENG30-00223983-n  0.00  0.00000
# 16  ENG30-04834605-n  0.00  0.00000
# 17  ENG30-00220522-n  0.00  0.37500
# 18  ENG30-00735936-n  0.00  0.62500
# 19  ENG30-07427060-n  0.00  0.50000
# 20  ENG30-13990675-n  0.00  0.62500
# 21  ENG30-01327301-v  0.00  0.50000
# 22  ENG30-14365741-n  0.00  0.12500
# 23  ENG30-00838043-v  0.00  0.25000
# 24  ENG30-00736786-n  0.00  0.00000
# 25  ENG30-00193480-a  0.00  0.62500
# 26  ENG30-14213199-n  0.00  0.62500
# 27  ENG30-07536245-n  0.00  0.87500
# 28  ENG30-02482425-v  0.00  0.62500
#
#                                                 Lemme  \
# 0                                          beznadežan
# 1                        deprimirajući,tmuran,sumoran
# 2   odbaciti,odbacivati,odbijati,odbiti,prezirati,...
# 3                               komplikovati,zamrsiti
# 4                                 uznemiriti,uzrujati
# 5                                   nauditi,naškoditi
# 6                                         tuga,žalost
# 7                                           nepouzdan
# 8       uništavati,uništiti,upropaštavati,upropastiti
# 9                                             teškoća
# 10                                  teškoća,neprilika
# 11                                  patnja,paćeništvo
# 12                                             gnezdo
# 13                                              ružan
# 14                 ciničan,mizantropski,mizantropičan
# 15           klanica,klanje,krvoproliće,masakr,pokolj
# 16                                          sebičnost
# 17                                            ubistvo
# 18                                      nepristojnost
# 19                                        atrofiranje
# 20                                            krivica
# 21                      likvidirati,ucmekati,skembati
# 22                                           atrofija
# 23                 praviti se,činiti se,izmotavati se
# 24             impulsivnost,raspojasanost,razuzdanost
# 25                                        užasavajući
# 26                                muka,fizička patnja
# 27                           krivica,osećanje krivice
# 28                        ubiti,ukloniti s ovog sveta
#
#                                            Definicija Vrsta
# 0   koji je označen beznadežnošću ili ispoljava be...     a
# 1                            koji izaziva potištenost     a
# 2                                  odbiti s gnušanjem     v
# 3                                 Učiniti složenijim.     v
# 4                                     Duboko dirnuti.     v
# 5                          uzrokovati bol, unesrećiti     v
# 6   Osećanja koja se javljaju kada osoba nije u sr...     n
# 7   onaj kojem se ne može ukazati poverenje, u kog...     a
# 8       ukinuti, čega uništenje ili opoziv uzrokovati     v
# 9                         Osobina onoga što je teško.     n
# 10  Stanje stvari koje je skoro izvan nečije moguć...     n
# 11                               intenzivna ojađenost     n
# 12  Struktura u kojoj životinje ležu jaja i legu s...     n
# 13      Koji je moralno odbojan ili neugodan za čula.     a
# 14  koji misli najgore o ljudskoj prirodi i motivi...     a
# 15       divljačko i prekomerno ubijanje mnogih ljudi     n
# 16  škrtost koja proizilazi iz brige za sopstvenu ...     n
# 17  Nezakonito ubijanje s predumišljajem jednog čo...     n
# 18                  nedolično ili nemoralno ponašanje     n
# 19  Slabljenje ili degeneracije, posebno usled nek...     n
# 20                   Stanje kada je učinjen prekršaj.     n
# 21                      Otarasiti se nekoga ubistvom.     v
# 22  smanjenje u veličini organa usled bolesti ili ...     n
# 23                                        Simulirati.     v
# 24                       bučno i neobuzdano ponašanje     n
# 25                        koji izaziva osećanje užasa     a
# 26         stanje bola ili patnje zbog lošeg zdravlja     n
# 27  griža savesti kada se neko oseća krivim za pre...     n
# 28              Usmrtiti namerno i sa predumišljajem.     v

# %%
pos_value_counts = df_POS['Vrsta'].value_counts()
neg_value_counts = df_NEG['Vrsta'].value_counts()
obj_value_counts = df_OBJ['Vrsta'].value_counts()

# Combine the value counts from all DataFrames
combined_value_counts = pos_value_counts.add(neg_value_counts, fill_value=0).add(obj_value_counts, fill_value=0)

# Print the combined value counts
print(combined_value_counts)
# Out:
# n    147
# v     47
# a     24
# Name: Vrsta, dtype: int64

# %%
rem_obj = ["ENG30-05528604-n",
"ENG30-00749767-n",
"ENG30-09593651-n",
"ENG30-13250542-n",
"ENG30-13132338-n",
"ENG30-05943066-n",
"ENG30-03123143-a",
"ENG30-10104209-n",
"ENG30-12586298-n",
"ENG30-01971094-n",
"ENG30-00759269-v",
"ENG30-00948206-n",
"ENG30-01039307-n",
"ENG30-02041877-v",
"ENG30-00023271-n",
"ENG30-13509196-n",
"ENG30-09450866-n",
"ENG30-03947798-n",
"ENG30-08589140-n"
          ]

# %%
len(rem_obj)
# Out:
# 19

# %%
# Initialize a dictionary to store the counts
type_counts = {}

# Iterate through the list and count the word types
for word in rem_obj:
    word_type = word[-1]  # Get the last character
    
    if word_type in type_counts:
        type_counts[word_type] += 1
    else:
        type_counts[word_type] = 1

# Print the counts for each type
print(type_counts)
# Out:
# {'n': 16, 'a': 1, 'v': 2}

# %%
for rem_id in rem_obj:
    syn = swordnet.synset_from_ID(rem_id)
    print(syn)
    print(syn.lemma_names())
    print(syn.definition())
# Out:
# Synset: ID is ENG30-05528604-n
# ['nosna šupljina']
# either of the two cavities lying between the floor of the cranium and the roof of the mouth and extending from the face to the pharynj
# Synset: ID is ENG30-00749767-n
# ['izdaja', 'verolomstvo']
# čin namernog izdajstva
# Synset: ID is ENG30-09593651-n
# ['Tantal']
# u grčkoj mitologiji zli kralj, Zevsov sin; osuđen da stoji u Hadu u vodi koja bi se povukla kada bi on želeo da pije i ispod voćke koja bi se povukla kada bi on posegao za njom
# Synset: ID is ENG30-13250542-n
# ['novac', 'imetak']
# Bogatstvo izraženo kroz novac.
# Synset: ID is ENG30-13132338-n
# ['?flower cluster']
# an inflorescence consisting of a cluster of flowers
# Synset: ID is ENG30-05943066-n
# ['vera', 'poverenje']
# Potpuno verovanje u osobu ili plan itd.
# Synset: ID is ENG30-03123143-a
# ['tarzalni', 'nožji']
# of or relating to or near the tarsus of the foot; "tarsal bones"
# Synset: ID is ENG30-10104209-n
# ['gazda', 'šef', 'pretpostavljeni']
# Osoba koja upravlja radom radnika.
# Synset: ID is ENG30-12586298-n
# ['?calamus']
# any tropical Asian palm of the genus Calamus; light tough stems are a source of rattan canes
# Synset: ID is ENG30-01971094-n
# ['?decapod']
# cephalopods having eight short tentacles plus two long ones
# Synset: ID is ENG30-00759269-v
# ['preklinjati']
# učtivo se obraćati s molbom nekome
# Synset: ID is ENG30-00948206-n
# ['iskorišćavanje']
# Čin kojim neki deo zemlje postaje produktivniji, korisniji ili profitabilniji.
# Synset: ID is ENG30-01039307-n
# ['ispoved']
# čin pokajnika kojim on otkriva svoje grehe pred sveštenikom u svetoj tajni pokajanja u nadi za oproštajem (u Rimokatoličkoj crkvi)
# Synset: ID is ENG30-02041877-v
# ['srušiti se', 'kolabirati', 'propasti']
# raspasti se; i u prenesenom značenju
# Synset: ID is ENG30-00023271-n
# ['saznanje']
# Psihološki rezultat opažanja i učenja i rezonovanja.
# Synset: ID is ENG30-13509196-n
# ['gubitak']
# pad aktivnosti
# Synset: ID is ENG30-09450866-n
# ['superior planet']
# any of the planets whose orbit lies outside the earth's orbit
# Synset: ID is ENG30-03947798-n
# ['pique']
# tightly woven fabric with raised cords
# Synset: ID is ENG30-08589140-n
# ['irredenta', 'irridenta']
# a region that is related ethnically or historically to one country but is controlled politically by another

# %%
Synset_Sentiment_set_2 = PolaritySets(swordnet, 0)
Synset_Sentiment_set_2.addWSWN()

# %%
defi2 = Synset_Sentiment_set_2.getDef()
defi2
# Out:
# {'POS': [],
#  'NEG': [],
#  'OBJ': [{'ID': 'ENG30-02769463-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nominativni,subjektivni',
#    'Definicija': 'koji je u fleksivnom obliku kojim se tipično identifikuje gramatički subjekat glagola',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-06616806-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dokumentarni film',
#    'Definicija': 'Film ili TV program koji predstavlja činjenice o stvarnim ljudima i događajima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14865221-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Ortoklas',
#    'Definicija': 'beli ili obojeni monoklinični feldspar',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13524399-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'brisanje,izostavljanje',
#    'Definicija': 'bilo koji proces koji čini da se zvuci ne izgovaraju pri izgovaranju reči ili izraza',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01127795-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'braniti se',
#    'Definicija': 'Biti u odbrambenom položaju; delovati protiv napada.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01310660-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kopati,izdubiti',
#    'Definicija': 'Ukloniti unutrašnji deo ili jezgro nečega.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01871265-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'životinja sa kljovama',
#    'Definicija': 'Sisar sa istaknutim kljovama (kod vepra ili slona).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02582042-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'postupati,parničiti,tužiti,parničiti se',
#    'Definicija': 'pokrenuti parnicu protiv nekog; tužiti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01294051-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dolazeći',
#    'Definicija': 'Onaj koji dolazi, sledi ili će biti u budućnosti.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-06835206-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lambda',
#    'Definicija': 'jedanaesto slovo grčkog alfabeta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02853016-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'blok',
#    'Definicija': 'prostor u velikoj zgradi koji je podeljen u zasebne jedinice',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05516067-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ciljni organ',
#    'Definicija': 'u radiologiji, organ koji prima terapeutsku dozu radioaktivne supstance.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06384480-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'katren',
#    'Definicija': 'strofa od četiri stiha',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13214031-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'papratac',
#    'Definicija': 'Neka od mnogih paprati iz roda Pteris koje imaju sastavljeno lišće, uključuje i neke popularne kućne biljke.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13691764-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kolumbijski pezo,kolumbijski pezos,COP',
#    'Definicija': 'osnovna novčana jedinica Kolumbije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01542207-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lita,politi,polivati,prosipati,prosuti,razliti,razlivati',
#    'Definicija': 'uzrokovati ili dozvoliti da (tečna supstanca) teče ili ističe iz kakve posude',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03284981-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'emajlirano posuđe',
#    'Definicija': 'posude za kuvanje od emajliranog čelika',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02761229-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'buknuti',
#    'Definicija': 'zapaliti se uz jak plamen',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00011160-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'halapljiv',
#    'Definicija': 'koji želi da jede i pije više nego što mu je potrebno',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-11221778-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Panini',
#    'Definicija': 'indijski gramatičar čija je gramatika sanskrita prvi poznati primer deskriptivne lingvistike (oko 400. godine stare ere)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14836127-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dioksid',
#    'Definicija': 'oksid koji ima dva atoma kiseonika u molekulu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14826173-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'krep papir',
#    'Definicija': 'papir koji deluje zgužvano; obično je u boji i koristi se za dekoraciju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01468576-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izbaciti,isključiti,isključivati,isterati',
#    'Definicija': 'Naterati na odlazak sa nekog mesta.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-11796744-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Araliaceae,porodica Araliaceae',
#    'Definicija': 'Uglavnom tropsko drveće, žbunje i puzavice: bršljan.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01666327-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'šiti',
#    'Definicija': 'Praviti odeću pomoću tkanine.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00191142-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'promena,menjanje',
#    'Definicija': 'Radnja promene nečega.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00721141-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'maska',
#    'Definicija': 'Neformalan termin za ulogu neke osobe.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04592962-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bekstejdž,zakulisni prostor',
#    'Definicija': 'pozorišna oblast koja se nalazi izvan vidnog polja publike',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12506614-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Anthyllis,rod Anthyllis',
#    'Definicija': 'Rod mediteranskih zeljastih biljkaka i žbunja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02830954-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'litijumski',
#    'Definicija': 'o litijumu ili koji sadrži litijum',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-11458624-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sila',
#    'Definicija': 'U fizici dejstvo koje proizvodi promenu u fizičkoj veličini.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13963970-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'brak,matrimonijum,matrimonij,zajednica',
#    'Definicija': 'Stanje u kome se nalaze muž i žena.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14585519-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'atom,trunčica',
#    'Definicija': 'Majušni komadić nečega.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09738400-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Amerikanac',
#    'Definicija': 'Rođen ili stanovnik Severne, Centralne ili Južne Amerike.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00371314-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'proširivanje',
#    'Definicija': 'dodavanje informacija ili detalja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09538757-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'faun',
#    'Definicija': 'drevno italijansko božanstvo u ljudskom obliku sa rogovima, zašiljenim ušima i kozjim repom; u grčkoj mitologiji mu odgovara satir',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07640991-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'blinc',
#    'Definicija': '(judaizam) Tanka palačinka punjena nadevom koja se peče ili prži.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01950731-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gološkržnjak',
#    'Definicija': 'Morski puž iz podreda Nudibranchia bez kućice i često sa telom lepe boje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09235894-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Karipsko more',
#    'Definicija': 'deo Atlantskog okeana između Severne i Južne Amerike pdakle počine Golfska struja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01029671-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bdenje,bdenije',
#    'Definicija': 'molitveno gledanje (posebno tokom večeri religijskog festivala)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02207179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trut',
#    'Definicija': 'Muška pčela bez žaoke čija je jedina funkicja da oplodi kraljicu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00471711-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'eliminirati,eliminisati,isključiti,odstraniti,osloboditi čega,osloboditi se,otarasiti se,ukinuti,ukloniti,uništiti,zatrti',
#    'Definicija': 'prekinuti ili izbaciti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00390445-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'deljenje reči na slogove',
#    'Definicija': 'povezivanje slogova i reči pomoću crtica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07702193-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'knedla',
#    'Definicija': 'male loptice ili trake od kuvanog testa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14932554-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'diorit',
#    'Definicija': 'intermedijarna magmatska dubinska stena',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01395773-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'infuzorija',
#    'Definicija': 'član podklase Infusoria',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07724819-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'šparglasta salata',
#    'Definicija': 'lisće koje se nalazi na stabljici nalik celeru; jede se sirovo ili kuvano',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07924747-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sok od grejpfruta',
#    'Definicija': 'sok od grejpfruta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01743223-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Pythoninae,podfamilija Pythoninae',
#    'Definicija': 'Boe iz starog sveta: pitoni; u nekim klasifikacijama se smatraju familijom zmija iz Boidae.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09295576-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Planine Gvadalupe',
#    'Definicija': 'planinski lanac u južnom Novom Meksiku i zapadnom Teksasu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01635432-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zamišljati,zamisliti,dočaravati,dočarati,predočiti',
#    'Definicija': 'Zamisliti, videti u mislima.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02598768-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'igumanski,opatijski',
#    'Definicija': 'koji pripada ili je u vezi sa opatijom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-09694269-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Beninjanin',
#    'Definicija': 'stanovnik Benina ili poreklom iz Benina',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02492536-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Alouatta,rod Alouatta',
#    'Definicija': 'Majmuni drekavci.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00459498-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'žuriti,hitati',
#    'Definicija': 'Raditi nešto ili krtati se velikom brzinom.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07653217-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'teleći jezik',
#    'Definicija': 'teleći jezik koji se koristi u ishrani',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06924468-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vintun',
#    'Definicija': 'kopehanski jezik kojim govori narod Vintun',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00226319-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stiska',
#    'Definicija': 'Čin prisiljavanja postavljanja u mali prostor, nabijanje u mali prostor.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02331960-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Mus,rod Mus',
#    'Definicija': 'Tipski rod porodice Muridae: domaći miš; gornji sekutići imaju kvadratni vrh.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12189620-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Adansonia,rod Adansonia',
#    'Definicija': 'baobab; ?cream-of-tartar tree',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02002556-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bela roda,štrk,lelek,Ciconia ciconia',
#    'Definicija': 'uobičajena evropska roda sa belim perjem',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07903543-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jabukovača',
#    'Definicija': 'destilovan jak sajder',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00935103-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jeftin,snižene vrednosti,isplativ',
#    'Definicija': 'that you have the financial means for; "low-cost housing"',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-08405603-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kraljevina',
#    'Definicija': 'monarhija na čijem je čelu gralj ili kraljica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00639975-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'testiranje',
#    'Definicija': 'čin podvrgavanja nečega eksperimentalnim testovima kako bi se utvrdilo koliko dobro nešto funkcioniše',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07915366-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'koktel Harvi Wolbenger',
#    'Definicija': 'koktel napravljen od vodke ili džina i soka od pomorandže i Galijana',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13682330-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'švedska kruna,SEK',
#    'Definicija': 'osnovna novčana jedinica Švedske',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13806614-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'preterit',
#    'Definicija': 'termin kojim se nekada označavalo prosto prošlo vreme',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02522247-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Gadus,rod Gadus',
#    'Definicija': 'type genus of the Gadidae: the typical codfishes',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08181540-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'niža klasa',
#    'Definicija': 'društvena klasa koja je najniža u društvenoj hijerarhiji',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06963429-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vulgarni latinski',
#    'Definicija': 'neklasični dijalekti latinskog kojima se govorilo u Rimskom Carstvu; izvor je romanskih jezika',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06030196-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'faktorska analiza',
#    'Definicija': 'metod smanjivanja korelacionih podataka na manji broj dimenzija ili faktora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01969216-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'penjati se,popeti se',
#    'Definicija': 'Ići nagore.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07603722-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'crna čokolada',
#    'Definicija': 'čokolada koja se sastoji od čokoladnog putera i čokoladne tečnosti, zaslađena sećerom i vanilom u malim količinama; obično sadrži lecitin',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01759182-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'porodica artropoda',
#    'Definicija': 'Bilo koji od artropoda (insekata).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05010801-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'eho,odzvanjanje',
#    'Definicija': 'ponavljanje zvuka kao rezultat refleksije zvučnog talasa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12396924-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'konoplja,kanabis',
#    'Definicija': 'Bilo koja biljka iz roda Cannabis; jednogodišnji čupavi žbun sa palmolikim lišćem i kiticom malih zelenih cvetova; daje čvrsto vlakno i narkotičke droge.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13517080-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'monadna operacija,unarna operacija',
#    'Definicija': 'operacija s tačno jednim operandom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07804323-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pirinač,riža',
#    'Definicija': 'Zrnevlje koje se koristi kao hrana; može da bude obrađen i neobrađen.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09566320-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Kaliopa',
#    'Definicija': 'u grčkoj mitologiji Muza epske poezije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05568104-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'femoralni nerv,Nervus femoralis',
#    'Definicija': 'jedan od para nerava koji potiču iz lumbalnih nerava i  inervišu mišiće i kožu prednjeg dela butine.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15006789-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sintetička guma',
#    'Definicija': 'sintetička elastična materija čije osobine liče na prirodnu gumu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15145586-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'detinjstvo,najranije detinjstvo,rano detinjstvo',
#    'Definicija': 'Rana faza rasta ili razvoja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01654957-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Gymnophiona,red Gymnophiona,beznošci,beznogi vodozemci',
#    'Definicija': 'Rod vodozemaca koji uključuje ceciliju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02259829-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cenjkati se',
#    'Definicija': 'pregovarati o uslovima razmene',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06639674-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'indeks,indeksni broj,indikator,pokazatelj',
#    'Definicija': 'broj ili odnos (vrednost na skali) izveden iz niza posmatranih činjenica; može otkriti relativne promene kao funkciju vremena',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01685439-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'teju-gušter',
#    'Definicija': 'Tropskigušter iz Novog sveta sa dugim repom i velikim pravougaonim krljuštima na stomaku i dugačkom repu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00467719-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'igra na igralištu',
#    'Definicija': 'Igra na otvorenom koja se igra na polju određenih dimenzija',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13636135-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'milifarad',
#    'Definicija': 'jedinica za kapacitet koja je jedanka hiljaditom delu jednog farada',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00211110-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'završna akcija',
#    'Definicija': 'Završna akcija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12826516-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': '?morning glory',
#    'Definicija': 'Jedna od mnogih penjačica uvijuša koje imaju cvetove levkastog oblika koji se zatvaraju krajem dana.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02300554-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dudov prelac,svilena buba,Bombyx mori',
#    'Definicija': 'Azijska buba koja proizvodi svilu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02197781-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naći,opaziti,otkriti,otkrivati,pronaći',
#    'Definicija': 'smatrati da ste u određenom stanju ili na određenom mestu',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07759424-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'muskadin grožđe',
#    'Definicija': 'zagasito ljubičasto grožđe sa juga Sjedinjenih država',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11952900-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Cichorium,rod Cichorium',
#    'Definicija': 'Cikorija',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02401809-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izbaciti,isterati,smeniti',
#    'Definicija': 'ukloniti nekoga sa položaja ili iz službe',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03069643-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gotički,gotski',
#    'Definicija': 'koji se odnosi na jezik drevnih Gota',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02045024-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Alcidae,porodica Alcidae',
#    'Definicija': 'morske ptice ronilice severnih mora: morski papagaj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06873252-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vizuelna komunikacija',
#    'Definicija': 'komunikacija koja se zasniva na vidu (?)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05607126-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kruna,corona',
#    'Definicija': 'u anatomiji struktura koja ima oblik krune',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01951480-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'upraviti,usmeriti,poslati',
#    'Definicija': 'uzrokovati da nešto negde ode',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08333030-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Inkvizicija',
#    'Definicija': 'nekadašnji tribunal Rimske katoličke crkve (1232-1820) stovren da otkrije i spreči heretičko ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08849549-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Flandrija,Flamanija',
#    'Definicija': 'srednjevekovna država na severu Evrope koja je uključivala delove sadašnje Francuske, Belgije i Holandije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03031152-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'muštikla',
#    'Definicija': 'Cev koja drži cigaretu za vreme pušenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13331198-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'suma novca',
#    'Definicija': 'Količina novca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04539876-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nestalna memorija',
#    'Definicija': 'računarska memorija čiji se sadržaj briše kada se isključi struja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00693399-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'traheotomija',
#    'Definicija': 'operativni zahvat razrezivanja dušnika da bi se uvela kanila i omogućilo disanje kod opasnosti od gušenja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07867616-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fondi od sira',
#    'Definicija': 'fondi napravljen od sira topljenog u vinu za umakanje hlaba i ponekad voća',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00227264-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'strangulacija,gušenje,zagušenje,strangulatio',
#    'Definicija': 'Konstrikcija dela tela čime je onemogućen protok krvi ili drugih telesnih tečnosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01904182-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'školjka',
#    'Definicija': 'Čvrsti uglavnom krečni oklop mekušca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00266806-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'popravka,reparacija',
#    'Definicija': 'Čin dovođenja stvari ponovo u red.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05431926-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zigot,oplođena jajna ćelija',
#    'Definicija': 'ćelija koja je nastala spajanjem jajne ćelije i spermatozoida (uključujući organizam koji se razvija iz te ćelije)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02268443-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vilinski konjic',
#    'Definicija': 'Krupni insekti iz grupe prakrilaca, uzana tela, snažnih i prozračnih krila i odličnog leta; velike grabljivice koje svoj plen hvatajuu letu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09218044-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bedrok,stene osnove',
#    'Definicija': 'Izraz koji je nastao sredinom XIX veka i oznacavao je cvrstu stenu koja leži ispod nanosa. Pojam se tokom vremena proširio na cvrstu stenu uopšte, koja se nalazi bilo ispod nanosa bilo ispod rastresitog pokrivača.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02551316-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Scomberesocidae,porodica Scomberesocidae,Scombresocidae,porodica Scombresocidae',
#    'Definicija': 'poletuše',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00993892-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kodirati,šifrovati,kriptirati,inskribirati',
#    'Definicija': 'pretvarati običan jezik u kod',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07765361-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'guava',
#    'Definicija': 'tropsko voće sa žutom korom i roze pulpom; jede se sveže ili se pravi džem',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01421622-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ubaciti,umetnuti,staviti',
#    'Definicija': 'Staviti ili ubaciti u nešto.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01124246-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'autoritet,dozvola,moć,odgovornost,ovlašćenje',
#    'Definicija': 'mehanizam društvene kontrole za sprovođenje društvenih standarda',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07644382-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ptičje meso',
#    'Definicija': 'Meso divlje ili domaće ptice koje se koristi kao hrana.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10235549-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rođak ili svojta',
#    'Definicija': 'osoba u srodstvu po krvi ili braku',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13590327-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gravitaciona konstanta',
#    'Definicija': 'u fizici univerzalna konstanta koja povezuje silu sa masom i rastojanjem u Njutnovom zakonu gravitacije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12147835-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trskovača,bambus,Bambusa vulgaris,trskovac',
#    'Definicija': 'vrsta tropske trske',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08817630-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Bosna i Hercegovina,Republika Bosna i Hercegovina,Bosna',
#    'Definicija': 'Planinska republika u južnoj Evropi; ranije deo Otomanskog carstva i deo Jugoslavije; stekla nezavisnost',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01030488-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': '?popery',
#    'Definicija': 'Uvredljiv izraz za običaje i rituale Rimske katoličke crkve',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00593944-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sudijska funkcija',
#    'Definicija': 'položaj sudije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02084071-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pas,pseto,domaći pas',
#    'Definicija': 'Pripadnik Canis familiaris, srodan vuku, pripitomljen od preistorijskog doba; postoje mnoge rase.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13824815-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'količnik',
#    'Definicija': 'odnos dva broja koji se dele',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12929783-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čajevac,Camellia sinensis',
#    'Definicija': 'Najrasprostranjenija vrsta čaja; tropski zimzeleni žbun ili nisko drvo koje se intenzivno gaji u Kini, Japanu i Indiji; korsiti se lišće za čaj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10249459-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'organ reda,službenik bezbednosti,milicioner',
#    'Definicija': 'zaštitnik zakona',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05400860-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'krvna grupa A',
#    'Definicija': 'krvna grupa čija crvena krvna zrnca nose A antigen.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06939431-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'javanski',
#    'Definicija': 'indonezijski jezik kojim se govori na Javi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01582398-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dugorepa svraka,Pica pica,Pica caudata',
#    'Definicija': 'obična evropska svraka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08798195-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Jafa',
#    'Definicija': 'luka u zapadnom Izraelu na Sredozemnom moru, uključena u Tel Aviv 1950.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07681355-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hleb sa kimom',
#    'Definicija': 'Hleb koji sadrži kim.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12939874-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'popanak,paponjak,šapika,medveđi dlan,mečja šapa,blatarica,Heracleum sphondžlium',
#    'Definicija': 'Visoka krupna biljka sa debelom stabljikom i grozdovima belih i ljubičastih cvetova.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02014941-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'liska',
#    'Definicija': 'Neka od brojnih široko rasprostranjenih malih ptica gacalica iz porodice Rallidae koje imaju kratka krila i vrlo dugačke prste na nogama za trčanje po mekom blatu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13289159-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'udeo,deo',
#    'Definicija': 'udeo u profitu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07814487-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'karanfilić,klinčić',
#    'Definicija': 'Začin koji se dobija od malog osušenog pupoljka tropskog zimzelenog drveta biljke karanfilić.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02767308-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'emitovati,emitirati',
#    'Definicija': 'vršiti emisiju (npr. zraka)',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02317661-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lišavati,lišiti,osiromašiti,osiromašivati',
#    'Definicija': 'učiniti siromašnm',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-15040493-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'silikon',
#    'Definicija': 'pripada velikoj klasi siloksana koji su obično stabilni na različitim temperaturama',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00931608-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uređivanje,priređivanje',
#    'Definicija': 'čin stavljanja nečega u pisani oblik',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05528060-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'respiratorni organ,organ za disanje',
#    'Definicija': 'Svaki organ koji je uključen u disanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06218162-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'federalizam',
#    'Definicija': 'ideja o federalnoj organizaciji više ili manje samoupravnih jedinica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02016062-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izaći,izlaziti,sići,silaziti',
#    'Definicija': 'ostaviti vozilo, avion itd.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-12288598-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Corylus,rod Corylus',
#    'Definicija': 'Listopadno ?monoecious grmlje ili malo drveće koje ima koštuničav plod: leska; ponekad se smešta u podporodicu ili porodicu Corylaceae.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11291284-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Segovia,Andres Segovia',
#    'Definicija': 'Španski gitarista koji je klasičnu gitaru učinio koncertnim instrumentom (1893-1987).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02969375-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'salvadorski',
#    'Definicija': 'koji se tiče El Salvadora',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02047835-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Fratercula,rod Fratercula',
#    'Definicija': 'morski papagaj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13937075-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slika,scena',
#    'Definicija': 'situacija koja se tretira kao osmotriv predmet',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01418789-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bukvalan',
#    'Definicija': 'koji je ograničen na eksplicitno značenje reči ili teksta',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-03897943-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zakrpa,krpa',
#    'Definicija': 'komad tkanine koji se koristi za ukras ili da zakrpi ili pokrije rupu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13968859-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poredak,državno uređenje,vladavina',
#    'Definicija': 'Oblik upravljanja društvenom organizcijom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07727868-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'boranija',
#    'Definicija': 'Nezrela mahuna pasulja koja se jede kao povrće.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02357741-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Citellus,rod Citellus,Spermophilus,rod Spermophilus',
#    'Definicija': 'tipične zemaljske veverice.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07870620-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Njuburg škampi',
#    'Definicija': 'škampi u Njuburg sosu posluženi u krugu od pirinča',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03586090-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'daska za peglanje',
#    'Definicija': 'Uska postavljena ploča na preklopnim osloncima; koristi se za peglanje odeće.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02973540-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tragikomičan',
#    'Definicija': 'o tragikomediji, koji se odnosi na tragikomediju ili je karakterističan za tragikomediju',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02326432-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zec',
#    'Definicija': 'Brz, plašlji sisar dugačkih ušiju, veći od kunića; ima rascepljenu gornju usnu i dugačke zadnje noge; mladunci se rađaju sa krznom i otvorenih očiju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03600806-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cigara,cigareta,džoint',
#    'Definicija': 'listovi marihuana uvaljane u cigaretu za pušenje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08906952-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tibet',
#    'Definicija': 'Autonomna oblast na jugozapadu Kine (oblast Himalaja)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09557770-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Haos',
#    'Definicija': 'najstariji bog; predstavlja beskonačnost prostora koji je prethodio nastanku sveta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04442312-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'toster',
#    'Definicija': 'kućni aparat, obično električni, za tostiranje hleba',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11708442-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Illicium,rod Illicium',
#    'Definicija': 'Zimzeleno drvo sa aromatičnim lišćem.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11883945-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'žličnjak,kašičak,trava od poljačine,Cochlearia officinalis',
#    'Definicija': 'Vrlo rasprostranjen arktički dragušac za koga se veruje da veči ili sprečava skorbut; izvor koncentrovanog vitamina C.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00363110-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ostaviti se,okaniti se',
#    'Definicija': 'prekinuti sa nekom radnjom, na primer',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08758172-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Austerlic,Osterlic,Slavkov u Brno',
#    'Definicija': 'grad u Češkoj republici, mesto čuvene bitke iy 1805',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01916634-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'šepiriti se,šepuriti se,kerebečiti se,prsiti se,razmetati se',
#    'Definicija': 'Hodati gordo, često pokušavajući da se impresioniraju drugi.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06013126-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'linearna algebra',
#    'Definicija': 'deo algebre koji se bavi teorijom linearnih jednačina i lineranim transformacijama',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01875313-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oposum,Didelphis virginiana,Didelphis marsupialis',
#    'Definicija': 'Svaštojed; živi po sumama i šibljacima; vere se i penje po drveću; veoma mu je razvijeno čulo mirisa; živi u Severnoj Americi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08779375-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Suva,prestonica Fidžija,glavni grad Fidžija',
#    'Definicija': 'glavni i najveći grad Fidžija; na ostrvu Viti Levu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13511507-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Markovljev proces',
#    'Definicija': 'jednostavan stohastički proces u kome distribucija budućih stanja zavisi samo od trenutnog stanja a ne i od toga kako se stiglo u trenutno stanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11984542-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oman',
#    'Definicija': 'Bilo koja biljka iz roda Inula.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09810867-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'likovni kritičar',
#    'Definicija': 'Kritičar koji se bavi kritikom dela likovne umetnosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07391863-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zvonjava,zvonjenje',
#    'Definicija': 'Zvuk zvona koje zvoni.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05850624-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'aspekt,vid,strana',
#    'Definicija': 'Određena karakteristika ili element u problemu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06938623-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fidži,fidžijski',
#    'Definicija': 'okeanijski jezik kojim se govori na Fidžiju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09457020-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Temza',
#    'Definicija': 'najduža engleska reka, plovi na istok, kroz London ka Severnom moru',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11492014-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'polarizacija',
#    'Definicija': 'Pojava pri kojoj se talasi svetlosti ili drugog zračenja ograničavaju u smeru vibracija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04293119-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cediljka',
#    'Definicija': 'kuhinjska sprava za ceđenje soka iz voća',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06413579-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'knjiga',
#    'Definicija': 'obično velika i učena knjiga',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13581218-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'relativna većina',
#    'Definicija': 'Na izborima sa više od 2 opcije, broj glasova za kandidata ili partiju koja je dobila najviše (ali manje od polovine) glasova.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02732798-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'primiti,primati',
#    'Definicija': 'imati prostora za nešto, obuhvatiti u svoj prostor',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06923182-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mohave',
#    'Definicija': 'jumanski jezik kojim govori narod Mohave',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00219856-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'eutanazija',
#    'Definicija': 'čin bezbolnog ubijanja nekoga (posebno nekoga ko pati od neizlečive bolesti)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02365848-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Dasyprocta,rod Dasyprocta',
#    'Definicija': 'Tipski rod porodice Dasyproctidae: aguti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07875267-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rijstafel',
#    'Definicija': 'jelo iz Indonezije; raznolika hrana i sosevi se služe sa pirinčem',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03676759-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zaslon od tečnih kristala,zaslon s tečnim kristalom,LCD',
#    'Definicija': 'zaslon koji koristi tečne kristale koji menjaju refleksivnost u električnom polju; koristi se za digitalne časovnike i prenosive računare',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02260035-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čvrst',
#    'Definicija': 'Definisanog oblika i zapremine; nije ni tečan ni gasovit.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01326291-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mikroorganizam,mikrob',
#    'Definicija': 'Organizam mikroskopske veličine.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10126708-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'biološki roditelj',
#    'Definicija': 'prirodni otac ili majka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00501820-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nem,ćutljiv,mučaljiv,mučljiv',
#    'Definicija': 'onaj koji odbija da govori ili komunicira kada se to od njega očekuje;',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-08256968-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'partija,stranka',
#    'Definicija': 'Organizacija čiji je cilj pribavljanje političke moći.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07587618-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kukuruzna čorba',
#    'Definicija': 'čorba sa kukuruzom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07657664-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ravan deo mesa',
#    'Definicija': 'tanak deo sa prednje četvrti životinje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07995453-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jato',
#    'Definicija': 'Velika grupa riba',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11630890-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'drvo čempresa',
#    'Definicija': 'Drvo nekog drveta iz roda Cupressus.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11894327-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rotkva',
#    'Definicija': 'Krstašica iz roda Raphanus sa zadebljalim jestivim korenom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01111750-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uvoz',
#    'Definicija': 'komercijalna delatnost kupovine i uvoza robe iz koje inostrane zemlje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13609214-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jedinica za masu',
#    'Definicija': 'Jedinica mere za masu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13498828-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'inflacija',
#    'Definicija': 'Opšti progresivan rast cena.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13724838-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kilo',
#    'Definicija': 'Kilogram narkotičke droge.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09455046-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tasmanovo more',
#    'Definicija': 'deo južnog Tihog okeana između jugoistočne Australije i Novog Zelanda',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02578894-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'manastirski,samostanski',
#    'Definicija': 'za život u zajednici odvojenoj od sveta koja se ponaša po verskim načelima',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-12702706-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Oxalis',
#    'Definicija': 'Tipski rod porodice Oxalidaceae; veliki rod biljaka čije lišće podseća na detelinu, cveće može biti raznih boja, obično je u grozdovima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07576182-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bife,švedski sto',
#    'Definicija': 'obrok na bazi švedskog stola gde se gosti sami služe',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09297423-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Botnički zaliv',
#    'Definicija': 'severni rukavac Baltičkog mora, između Švedske i Finske',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00962722-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'revolucija',
#    'Definicija': 'Svrgavanje vlade od strane podanika.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02323186-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Lagomorpha,red Lagomorpha,dvojezupci',
#    'Definicija': 'Zečevi; kunići i ?pikas; ranije su se smatrali podredom Duplicidentata reda Rodentia.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03483316-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fen za kosu',
#    'Definicija': 'električni fen koji se drži u ruci a služi za sušenje kose i stiliozvanje frizure',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03739518-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bolnica,dom zdravlja,klinika',
#    'Definicija': 'zgrade u kojoj se ljudi bave medicinom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05798043-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'eksperiment,eksperimentisanje,opit,pokus',
#    'Definicija': 'testiranje ideje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07779263-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bufalo riba',
#    'Definicija': 'dugačka riba koja liči na šarana; pronalazi se u Severnoj Americi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02501275-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tarsiidae,porodica Tarsiidae',
#    'Definicija': 'Poklapa se sa rodom Tarsius: aveti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04404200-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'teleprinter,teleks',
#    'Definicija': 'Serijski štampač zakačen za telegraf koji funkcioniše kao pisača mašina.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08305942-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'saveznik',
#    'Definicija': 'Prijateljska država.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09493204-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Kerber',
#    'Definicija': 'u grčkoj mitologiji troglavi pas koji čuva ulaz u Had; Tifonov sin',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03392741-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mašina za frankiranje',
#    'Definicija': 'mašina koja automatski pečati pisma i pakete koji prolaze kroz nju i izračnava ukupno zaduženje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02332755-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poljski miš',
#    'Definicija': 'Noćni miš iz starog sveta iz roda Apodemus živi u šumama, poljima i baštama.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10164492-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'glavna sestra',
#    'Definicija': 'Žena koja je zadužena za negu i lečenje u medicinskoj ustanovi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00196084-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prebacivanje',
#    'Definicija': 'čin promene jedne stvari ili pozicije na drugu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01981702-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'morski pauk,rakovica',
#    'Definicija': 'Neki od brojnih rakova sa vrlo dugim nogama i mali trouglastim telom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02433925-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'irvas,sob,severni jelen,karibu,Rangifer tarandus',
#    'Definicija': 'Arktički jelen sa velikim rogovima kod oba pola.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05546298-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kotlet',
#    'Definicija': 'mali odrezak mesa koji uključuje deo rebra',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06834885-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'teta',
#    'Definicija': 'osmo slovo grčkog alfabeta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02776505-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čoja',
#    'Definicija': 'svetlo zelena tkanina koja nalikuje na filc, a koristi se za prekrivanje stolova za igru',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04892084-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'visprenost,pronicljivost',
#    'Definicija': 'Sposobnost da se vispreno procene situacije ili okolnosti i da se izvuku čvrsti zaključci.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11738547-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kozlačica',
#    'Definicija': 'Neka od mnogih trava iz roda Thalictrum; imaju čipkasto lišće i oblake malih purpurnih ili žutih cvetova.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14923458-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gvozdena ruda,ruda gvožđa',
#    'Definicija': 'ruda iz koje se vadi gvožđe',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09569467-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Persefona',
#    'Definicija': 'u grčkoj mitologiji ćerka Zevsa i Demetre; po drvenoj mitologiji Pluton ju je učinio kraljicom podzemnog sveta; u Rimskoj mitologiji joj odgovara Prozerpina',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02285629-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naći',
#    'Definicija': 'pronaći nečiju lokaciju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03709206-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lupa,mikroskop,povećalo',
#    'Definicija': 'naučni instrument koji uvećava sliku',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12356023-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'đumbir,Zingiber officinale',
#    'Definicija': 'Tropska azijska biljka koja se gaji zbog reskog korena; od njega se pravi džumbir u prahu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02611373-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pretrpeti,dobiti',
#    'Definicija': 'Biti u nekom određenom stanju ili uslovima',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08296059-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'generalna skupština',
#    'Definicija': 'vrhovna savetodavna skupština Ujedinjenih nacija',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15125097-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tercijar,tercijer',
#    'Definicija': 'treći period u razvoju zemlje, starija formacija kenozojskog doba',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08730895-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tajpej,glavni grad Tajvana,prestonica Tajvana',
#    'Definicija': 'glavni grad Tajvana',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04395875-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gostionica,krčma,kavana,kafana',
#    'Definicija': 'Zgrada u kojoj je bar koji ima dozvolu da služi alkoholna pića.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07648913-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bufalo pileća krilca',
#    'Definicija': 'hrskava, začinjena pileća krilca',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07866571-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jaja fu jong',
#    'Definicija': 'omlet sa lukom, celerom i seckanim mesom ili ribom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02006573-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'doći,dolaziti,prispeti,stići,stignuti,ukrcati se,ukrcavati se',
#    'Definicija': 'stići kamo i ukrcati se',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-12950501-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Valerianella,rod Valerianella',
#    'Definicija': 'Rod široko rapsrostranjenih zeljastih biljaka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12387201-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Violaceae,porodica Violaceae,ljubičice',
#    'Definicija': 'Porodica iz reda Parietales koja uključuje rodove Viola; Hybanthus; Hymenanthera; Meličtus.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03003928-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'avganistanski',
#    'Definicija': 'koji se odnosi ili je karakterističan za Avganistan',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01664172-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kuvati,spremiti,zgotoviti',
#    'Definicija': 'Spremti za jelo podvrgavajući toploti.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01956764-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'morska školjka',
#    'Definicija': 'Skoljka morskog organizma.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01235859-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uspravan,vertikalan,okomit',
#    'Definicija': 'Čija je pozicija ili položaj uspravan.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04405907-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'televizor,TV aparat,televizijski aparat,mali ekran',
#    'Definicija': 'Prijemnik koji prikazuje televizijske slike.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02069888-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'isteći,isticati,prosipati se,prosuti se,razliti se,razlivati se',
#    'Definicija': 'teći, proticati, isticati ili se gubiti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-09163192-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Vijetnam,Socijalistička Republika Vijetnam',
# ...
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Vezuv',
#    'Definicija': 'vulkan na jugoistoku Italije na obali Sredozemnog mora; erupcija iz 79 god. p.n.e. je unišitla Pompeju i ubila Plinija Starijeg; poslednja erupcija 1944',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12163035-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bljuštac',
#    'Definicija': 'Penjačica iz roda genus Bryonia koja ima veliko lišće i male cvetiće; daje sok ima purgativna svojstva.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04247736-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'snek-bar,bife',
#    'Definicija': 'bar koji obično nije skup',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04096066-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'put,cesta',
#    'Definicija': 'Obično javni put za putovanje ili transport.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00262743-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kićenje',
#    'Definicija': 'Čin dodavanja spoljašnjih ukrasa na nešto.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01539377-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Passeridae,familija Passeridae',
#    'Definicija': 'Pravi vrapci; ptice iz starog sveta koje su nekad smatrane ?weaverbirds.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04105893-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prostorija',
#    'Definicija': 'Zona u zgradi koja je okružena zidovima, podom i plafonom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03171356-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bedem,linija odbrane',
#    'Definicija': 'struktura koja se koristi za odbranu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11972569-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Gnaphalium,rod Gnaphalium',
#    'Definicija': 'Veliki rasprostranjen rod krupnih dlakavih trava sa belim?',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01382083-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'brati,sakupljati',
#    'Definicija': 'Tražiti i sakupljati.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14678230-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'barit,barijum sulfat',
#    'Definicija': 'beli ili bezbojni mineral (BaSO4); glavni izvor barijuma',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00661091-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'terapija',
#    'Definicija': 'Čin brige o nekome, lekovima ili medicinskim tretmanom (u medicini).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00994895-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'transkribovati',
#    'Definicija': 'napraviti fonetsku transkripciju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01030372-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grgurav',
#    'Definicija': '(o kosi) koji ima sitne čvrste uvojke',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-06990371-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'koptski',
#    'Definicija': 'liturgijski jezik koptske crkve koji se koristi u Egiptu i Etiopiji; piše se grčkim alfabetom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09249034-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanac',
#    'Definicija': 'prolaz između planinskih vrhova',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09473239-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Volga',
#    'Definicija': 'ruska reke, najduža reka u Evropi, uliva se u Kaspijsko more',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09593144-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Penelopa',
#    'Definicija': 'u grčkoj mitologiji Odisejeva žena i simbol odanosti i vernosti; tokom deset godina dok se Odisej borio u Trojanskom ratu ona je odolevala mnogim proscima sve dok se (posle još 10 godina) Odisej nije vratio i sve ih ubio',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09733899-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tajvanac',
#    'Definicija': 'stanovnik Tajvana ili poreklom s Tajvana',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06577369-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'parser,raščlanjivač',
#    'Definicija': 'računarski program koji raščlanjuje kod u funkcionalne komponente',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12640607-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kajsija',
#    'Definicija': 'Azijsko drvo koje ima grozdove obično belih cvetova i jestiv plod koji liči na breskvu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00855527-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'autoeroticizam,autoerotizam',
#    'Definicija': 'korišćenje sopstvenog tela u svojstvu seksualnog objekta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07820960-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'baštenski vresak,morski vresak,šetrajka',
#    'Definicija': 'Zeljasta biljka čiji listovi imaju delikatan miris i razne primene.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07834160-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'italijanski preliv,italijanski preliv za salatu',
#    'Definicija': 'preliv sa sirćetom, uljem, belim lukom i začinskim biljem: origano, bosiljak i mirođija',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07932323-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kasiri',
#    'Definicija': 'piće slično pivu; napravljeno od fermentisanog soka manioke',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13697011-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'novčana jedinica Omana,omanska novčana jedinica Omana',
#    'Definicija': 'novčana jedinica Omana',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02817031-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ležište',
#    'Definicija': 'podupirač koji se postavlja između pokretnih delova da bi im omogućilo lakše kretanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00665886-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'potvrditi',
#    'Definicija': 'Utvrditi ili potkrepiti novim dokazima ili činjenicama.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01920048-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pohraniti',
#    'Definicija': 'smestiti u datoteku',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00931040-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fikcionalizacija,fikcionaliziranje',
#    'Definicija': 'pisanje u formi fikcije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03096439-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kontrafagot',
#    'Definicija': 'Drveni duvački instrument, sličan fagotu, samo je od njega veći i zvuči za oktavu nize.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06927486-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ujgurski',
#    'Definicija': 'turkijski jezik kojim govori otprilike 7.000.000 Ujgura na krajnjem severozapadu Kine',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11669921-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ukrasni cvet',
#    'Definicija': 'Biljka koja se gaji zbog cveta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02432682-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'umoran od svega,smoren',
#    'Definicija': 'koji je umoran od sveta i života',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07788885-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jastog',
#    'Definicija': 'vrsta malog raka koji se obično kratko kuva',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08836165-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Australazija',
#    'Definicija': 'Australija, Novi Zeland i susedna ostrva Južnog Pacifika',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08459648-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'niz,sled,lanac',
#    'Definicija': 'uzastopno poređan skup stvari ili događaja ili ideja u kome je svaki naredni član povezan sa prethodnim',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06671150-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'simultane jednačine',
#    'Definicija': 'skup jednačina dve ili više promenljivih za koje postoje vrednosti koje zadovoljavaju sve jednačine istovremeno',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13742011-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'značajna cifra,značeća cifra',
#    'Definicija': 'cifra u broju za koju se pouzdano zna da je tačna',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04916342-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'svojstvo',
#    'Definicija': 'Osnovni ili suštinski atribut koji dele svi članovi klase.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03172965-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'linija za kašnjenje',
#    'Definicija': 'električno kolo koje je tako napravljeno da uvede proračunato kašnjenje u prenos signala',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13349395-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jemstvo,jamstvo,zalog',
#    'Definicija': 'Imovina koju nečiji poverilac može da tržži u slučaju da ne ispunite obavezu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00271419-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fluorescentan',
#    'Definicija': 'onaj koji emituje svetlost nakon izlaganja zračenju iz spoljnog izvora',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01424782-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'haemoproteid',
#    'Definicija': 'povezani su sa parazitima malarije i imaju fazu u razvoju koja se odvija u visceralnim (unutrašnjim) organima ptica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00786195-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nastojanje,pregnuće,pokušaj',
#    'Definicija': 'Ozbiljna i svesna aktivnost s ciljem da se nešto postigne.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01646134-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Bufo',
#    'Definicija': 'Tipski rod porodice Bufonidae; obične krastače iz novog i starog sveta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09567309-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Uranija',
#    'Definicija': 'u grčkoj mitologiji Muza astronomije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04068441-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rafinerija',
#    'Definicija': 'Industrijski pogon za pročišćavanje sirove supstance.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07619508-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'voćni krem',
#    'Definicija': 'krem koji sadrži voće',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08213671-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'borbena jedinica',
#    'Definicija': 'Vojna jedinica koja se obično sastoji od pet četa.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02018795-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'droplja',
#    'Definicija': 'Velika ptica teškog tela, može brz da leti; smešta se među ptice gacalice, ali nastanjuje i travnate stepe.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14822563-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bakarna legura',
#    'Definicija': 'Bilo koja legura čija glavna komponenta je bakar.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01699059-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prepevati',
#    'Definicija': 'pisati nove reči za (pesmu)',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-13887509-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ugao',
#    'Definicija': 'Prostor između dva pve ili ravni koje se seku; nagib prave prema drugoj pravoj; meri se stepenima ili radijanima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11686195-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cataphyll',
#    'Definicija': "a reduced or scarcely developed leaf at the start of a plant's life (i.e., cotyledons) or in the early stages of leaf development",
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08959254-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Liberija,Republika Liberija',
#    'Definicija': 'LR',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06127209-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'genetičko inženjerstvo,genetsko inženjerstvo,spajanje gena,rekombinantna DNK tehnologija',
#    'Definicija': 'tehnologija pripremanja rekombinantne DNK in vitro isecanjem DNK molekula i spajanjem fragmenata dobijenih iz više od jednog organizma',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01309109-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tridesetogodišnji rat',
#    'Definicija': 'niz konlikata (1618-1648) između protestanata i kataloika koji je počeo u Nemačkoj a dalje se širio sve dok Fracuska, Danska i Švedska nisu ustale protiv Svetog Rimskog Carstva i Španije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04536866-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'violina',
#    'Definicija': 'Gudački žičani instrument, razvio se iz viole; ima četiri žice, šuplji korpus i hvataljku bez prečnica za odredženi ton; svira se uz pomoć gudala.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06261922-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hipermedija,hipermediji,interaktivna multimedija',
#    'Definicija': 'multimedijalni sistem u kojem su srodni elementi informacija povezani i mogu se predstaviti zajedno',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05728678-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'plan,dizajn',
#    'Definicija': 'Šema ustrojstva.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01375460-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Actinomycetaceae,porodica Actinomycetaceae',
#    'Definicija': 'filamentozne anaerobne bakterije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01119169-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'napasti,navaliti na koga,nasrnuti,navaliti',
#    'Definicija': 'Pokrenuti napad ili uvredu na nekoga; početi sa neprijateljstvom, kao u slučaju rata.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-11803475-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Caryophyllidae,podklasa Caryophyllidae',
#    'Definicija': 'Grupa familija, uglavnom cveće koje ima ???; sadrži 14 familija uključujući: Caryophyllaceae (karanfil i ?pinks); Aizoaceae; Amaranthaceae; Batidaceae; Chenopodiaceae; Cactaceae (red Opuntiales); Nyctaginaceae; Phytolaccaceae; odgovara približno redu Caryophyllales; ponekad se klasifikuje kao nadred.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02537319-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pastrmka,pastrvka,pastrva,bistranga,Salmo trutta',
#    'Definicija': 'pegava pastrmka evropskih reka; preneta i u Severnu Ameriku',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08757926-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Prag,prestonica Češke,glavni grad Češke Republike',
#    'Definicija': 'Prestonica i najveći grad Češke Republike u zapadnom delu zemlje; kulturni i trgovački centar od 14. veka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04543772-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'točak vagona',
#    'Definicija': 'Točak na vagonu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05793554-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'osnova,temelj,fundament',
#    'Definicija': 'Osnovne pretpostavke koje leže ispod objašnjenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08431437-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'red',
#    'Definicija': 'Skup predmeta ili ljudi smeštenih jedno do drugog u nizu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02206856-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pčela',
#    'Definicija': 'bilo koji od brojnih dlakavih insekata uključujući i društvene i osamljene vrste',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02370360-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vime',
#    'Definicija': 'mlečna žlezda kod govečeta (krave, ovce i koze)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06320153-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zajednička imenica',
#    'Definicija': 'a noun that denotes any or all members of a class',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00812274-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hvatanje,stezanje,uzimanje',
#    'Definicija': 'čin kada se šta rukama čvrsto stegne',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05385534-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jetra,Hepar',
#    'Definicija': 'Veliki i komplikovan crvenkasto-braon žlezdani organkoji se  nalazi u gornjem desnom delu trbušne duplje. Luči žuč i ima funkcije u metabolizmu proteina,ugljenih hidrata i masti. Sintetiše supstance uključene u zgrušavanje krvi, vitamin A, detoksifikuje otrovne supstance i razgrađuje  eritrocita koji su nefunkcionalni.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09577004-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Temida',
#    'Definicija': 'u grčkoj mitlogiji titanka koja je bila boginja pravde',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01038147-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'polivanje',
#    'Definicija': 'čin krštavanja polivanjem vode po glavi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15210870-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mart,ožujak',
#    'Definicija': 'Mesec koji dolazi posle februara a pre aprila u kalendaru.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04404412-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mali ekran,televizija,televizijski aparat,televizor,TV aparat,video',
#    'Definicija': 'telekomunikacioni sistem koji prenosi slike objekata (mirujućih ili pokretnih) između udaljenih tačaka',
#    'Vrsta': 'n'},
#   ...],
#  'iteration': 0}

# %%
df_OBJ2 = pd.DataFrame(defi2["OBJ"])

# %%
df_OBJ2
# Out:
#                      ID  POS  NEG  \
# 0      ENG30-02769463-a  0.0  0.0
# 1      ENG30-06616806-n  0.0  0.0
# 2      ENG30-14865221-n  0.0  0.0
# 3      ENG30-13524399-n  0.0  0.0
# 4      ENG30-01127795-v  0.0  0.0
# ...                 ...  ...  ...
# 19502  ENG30-14677314-n  0.0  0.0
# 19503  ENG30-02707889-a  0.0  0.0
# 19504  ENG30-01243453-n  0.0  0.0
# 19505  ENG30-02972925-a  0.0  0.0
# 19506  ENG30-05827684-n  0.0  0.0
#
#                                              Lemme  \
# 0                          nominativni,subjektivni
# 1                                dokumentarni film
# 2                                         Ortoklas
# 3                           brisanje,izostavljanje
# 4                                       braniti se
# ...                                            ...
# 19502                                        getit
# 19503                                      bakarni
# 19504                           izuzeće,izuzimanje
# 19505                                    izraelski
# 19506  podstrek,podsticaj,stimulans,stimulus,input
#
#                                               Definicija Vrsta
# 0      koji je u fleksivnom obliku kojim se tipično i...     a
# 1      Film ili TV program koji predstavlja činjenice...     n
# 2                 beli ili obojeni monoklinični feldspar     n
# 3      bilo koji proces koji čini da se zvuci ne izgo...     n
# 4      Biti u odbrambenom položaju; delovati protiv n...     v
# ...                                                  ...   ...
# 19502  mineral hemijske formule α-FeO(OH), stabilan p...     n
# 19503       koji je napravljen od bakra ili sadrži bakar     a
# 19504  odbijanje čoveka da se podvrgne ustanovljenom ...     n
# 19505     koji se tiče Izraela, njegovih ljudi i kulture     a
# 19506  bilo koji podsticajan podatak ili događaj; del...     n
#
# [19507 rows x 6 columns]

# %%
Synset_Sentiment_set_2.removeSynIDs(rem_obj)
defi3 = Synset_Sentiment_set_2.getDef()
df_OBJ3 = pd.DataFrame(defi3["OBJ"])

# %%
df_OBJ3
# Out:
#                      ID  POS  NEG  \
# 0      ENG30-02769463-a  0.0  0.0
# 1      ENG30-06616806-n  0.0  0.0
# 2      ENG30-14865221-n  0.0  0.0
# 3      ENG30-13524399-n  0.0  0.0
# 4      ENG30-01127795-v  0.0  0.0
# ...                 ...  ...  ...
# 19483  ENG30-14677314-n  0.0  0.0
# 19484  ENG30-02707889-a  0.0  0.0
# 19485  ENG30-01243453-n  0.0  0.0
# 19486  ENG30-02972925-a  0.0  0.0
# 19487  ENG30-05827684-n  0.0  0.0
#
#                                              Lemme  \
# 0                          nominativni,subjektivni
# 1                                dokumentarni film
# 2                                         Ortoklas
# 3                           brisanje,izostavljanje
# 4                                       braniti se
# ...                                            ...
# 19483                                        getit
# 19484                                      bakarni
# 19485                           izuzeće,izuzimanje
# 19486                                    izraelski
# 19487  podstrek,podsticaj,stimulans,stimulus,input
#
#                                               Definicija Vrsta
# 0      koji je u fleksivnom obliku kojim se tipično i...     a
# 1      Film ili TV program koji predstavlja činjenice...     n
# 2                 beli ili obojeni monoklinični feldspar     n
# 3      bilo koji proces koji čini da se zvuci ne izgo...     n
# 4      Biti u odbrambenom položaju; delovati protiv n...     v
# ...                                                  ...   ...
# 19483  mineral hemijske formule α-FeO(OH), stabilan p...     n
# 19484       koji je napravljen od bakra ili sadrži bakar     a
# 19485  odbijanje čoveka da se podvrgne ustanovljenom ...     n
# 19486     koji se tiče Izraela, njegovih ljudi i kulture     a
# 19487  bilo koji podsticajan podatak ili događaj; del...     n
#
# [19488 rows x 6 columns]

# %%
df_OBJ3[df_OBJ3["ID"]=="ENG30-05528604-n"]
# Out:
# Empty DataFrame
# Columns: [ID, POS, NEG, Lemme, Definicija, Vrsta]
# Index: []

# %%
df_OBJ3['Vrsta'].value_counts()
# Out:
# n    16349
# v     2083
# a     1056
# Name: Vrsta, dtype: int64

# %%
positive_seed_IDS = ["ENG30-01828736-v",
                     "ENG30-13987905-n",
                     "ENG30-01777210-v",
                     "ENG30-13987423-n",
                     "ENG30-01128193-v",
                     "ENG30-02355596-v",
                     "ENG30-00271946-v",
                    ]

# %%
Synset_Sentiment_set_3 = PolaritySets(swordnet, 0)

# %%
negative_seed_IDS = ["ENG30-01510444-a",
                     "ENG30-01327301-v",
                     "ENG30-00735936-n",
                     "ENG30-00220956-a",
                     "ENG30-02463582-a",
                     "ENG30-01230387-a",
                     "ENG30-00193480-a",
                     "ENG30-00364881-a",
                     "ENG30-14213199-n",
                     "ENG30-01792567-v",
                     "ENG30-07427060-n",
                     "ENG30-14408086-n",
                     "ENG30-14365741-n",
                     "ENG30-02466111-a",
                     "ENG30-14204950-n",
                     "ENG30-10609960-n",
                     "ENG30-02319050-v",
                     "ENG30-02495038-v",
                     "ENG30-01153548-n",
                     "ENG30-00751944-n",
                    ]

# %%
Synset_Sentiment_set_3.addPOSIDall(positive_seed_IDS)
Synset_Sentiment_set_3.addNEGIDall(negative_seed_IDS)

# %%
defi4 = Synset_Sentiment_set_3.getDef()

# %%
df_POS4 = pd.DataFrame(defi4["POS"])
df_NEG4 = pd.DataFrame(defi4["NEG"])

# %%
df_POS4
# Out:
#                  ID  POS   NEG  \
# 0  ENG30-00271946-v  0.0  0.00
# 1  ENG30-01777210-v  1.0  0.00
# 2  ENG30-13987905-n  1.0  0.00
# 3  ENG30-02355596-v  0.0  0.00
# 4  ENG30-13987423-n  1.0  0.00
# 5  ENG30-01828736-v  1.0  0.00
# 6  ENG30-01128193-v  0.0  0.75
#
#                                                Lemme  \
# 0                        stabilizovati se,smiriti se
# 1                             dopadati se,sviđati se
# 2                  blaženstvo,sedmo nebo,deveto nebo
# 3  dobijati,dobiti,dostići,dostignuti,postići,pos...
# 4                                              sreća
# 5                                     voleti,uživati
# 6                                            štititi
#
#                                           Definicija Vrsta
# 0                   Postati stabilan ili stabilniji.     v
# 1         Nalaziti da je nešto zabavno ili prijatno.     v
# 2                             Stanje izuzetne sreće.     n
# 3                               postići bod ili cilj     v
# 4  Stanje pozitivnih osećanja, od zadovoljstva do...     n
# 5                   osećati zadovoljstvo zbog nečega     v
# 6  Zaklanjati od opasnosti, povrede, uništenja il...     v

# %%
swordnet.synsets("sreća")
# Out:
# [<SrbSynset ID:ENG30-11418460-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-11418460-n>]"
#          "Definition- nepoznata i nepredvidljiva prirodna pojava koja vodi do povoljnog ishoda"
#
#          ,
#  <SrbSynset ID:ENG30-14473222-n>
#          "Lemma - [<SrbLemma name:okolnosti synset:Synset: ID is ENG30-14473222-n>, <SrbLemma name:sudbina synset:Synset: ID is ENG30-14473222-n>, <SrbLemma name:sreća synset:Synset: ID is ENG30-14473222-n>]"
#          "Definition- Nečije opšte okolnosti ili uslovi u životu (uključujući sve što vam se dešava)."
#
#          ,
#  <SrbSynset ID:ENG30-11418138-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-11418138-n>]"
#          "Definition- Nepoznat i nepredvidiv fenomen koji uzrokuje da neki događaj ima jedan, a ne drugi, rezultat."
#
#          ,
#  <SrbSynset ID:ENG30-07526757-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-07526757-n>]"
#          "Definition- Osećanja proživljena kada je neko u zadovoljnom stanju."
#
#          ,
#  <SrbSynset ID:ENG30-13987423-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-13987423-n>]"
#          "Definition- Stanje pozitivnih osećanja, od zadovoljstva do jakog ushićenja."
#
#          ]

# %%
swordnet.synsets("voleti")
# Out:
# [<SrbSynset ID:ENG30-01775164-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01775164-v>]"
#          "Definition- Gajiti nežna osećanja prema nekome."
#
#          ,
#  <SrbSynset ID:ENG30-01824736-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01824736-v>, <SrbLemma name:želeti synset:Synset: ID is ENG30-01824736-v>]"
#          "Definition- Želeti nešto uraditi."
#
#          ,
#  <SrbSynset ID:ENG30-01824339-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01824339-v>]"
#          "Definition- nadati se nećemu, imati želju"
#
#          ,
#  <SrbSynset ID:ENG30-01775535-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01775535-v>]"
#          "Definition- biti zaljubljen ili u ljubavi s nekim"
#
#          ,
#  <SrbSynset ID:ENG30-01828736-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01828736-v>, <SrbLemma name:uživati synset:Synset: ID is ENG30-01828736-v>]"
#          "Definition- osećati zadovoljstvo zbog nečega"
#
#          ,
#  <SrbSynset ID:ENG30-01776952-v>
#          "Lemma - [<SrbLemma name:dopadati se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:dopasti se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:sviđati se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:svideti se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:voleti synset:Synset: ID is ENG30-01776952-v>]"
#          "Definition- voleti"
#
#          ]

# %%
df_NEG4
# Out:
#                   ID   POS      NEG  \
# 0   ENG30-01230387-a  0.00  0.37500
# 1   ENG30-00364881-a  0.00  0.62500
# 2   ENG30-02319050-v  0.00  0.00000
# 3   ENG30-01792567-v  0.00  0.37500
# 4   ENG30-01153548-n  0.00  0.00000
# 5   ENG30-02466111-a  0.00  0.00075
# 6   ENG30-14408086-n  0.00  0.25000
# 7   ENG30-14204950-n  0.75  0.12500
# 8   ENG30-00220956-a  0.00  0.37500
# 9   ENG30-01510444-a  0.25  0.25000
# 10  ENG30-02463582-a  0.00  0.62500
# 11  ENG30-00735936-n  0.00  0.62500
# 12  ENG30-07427060-n  0.00  0.50000
# 13  ENG30-02495038-v  0.00  0.00000
# 14  ENG30-01327301-v  0.00  0.50000
# 15  ENG30-14365741-n  0.00  0.12500
# 16  ENG30-00193480-a  0.00  0.62500
# 17  ENG30-14213199-n  0.00  0.62500
# 18  ENG30-10609960-n  0.00  0.00000
# 19  ENG30-00751944-n  0.00  0.00000
#
#                                                 Lemme  \
# 0                                          beznadežan
# 1                        deprimirajući,tmuran,sumoran
# 2   čerupati,drati,očerupati,odrati,opljačkati,tra...
# 3                                   nauditi,naškoditi
# 4                                      diskriminacija
# 5                                           nepouzdan
# 6                                   teškoća,neprilika
# 7                                          patologija
# 8                                               ružan
# 9                                         velik,težak
# 10                 ciničan,mizantropski,mizantropičan
# 11                                      nepristojnost
# 12                                        atrofiranje
# 13                            lišiti slobode,zatočiti
# 14                      likvidirati,ucmekati,skembati
# 15                                           atrofija
# 16                                        užasavajući
# 17                                muka,fizička patnja
# 18                                       gonič robova
# 19                                   izmišljotina,laž
#
#                                            Definicija Vrsta
# 0   koji je označen beznadežnošću ili ispoljava be...     a
# 1                            koji izaziva potištenost     a
# 2   koga odrati (po pitanju cene); za šta nerazumn...     v
# 3                          uzrokovati bol, unesrećiti     v
# 4   Nepravedno postupanje prema nekoj osobi ili gr...     n
# 5   onaj kojem se ne može ukazati poverenje, u kog...     a
# 6   Stanje stvari koje je skoro izvan nečije moguć...     n
# 7     svako odstupanje od zdravog ili normanog stanja     n
# 8       Koji je moralno odbojan ili neugodan za čula.     a
# 9                                Velika (glavobolja).     a
# 10  koji misli najgore o ljudskoj prirodi i motivi...     a
# 11                  nedolično ili nemoralno ponašanje     n
# 12  Slabljenje ili degeneracije, posebno usled nek...     n
# 13                   lišiti slobode; držati u zatvoru     v
# 14                      Otarasiti se nekoga ubistvom.     v
# 15  smanjenje u veličini organa usled bolesti ili ...     n
# 16                        koji izaziva osećanje užasa     a
# 17         stanje bola ili patnje zbog lošeg zdravlja     n
# 18  Okrutni poslodavac koji od zaposleni traži da ...     n
# 19                  čin namernog odstupanja od istine     n

# %%
swordnet.synsets("atrofiranje")
# Out:
# [<SrbSynset ID:ENG30-07427060-n>
#          "Lemma - [<SrbLemma name:atrofiranje synset:Synset: ID is ENG30-07427060-n>]"
#          "Definition- Slabljenje ili degeneracije, posebno usled nekorišćenja."
#
#          ]

# %%
Synset_Sentiment_set_4 = PolaritySets(swordnet, 0)
positive_seed_words = ["dobar",
                       "dobrota",
                       "lep",
                       "čudesno",
                       "dragocen",
                       "anđeoski",
                       "izobilje",
                       "izbavljenje",
                       "tešiti",
                       "ispravnost",
                       "oduševiti se",
                       "slast",
                       "uveseljavajući",
                       "napredovati",
                       "proslavljen",
                       "usrećiti",
                       "uspešnost"]

negative_seed_words = ["zao",
                       "antipatija",
                       "beda",
                       "bedan",
                       "bol",
                       "laž",
                       "lažno",
                       "korupcija",
                       "krivica",
                       "prezreti",
                       "tuga",
                       "nauditi",
                       "sebičnost",
                       "paćeništvo",
                       "ukloniti s ovog sveta",
                       "masakr",
                       "ratovanje"]
Synset_Sentiment_set_4.addPOSall(positive_seed_words)
Synset_Sentiment_set_4.addNEGall(negative_seed_words)
Synset_Sentiment_set_4.addPOSIDall(positive_seed_IDS)
Synset_Sentiment_set_4.addNEGIDall(negative_seed_IDS)
