# %%
import sys
sys.path.append('../')
from srpskiwordnet import SrbWordNetReader
from srppolsets import PolaritySets, syn2gloss

# %%
RES_DIR = "..\\resources\\"
MOD_DIR = "..\\ml_models\\"
swordnet = SrbWordNetReader("F:\Serbian Corpora\wnsrp30","wnsrp30.xml")
# Out:
# Synset ENG30-07010821-n lacks literals 24612

# %%
swordnet.load_lexicon(RES_DIR + "lexiconPOSlat")

# %%
Synset_Sentiment_set_1 = PolaritySets(swordnet, 0)

# %%
Synset_Sentiment_set_1.addWNopAll()

# %%
defi = Synset_Sentiment_set_1.getDef()
defi
# Out:
# {'POS': [{'ID': 'ENG30-01821423-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'zainteresovati,zaintrigirati',
#    'Definicija': 'pobuditi nečiju radoznalost; podstaći nečije interesovanje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00473799-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'obnoviti,doterati,uglancati,uljuditi',
#    'Definicija': 'Ostalo je još samo da se doteraju neke finese u igri plavih.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14491625-n',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'izobilje',
#    'Definicija': 'Veliko bogatstvo.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02397637-v',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'unaprediti,promovisati,promaknuti',
#    'Definicija': 'Dodeliti viši položaj.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07509996-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'čuđenje,zaćuđenost',
#    'Definicija': 'osećanje izazvano nečim čudnim i iznenađujućim',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00248659-v',
#    'POS': 0.5,
#    'NEG': 0.0,
#    'Lemme': 'napredovati,ići',
#    'Definicija': 'razvijati se u pozitivnom smeru',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00093483-n',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'spas,izbavljenje',
#    'Definicija': 'Oporavak ili način čuvanja od gubitka ili opasnosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04814238-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'veličanstvenost,briljantnost',
#    'Definicija': 'Osobina nekoga ko je veličanstven, briljantan',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01129977-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'častan,dobar,primeran,ugledan',
#    'Definicija': 'moralno primeran',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07491981-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'polet,oduševljenje,slast',
#    'Definicija': 'energično i oduševljeno uživanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01123148-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'častan,dobar,pouzdan',
#    'Definicija': 'imati poželjne ili pozitivne kvalitete, posebno one koji su pogodni za određenu stvar',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14474052-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'prosperitet,uspešnost',
#    'Definicija': 'Stanje kada je neko prosperitetan i uspešan.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00474017-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'ugladiti,rafinirati',
#    'Definicija': 'Poboljšati glačanjem ili kresanjem.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01817938-v',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'bodriti,osokoliti,obodriti,ohrabriti',
#    'Definicija': 'dati ohrabrenje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04849241-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'dobrota',
#    'Definicija': 'Moralna izvanrednost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00925490-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'čuditi se,oduševiti se',
#    'Definicija': 'diviti se i čuditi nečemu',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01375831-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slavan,poznat,čuven,značajan,renomiran,priznat,proslavljen',
#    'Definicija': 'opšte prihvaćen i uvažen',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07528470-n',
#    'POS': 0.25,
#    'NEG': 0.25,
#    'Lemme': 'nalet,juriš,naboj,uzbuđenje,ushićenje,stimulacija',
#    'Definicija': 'brzo oslobađanje zalihe uticajne sile',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01816431-v',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'usrećiti',
#    'Definicija': 'usrećiti ili zadovoljiti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01676517-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'fantastičan,veličanstven,izvanredan,sjajan,izvrstan,izuzetan,predivan,čdesan',
#    'Definicija': 'izuzetno dobar; ove reči se koriste za naglašavanje značenja drugih reči',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00064095-v',
#    'POS': 0.25,
#    'NEG': 0.0,
#    'Lemme': 'olakšati,ublažiti,utažiti',
#    'Definicija': 'Omogućiti olakšanje od fizičkog bola.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07289588-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'čudo',
#    'Definicija': 'nešto što izaziva osećanje čuđenja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14546844-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ispravnost,korektnost',
#    'Definicija': 'stanje bez oštećenja ili propadanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00228645-a',
#    'POS': 0.5,
#    'NEG': 0.0,
#    'Lemme': 'optimalan',
#    'Definicija': 'koji je najpoželjniji pod datim uslovima ili ograničenjima',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14538472-n',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'sigurnost',
#    'Definicija': 'Stanje u kome je neko siguran da neki uzrok neće izazvati štetne efekte pod definisanim uslovima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02036934-a',
#    'POS': 0.00075,
#    'NEG': 0.0,
#    'Lemme': 'dobar,moralan,pravedan',
#    'Definicija': 'onaj koji poseduje moralne kvalitete;',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07357388-n',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'napredak,progres,unapređenje',
#    'Definicija': 'Promena nabolje, napredak u razvoju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00362467-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'uveseljavajući',
#    'Definicija': 'koji je pun pozitivne energije i širi dobro raspoloženje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00518395-v',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'olakšati,potpomoći',
#    'Definicija': 'Učiniti lakšim.',
#    'Vrsta': 'v'}],
#  'NEG': [{'ID': 'ENG30-01619929-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uništavati,uništiti,upropaštavati,upropastiti',
#    'Definicija': 'ukinuti, čega uništenje ili opoziv uzrokovati',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01327301-v',
#    'POS': 0.0,
#    'NEG': 0.5,
#    'Lemme': 'likvidirati,ucmekati,skembati',
#    'Definicija': 'Otarasiti se nekoga ubistvom.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14408086-n',
#    'POS': 0.0,
#    'NEG': 0.25,
#    'Lemme': 'teškoća,neprilika',
#    'Definicija': 'Stanje stvari koje je skoro izvan nečije mogućnosti da je reši i zahteva veliki napor da se reši ili prevaziđe.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07532440-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'tuga,žalost',
#    'Definicija': 'Osećanja koja se javljaju kada osoba nije u srećnom stanju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00796976-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odbaciti,odbacivati,odbijati,odbiti,prezirati,prezreti',
#    'Definicija': 'odbiti s gnušanjem',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01770501-v',
#    'POS': 0.25,
#    'NEG': 0.375,
#    'Lemme': 'uznemiriti,uzrujati',
#    'Definicija': 'Duboko dirnuti.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00838043-v',
#    'POS': 0.0,
#    'NEG': 0.25,
#    'Lemme': 'praviti se,činiti se,izmotavati se',
#    'Definicija': 'Simulirati.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07536245-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'krivica,osećanje krivice',
#    'Definicija': 'griža savesti kada se neko oseća krivim za prekršaj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01230387-a',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'beznadežan',
#    'Definicija': 'koji je označen beznadežnošću ili ispoljava beznadežnost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14213199-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'muka,fizička patnja',
#    'Definicija': 'stanje bola ili patnje zbog lošeg zdravlja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02482425-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ubiti,ukloniti s ovog sveta',
#    'Definicija': 'Usmrtiti namerno i sa predumišljajem.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00220956-a',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'ružan',
#    'Definicija': 'Koji je moralno odbojan ili neugodan za čula.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00364881-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'deprimirajući,tmuran,sumoran',
#    'Definicija': 'koji izaziva potištenost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00220522-n',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'ubistvo',
#    'Definicija': 'Nezakonito ubijanje s predumišljajem jednog čoveka od strane drugog.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04834605-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sebičnost',
#    'Definicija': 'škrtost koja proizilazi iz brige za sopstvenu dobrobit i nepoštovanje drugih',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00735936-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nepristojnost',
#    'Definicija': 'nedolično ili nemoralno ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00193480-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'užasavajući',
#    'Definicija': 'koji izaziva osećanje užasa',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-09369169-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gnezdo',
#    'Definicija': 'Struktura u kojoj životinje ležu jaja i legu svoje mlade.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00223983-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanica,klanje,krvoproliće,masakr,pokolj',
#    'Definicija': 'divljačko i prekomerno ubijanje mnogih ljudi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13990675-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'krivica',
#    'Definicija': 'Stanje kada je učinjen prekršaj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02466111-a',
#    'POS': 0.0,
#    'NEG': 0.00075,
#    'Lemme': 'nepouzdan',
#    'Definicija': 'onaj kojem se ne može ukazati poverenje, u koga se ne možemo pouzdati',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00736786-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'impulsivnost,raspojasanost,razuzdanost',
#    'Definicija': 'bučno i neobuzdano ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07427060-n',
#    'POS': 0.0,
#    'NEG': 0.5,
#    'Lemme': 'atrofiranje',
#    'Definicija': 'Slabljenje ili degeneracije, posebno usled nekorišćenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02463582-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ciničan,mizantropski,mizantropičan',
#    'Definicija': 'koji misli najgore o ljudskoj prirodi i motivima; koji ima podrugljivu nevericu u, npr. u nesebičnost drugih',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04709253-n',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'teškoća',
#    'Definicija': 'Osobina onoga što je teško.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00402539-v',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'komplikovati,zamrsiti',
#    'Definicija': 'Učiniti složenijim.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07533877-n',
#    'POS': 0.0,
#    'NEG': 0.5,
#    'Lemme': 'patnja,paćeništvo',
#    'Definicija': 'intenzivna ojađenost',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14365741-n',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'atrofija',
#    'Definicija': 'smanjenje u veličini organa usled bolesti ili nekorišćenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01792567-v',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'nauditi,naškoditi',
#    'Definicija': 'uzrokovati bol, unesrećiti',
#    'Vrsta': 'v'}],
#  'OBJ': [{'ID': 'ENG30-01099436-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ulaganje',
#    'Definicija': 'Čin ulaganja novca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06009086-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'koordinatni početak',
#    'Definicija': 'Tačka preseka koordinatnih osi; gde su sve koordinatne vrednosti nula.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05999797-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naučno područje,nauka',
#    'Definicija': 'Određena grana naučnog znanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08897065-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Egipat,Misir,Arapska Republika Egipat',
#    'Definicija': 'država na severoistoku Afrike, nalazi se na mestu drevne civilizacije čiji je procvat bio od 2600 do 30 p.n.e',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13134947-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'plod',
#    'Definicija': 'Zrelo reproduktivno telo biljke semenjače.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03014705-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kovčeg,sanduk,škrinja',
#    'Definicija': 'kutija sa poklopcem, korišćena za skladištenje, obično velika i čvrsta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06468951-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sinopsis',
#    'Definicija': 'skica rezimea koja sadrži glavne tačke neke teroije ili ideje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02117955-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'uhvatiti',
#    'Definicija': 'Osetiti čulima brzo, iznenada ili trenutno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07197021-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ispit,ispitno pitanje,test',
#    'Definicija': 'Skup pitanja ili vežbanja kojim se procenjuje veština ili znanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02713372-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'štrčati,strčati,stršiti',
#    'Definicija': 'izbijati upadljivo iz nečega',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04188179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'krevetski čaršav,lancun',
#    'Definicija': 'deoposteljine koji služi za prekrivanje kreveta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13769033-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'puna mera',
#    'Definicija': 'Količina koja može da stane u neku mericu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01082454-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hvatati',
#    'Definicija': 'biti hvatač (u bejzbolu)',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00651991-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odlikovati,praviti razliku',
#    'Definicija': 'Biti distingtivno svojstvo, osobina ili crta; ponekad u veoma pozitivnom smislu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-15287830-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ciklus,ritam',
#    'Definicija': 'interval u toku koga se ponavlja sekvencija događaja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00706243-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izneti predlog',
#    'Definicija': 'dati na razmatranje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-13286801-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'interes',
#    'Definicija': 'Pravedni ili zakoniti deo nečega; finansijska uključenost u nešto.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00136329-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'šutiranje',
#    'Definicija': 'Čin zadavanja udarca nogom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01522716-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zaokružiti',
#    'Definicija': 'napraviti krug oko nečega',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-13802306-n',
#    'POS': 0.25,
#    'NEG': 0.25,
#    'Lemme': 'imperativ,zapovedni način',
#    'Definicija': 'način kojim se izražava želja da se utiče na ponašanje slušaoca',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06255777-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'list papira,list',
#    'Definicija': 'Koristi se za pisanje ili štampanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02678438-v',
#    'POS': 0.375,
#    'NEG': 0.0,
#    'Lemme': 'zainteresovati se,zanimati se,brinuti',
#    'Definicija': 'biti na nečijem umu',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03094404-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'imperativni',
#    'Definicija': 'odnosi se na glagolski način kojim se izražava naredba',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02189398-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čuti,načuti,oslušnuti,slušati,uhvatiti',
#    'Definicija': 'opaziti slušajući',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00845523-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'seksualni odnos,seksualni čin,koitus,kopulacija',
#    'Definicija': 'fizički odnos između muškarca i žene',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08717209-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Kamerun,Republika Kamerun',
#    'Definicija': 'država na zapadnoj obali centralne Afrike, stekla nezavisnost 1960',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02719009-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'elektrostatički',
#    'Definicija': 'koji se tiče ili koji proizvodi ili koji je izazvan statičkim elektricitetom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00625393-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvaran,realan,materijalan',
#    'Definicija': 'koji postoji u stvarnosti, uzet iz života',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07968702-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'interesna grupa',
#    'Definicija': 'Obično u množini, društvena grupa čiji članovi kontrolišu neko polje rada i koji imaju zajedničke ciljeve.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02071294-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kit ubica,kosatka,Orcinus orca',
#    'Definicija': 'Grabljivi crnobeli kit sa zubima sa velikim leđnim perajem; živi u hladnim vodama.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00098346-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'aktivirati sistem,podići sistem,pokrenuti sistem,ponovo aktivirati sistem,ponovo podići sistem,ponovo pokrenuti sistem',
#    'Definicija': 'pokrenuti učitavanje (operativnog sistema) i započeti inicijalne procese',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04188643-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'list',
#    'Definicija': 'Ravna tvorevina koja se relativno tanka u odnosu na širinu i dužinu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10518602-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'redovnik',
#    'Definicija': 'Član monaškog reda koji se zakleo na siromaštvo, poslušnost i krepost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03781787-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'monitor',
#    'Definicija': 'deo elektronske opreme koji kontinuirano prati operacije sistema i upozorava na probleme',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02397732-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hot,papren',
#    'Definicija': 'koji jako nadražuje organe ukusa i mirisa',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02725829-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'federalni,savezni',
#    'Definicija': 'koji se odnosi na centralnu vladu federacije',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00158222-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'porasti',
#    'Definicija': 'Rasti po ceni ili nivou.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-09989502-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'plesač',
#    'Definicija': 'Izvođač koji pleše.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05576194-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jagodica,jabučica',
#    'Definicija': 'Više ili manje zaobljeni deo tela na stopalu ili vrhu palca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05976948-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stoicizam',
#    'Definicija': '(filozofija) filozofski sistem stoika zasnovan na učenjima drevnog grčkog filozofa Zenona',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13661273-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dolar',
#    'Definicija': 'osnovna nočana jedinica u mnogim zemljama; vrednost joj je 100 centi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01439190-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zgrabiti,ščepati',
#    'Definicija': 'Dokopati se nečega tako da se obustavi njegovo kretanje.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01061333-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zahtevanje',
#    'Definicija': 'čin kojim se zahteva',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13729902-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'realni broj',
#    'Definicija': 'svaki racionalan ili iracionalan broj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13275495-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trošak,izdatak',
#    'Definicija': 'Iznosi plaćeni za robu i usluge za koje je moguć oslobađanje od poreza (nasuprot troškovima kapitala).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07609840-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'desert,poslastica',
#    'Definicija': 'Jelo koje se poslednje servira u obroku.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10523076-n',
#    'POS': 1.0,
#    'NEG': 0.0,
#    'Lemme': 'istraživač',
#    'Definicija': 'Naučnik koji je posvećen istraživanju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02991048-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'elektrohemijska ćelija',
#    'Definicija': 'uređaj koji isporučuje električnu struju kao rezultat hemijske reakcije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02518161-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'držati se,nositi se',
#    'Definicija': 'Ponašati se na određen način.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08954611-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Korejsko poluostrvo',
#    'Definicija': 'poluostrvo u Aziji koje razdvaja Žuto more od Japanskog mora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08240169-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grupa,grupacija,krug',
#    'Definicija': 'Nezvanična asocijacija ljudi ili grupa.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07584727-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'supa,lonac supe',
#    'Definicija': 'tečnost u kojoj se kuvaju povrće ili meso',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01200095-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'konzistentan,uniforman',
#    'Definicija': 'koji je uvek isti po strukturi ili sastavu',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07961016-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grumen,kvrga,gruda',
#    'Definicija': 'Kompaktna masa.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03800563-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'muzej',
#    'Definicija': 'Mesto za sakupljanje i prikazivanje predmeta koji imaju naučnu ili istorijsku ili umetničku vrednost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13861050-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ravnina',
#    'Definicija': 'neograničen dvodimenzionalan oblik',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07289831-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Neki događaj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03827107-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čvor,klijent,gost',
#    'Definicija': 'u računarstvu, računar koji je povezan na računarsku mrežu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04350905-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odelo,garnitura',
#    'Definicija': 'skup odevnih predmeta za nošenje na otvorenom, iste tkanine i boje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00023271-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'saznanje',
#    'Definicija': 'Psihološki rezultat opažanja i učenja i rezonovanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03782190-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'monitor,MONITOR (MONITOR),MONITORSKI UREĐAJ (MONITORING DEVICE)',
#    'Definicija': 'ekran koji se sastoji od uređaja koji preuzima signale sa računara i prikazuje ih na CRT ekranu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06303888-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'termin',
#    'Definicija': 'Reč ili izraz koji se koristi za neku određenu stvar.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08101937-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'preci,loza,pedigre',
#    'Definicija': 'Praoci neke osobe.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07206887-n',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'kontradikcija',
#    'Definicija': 'u logici, iskaz koji je uvek netačan',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12143676-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kukuruz,Zea Mays',
#    'Definicija': 'Visoka jednogodišnja žitarica koja nosi klip na velikim ušima; široko rasprostranjena u Americi sa raznim varijetetima; osnovna žitarica u Meksiku i Centralnoj i Južnoj Americi pre Kolumba.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04922113-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odgoj,vaspitanje',
#    'Definicija': 'osobine stečene kao posledica načina na koji ste bili tretirani kao dijete',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06267893-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'novina malog formata',
#    'Definicija': 'novina malog formata (400x300 mm)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01510827-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uključiti',
#    'Definicija': 'Staviti u pogon.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07270179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'znak,beleg',
#    'Definicija': 'Prepoznatljiv simbol.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01211699-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'manipulisati',
#    'Definicija': 'držati nešto u rukama i pomerati ga',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01048171-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cvileti,kevtati',
#    'Definicija': 'lajati visokim tonom',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07154330-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'idiom,fraza',
#    'Definicija': 'Izraz čije značenje ne može da se zaključi iz značenja reči koje ga sačinjavaju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02779435-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lopta',
#    'Definicija': 'okrugao predmet koji se koristi kao igračka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02733524-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'luk',
#    'Definicija': 'Građevinska konstrukcija (obično zakrivljena) koja služi da premosti otvor (arhitektura).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01442779-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'preforirati',
#    'Definicija': 'Napraviti rupu u nečemu ili izmedžu nečega da bi se lakše odvajalo.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00138956-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grabljenje,ščepavanje,hvatanje',
#    'Definicija': 'Čin hvatanja predmeta pomoću ruke.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00795720-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'posao,poduhvat,projekat',
#    'Definicija': 'Neki posao koji preduzet ili se planira.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02056265-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'verski,duhovan',
#    'Definicija': 'koji se tiče svetih stvari, religije ili crkve',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-13667908-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'real,brazilski real,BRL',
#    'Definicija': 'osnovna novčana jedinica Brazila',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06723908-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar,iskaz',
#    'Definicija': 'Iskaz posmatran kao objekat.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04446521-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zahod,nužnik,klozet',
#    'Definicija': 'Vodovodna instalacija za vršenje nužde.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02982599-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'reza,rajber',
#    'Definicija': 'pričvrščivaač za zatvaranje vrata ili prozora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02961258-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poljski',
#    'Definicija': 'koji se tiče Poljske, njenih ljudi i kulture',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07086518-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ritam,takt',
#    'Definicija': 'Osnovna ritmička jedinicaâ\x80\x93 u muzičkom delu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04617289-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nešto',
#    'Definicija': 'Atribut ili kvalitet za koji se smatra da ima sopstvenu egzistenciju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01635432-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zamišljati,zamisliti,dočaravati,dočarati,predočiti',
#    'Definicija': 'Zamisliti, videti u mislima.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06751974-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'uslov',
#    'Definicija': 'jedan od koncepata koji se poredi ili povezuje u logičkoj propoziciji',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08358594-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ćelija',
#    'Definicija': 'mala jedinica koja služi kao deo jezgra ili kao jezgro većeg političkog pokreta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05578442-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gležanj,članak',
#    'Definicija': 'Zglob koji spaja stopalo i potkoleničnu kost, tarsus.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03306207-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izvoz',
#    'Definicija': 'Dobra ili usluge prodati stranoj zemlji.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01124794-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'upravljanje,vladanje',
#    'Definicija': 'Čin upravljanja; sprovođenje vlasti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13391967-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dolar',
#    'Definicija': 'američki novčić koji vredi jedan dolar',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00761713-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pregovarati',
#    'Definicija': 'raspravljati o uslovima kakvog dogovora',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07596684-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slatkiš',
#    'Definicija': 'Hrana koja sadrži puno šećera.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00001740-a',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'sposoban,kadar',
#    'Definicija': 'Koji ima potrebne sposobnosti, veštinu ili znanje da nešto uradi.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00497061-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'podignuti,povisiti',
#    'Definicija': 'Podići ili povećati.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04127904-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jedro',
#    'Definicija': 'Veliki komad tkanine, na primer platna, pomoću koga se koristi vetar za pokretanje jedrenjaka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01245637-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'glačati,uglačati',
#    'Definicija': 'Učiniti da površine sijaju.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-05552607-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grudni koš,toraks',
#    'Definicija': 'Deo ljudskog tela između vrata i dijafragme ili odgovarajući deo kod drugih kičmenjaka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07901587-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'žestoko piće,cuga,cirka',
#    'Definicija': 'nešto pre destilovano nego fermentisano',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07452074-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'svadba',
#    'Definicija': 'Društvena prilika u kojoj se vrši ceremonija sklapanja braka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02150948-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gledati,motriti,opaziti,osmatrati,pogledati,posmatrati,pratiti,promatrati,spaziti,ugledati,videti',
#    'Definicija': 'videti ili posmatrati',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-15224486-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': '?term',
#    'Definicija': 'Ograničen vremenski period.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00378069-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gorenje',
#    'Definicija': 'Čin u kome nešto gori',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03088164-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gumica,higijenska gumica,kondom,kurton,prezervativ,zaštita',
#    'Definicija': 'kontraceptivni uređaj koji se sastoji od tanke gume ili lateksne prevlake koja se nosi preko penisa tokom seksa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02187922-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'grgoljiti,žuboriti,romoriti',
#    'Definicija': 'Teći u nepravilnom toku praveći grgoljav zvuk; o vodi.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03165211-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'glavna knjiga',
#    'Definicija': 'Knjigovodstveni dnevnik kao fizički objekat.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00002452-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Odvojen i zaokružni objekat.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01993926-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'primaknuti,prineti,približiti',
#    'Definicija': 'Učiniti da nešto bude pomaknuto prema napred.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03602562-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dnevnik',
#    'Definicija': 'knjiga zabeleški kao fizički predmet',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02872752-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čizma',
#    'Definicija': 'Obuća koja pokriva celo stopalo i potkolenicu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04515129-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'potporanj,podupirač',
#    'Definicija': 'Vertikalni građevinski element, kao stub.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04612722-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'količina proizvedenih proizvoda,prinos',
#    'Definicija': 'Neka količina proizvoda.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02666943-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanica',
#    'Definicija': 'Zgrada u kojoj se vrši likvidacija životinja radi proizvodnje mesa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07930554-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'punč',
#    'Definicija': 'rashlađeno mešano piće koje često sadrži alkohol i priprema se za više serviranja; servira se u činiji punč',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02842042-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'semantički',
#    'Definicija': 'koji se odnosi na proučavanje značenja i promena značenja',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02228031-v',
#    'POS': 0.0,
#    'NEG': 0.125,
#    'Lemme': 'ostaviti',
#    'Definicija': 'Rešiti se nečega.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01481154-v',
#    'POS': 0.0,
#    'NEG': 0.375,
#    'Lemme': 'obesiti',
#    'Definicija': 'Okačiti nekoga da visi.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03032811-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'krug,cirkular',
#    'Definicija': 'kružni ili rotirajući mehanizam',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03722007-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'marker',
#    'Definicija': 'pribor za pisanje koji služi da se nešto označi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02121620-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prava mačka',
#    'Definicija': 'Životinja iz porodice mačaka koja ima debelo meko krzno i može da reži: domaće mačke i divlje mačke.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04295881-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stadion',
#    'Definicija': 'Velika konstrukcija za sportove na otvorenom i zabavu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15236859-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jesen',
#    'Definicija': 'Godišnje doba kada lišće opada sa drveća.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00875806-v',
#    'POS': 0.125,
#    'NEG': 0.0,
#    'Lemme': 'podneti,predložiti',
#    'Definicija': 'Istaći za raspravu ili prihvatanje.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02732798-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'primiti,primati',
#    'Definicija': 'imati prostora za nešto, obuhvatiti u svoj prostor',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06295235-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oblik množine,oblik plurala,oblik u množini,oblik u pluralu',
#    'Definicija': 'oblik reči koji označava više od jednog objekta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00901476-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kompjuterizovana tomografija,aksijalna tomografija,CT,skener,računarska tomografija',
#    'Definicija': 'savremena metoda ispitivanja, koja se zasniva na nekim starim metodama (upotreba X zraka, tehnika tomografskog snimanja) i nekim savremenim tehničkim dostignućima (upotreba računara), pri čemu se dobijaju snimci u jednoj osi u slojevima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09078231-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Havaji',
#    'Definicija': 'Savezna država SAD-a u centralnom Pacifiku na Havajskim ostrvima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01036996-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'venčanje',
#    'Definicija': 'Čin venčanja; bračna ceremonija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03990474-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lonac',
#    'Definicija': 'Metalna ili zemljana posuda za kuvanje, okrugla i duborka, česti ima reučke i poklopac.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06148148-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'političke nauke,politikologija',
#    'Definicija': 'proučavanje upravnih sistema u državama i drugih političkih jedinica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03819595-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pletivo',
#    'Definicija': 'Tkanina od niti, konopca ili žice koji se tkuju zajedno u pravilnim intervalima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07906877-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kukuruzni viski',
#    'Definicija': 'viski destilovan iz smeš koja sadrži bar 80 procenata kukuruza',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08507558-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izvor,početak,poreklo',
#    'Definicija': 'Mesto gde nešto počine, gde nastaje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13333237-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ulog,investicija',
#    'Definicija': 'Novac koji se ulaže uz očekivani profit.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07221094-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naracija,priča,pripovest,pripovetka',
#    'Definicija': 'priča o događajima ili dešavanjima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00874067-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ocena,procenjivanje,sud',
#    'Definicija': 'Čin procenjivanja ili prosuđivanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02127808-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'velika mačka',
#    'Definicija': 'Neka od više velikih mačaka koje mogu da reže i žive u divljini.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00692329-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'apstrahovati,teoretisati',
#    'Definicija': 'razmišljati o kakvom konceptu nemajući na umu konkretan primer, razmotriti nešto na abstraktan i teoretski način',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03359137-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'baterijska lampa',
#    'Definicija': 'Mala prenosiva električna lampa koja radi na baterije.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13375891-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'avans,predujam',
#    'Definicija': 'Iznos koji se plaća pre nego što se zaradi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01482330-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'morski pas,ajkula',
#    'Definicija': 'Neka od brojnih morskih riba-mesoždera sa izduženim telom,? i debelom kožom koja je prekrivena malim nazubljenim krljuštima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10235549-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rođak ili svojta',
#    'Definicija': 'osoba u srodstvu po krvi ili braku',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01992503-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ići,prolaziti,odmicati,nastaviti',
#    'Definicija': 'i u metaforičkom značenju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01107206-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'federalni,savezni',
#    'Definicija': 'koji je karakterističan za ili koji odražava takav oblik vlasti u kome je vlast podeljena između jedne centralne i nekoliko regionalnih uprava',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05671325-n',
#    'POS': 0.125,
#    'NEG': 0.25,
#    'Lemme': 'stvar,posao',
#    'Definicija': 'Neodređeno specifikovana preokupacija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07323922-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'postanje,postanak,prapočetak',
#    'Definicija': 'Događaj koji predstavlja početak; prvi deo ili stadijum potonjih događaja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09376198-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'okean',
#    'Definicija': 'velika vodena površina koji čini glavni deo hidrosfere',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13873502-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kružnica',
#    'Definicija': 'elipsa kod koje su dve ose iste dužine; kriva u ravni koja se dobija kretanjem tačke na stalnom rastojanju od jedne fiksne tačke',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04424218-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Neka ljudska tvorevina.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00620424-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klanica,mesara,mesarija',
#    'Definicija': 'radnja mesara',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00471613-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bejzbol',
#    'Definicija': 'utakmica sa palicom i loptom između dve ekipe od 9 igrača; ekipe se smenjuju pokušavajući da pomoću palice ostvare pogodak',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06402031-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dnevnik',
#    'Definicija': 'dnevno pisane zabeleške (obično ličnih) iskustava i zapažanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00196485-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zamena,supstitucija',
#    'Definicija': 'Stavljanje jedne stvari ili osobe na mesto druge.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08050678-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vlast,režim,vlada',
#    'Definicija': 'Organizacija koja je upravljačko telo političke jedinice.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03015254-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'komoda',
#    'Definicija': 'Komad nameštaja sa ladicama za držanje odeće.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02778669-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lopta,loptica',
#    'Definicija': 'okrugli objekat koji se u igrama udara, baca ili šutira',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05855004-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stvar',
#    'Definicija': 'Specijalna apstrakcija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06669864-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jednačina',
#    'Definicija': 'matematički iskaz da su dva izraza jednaka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08896831-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Egipatsko carstvo,Egipat',
#    'Definicija': 'drevno carstvo koje je zauzimalo prostor oko reke Nil i kojim su vladali faraoni of Israel; centered on the Nile River and ruled by a Pharaoh; figured in many events described in the Old Testament',
#    'Vrsta': 'n'}],
#  'iteration': 0}

# %%
import pandas as pd

# %%
df_POS = pd.DataFrame(defi["POS"])

# %%
df_POS
# Out:
#                   ID      POS   NEG  \
# 0   ENG30-01821423-v  0.12500  0.00
# 1   ENG30-00473799-v  0.00000  0.00
# 2   ENG30-14491625-n  0.25000  0.00
# 3   ENG30-02397637-v  0.25000  0.00
# 4   ENG30-07509996-n  0.75000  0.00
# 5   ENG30-00248659-v  0.50000  0.00
# 6   ENG30-00093483-n  0.12500  0.00
# 7   ENG30-04814238-n  0.62500  0.00
# 8   ENG30-01129977-a  0.00000  0.00
# 9   ENG30-07491981-n  0.75000  0.00
# 10  ENG30-01123148-a  0.00000  0.00
# 11  ENG30-14474052-n  0.75000  0.00
# 12  ENG30-00474017-v  0.12500  0.00
# 13  ENG30-01817938-v  0.25000  0.00
# 14  ENG30-04849241-n  0.87500  0.00
# 15  ENG30-00925490-v  0.12500  0.00
# 16  ENG30-01375831-a  0.00000  0.00
# 17  ENG30-07528470-n  0.25000  0.25
# 18  ENG30-01816431-v  0.37500  0.00
# 19  ENG30-01676517-a  0.75000  0.00
# 20  ENG30-00064095-v  0.25000  0.00
# 21  ENG30-07289588-n  0.62500  0.00
# 22  ENG30-14546844-n  0.00000  0.00
# 23  ENG30-00228645-a  0.50000  0.00
# 24  ENG30-14538472-n  0.12500  0.00
# 25  ENG30-02036934-a  0.00075  0.00
# 26  ENG30-07357388-n  0.37500  0.00
# 27  ENG30-00362467-a  0.75000  0.00
# 28  ENG30-00518395-v  0.37500  0.00
#
#                                                 Lemme  \
# 0                        zainteresovati,zaintrigirati
# 1                obnoviti,doterati,uglancati,uljuditi
# 2                                            izobilje
# 3                   unaprediti,promovisati,promaknuti
# 4                                  čuđenje,zaćuđenost
# 5                                     napredovati,ići
# 6                                    spas,izbavljenje
# 7                        veličanstvenost,briljantnost
# 8                       častan,dobar,primeran,ugledan
# 9                            polet,oduševljenje,slast
# 10                               častan,dobar,pouzdan
# 11                              prosperitet,uspešnost
# 12                                ugladiti,rafinirati
# 13               bodriti,osokoliti,obodriti,ohrabriti
# 14                                            dobrota
# 15                             čuditi se,oduševiti se
# 16  slavan,poznat,čuven,značajan,renomiran,priznat...
# 17  nalet,juriš,naboj,uzbuđenje,ushićenje,stimulacija
# 18                                           usrećiti
# 19  fantastičan,veličanstven,izvanredan,sjajan,izv...
# 20                          olakšati,ublažiti,utažiti
# 21                                               čudo
# 22                              ispravnost,korektnost
# 23                                          optimalan
# 24                                          sigurnost
# 25                             dobar,moralan,pravedan
# 26                       napredak,progres,unapređenje
# 27                                     uveseljavajući
# 28                                 olakšati,potpomoći
#
#                                            Definicija Vrsta
# 0   pobuditi nečiju radoznalost; podstaći nečije i...     v
# 1   Ostalo je još samo da se doteraju neke finese ...     v
# 2                                   Veliko bogatstvo.     n
# 3                              Dodeliti viši položaj.     v
# 4      osećanje izazvano nečim čudnim i iznenađujućim     n
# 5                     razvijati se u pozitivnom smeru     v
# 6   Oporavak ili način čuvanja od gubitka ili opas...     n
# 7       Osobina nekoga ko je veličanstven, briljantan     n
# 8                                    moralno primeran     a
# 9                    energično i oduševljeno uživanje     n
# 10  imati poželjne ili pozitivne kvalitete, posebn...     a
# 11       Stanje kada je neko prosperitetan i uspešan.     n
# 12                Poboljšati glačanjem ili kresanjem.     v
# 13                                    dati ohrabrenje     v
# 14                              Moralna izvanrednost.     n
# 15                          diviti se i čuditi nečemu     v
# 16                           opšte prihvaćen i uvažen     a
# 17              brzo oslobađanje zalihe uticajne sile     n
# 18                           usrećiti ili zadovoljiti     v
# 19  izuzetno dobar; ove reči se koriste za naglaša...     a
# 20              Omogućiti olakšanje od fizičkog bola.     v
# 21                 nešto što izaziva osećanje čuđenja     n
# 22                stanje bez oštećenja ili propadanja     n
# 23  koji je najpoželjniji pod datim uslovima ili o...     a
# 24  Stanje u kome je neko siguran da neki uzrok ne...     n
# 25              onaj koji poseduje moralne kvalitete;     a
# 26               Promena nabolje, napredak u razvoju.     n
# 27  koji je pun pozitivne energije i širi dobro ra...     a
# 28                                    Učiniti lakšim.     v

# %%
df_OBJ = pd.DataFrame(defi["OBJ"])

# %%
df_OBJ
# Out:
#                    ID  POS  NEG                                  Lemme  \
# 0    ENG30-01099436-n  0.0  0.0                               ulaganje
# 1    ENG30-06009086-n  0.0  0.0                    koordinatni početak
# 2    ENG30-05999797-n  0.0  0.0                  naučno područje,nauka
# 3    ENG30-08897065-n  0.0  0.0  Egipat,Misir,Arapska Republika Egipat
# 4    ENG30-13134947-n  0.0  0.0                                   plod
# ..                ...  ...  ...                                    ...
# 155  ENG30-03015254-n  0.0  0.0                                 komoda
# 156  ENG30-02778669-n  0.0  0.0                          lopta,loptica
# 157  ENG30-05855004-n  0.0  0.0                                  stvar
# 158  ENG30-06669864-n  0.0  0.0                              jednačina
# 159  ENG30-08896831-n  0.0  0.0               Egipatsko carstvo,Egipat
#
#                                             Definicija Vrsta
# 0                                  Čin ulaganja novca.     n
# 1    Tačka preseka koordinatnih osi; gde su sve koo...     n
# 2                       Određena grana naučnog znanja.     n
# 3    država na severoistoku Afrike, nalazi se na me...     n
# 4           Zrelo reproduktivno telo biljke semenjače.     n
# ..                                                 ...   ...
# 155      Komad nameštaja sa ladicama za držanje odeće.     n
# 156  okrugli objekat koji se u igrama udara, baca i...     n
# 157                            Specijalna apstrakcija.     n
# 158         matematički iskaz da su dva izraza jednaka     n
# 159  drevno carstvo koje je zauzimalo prostor oko r...     n
#
# [160 rows x 6 columns]

# %%
df_NEG = pd.DataFrame(defi["NEG"])

# %%
df_NEG
# Out:
#                   ID   POS      NEG  \
# 0   ENG30-01619929-v  0.00  0.00000
# 1   ENG30-01327301-v  0.00  0.50000
# 2   ENG30-14408086-n  0.00  0.25000
# 3   ENG30-07532440-n  0.00  0.75000
# 4   ENG30-00796976-v  0.00  0.00000
# 5   ENG30-01770501-v  0.25  0.37500
# 6   ENG30-00838043-v  0.00  0.25000
# 7   ENG30-07536245-n  0.00  0.87500
# 8   ENG30-01230387-a  0.00  0.37500
# 9   ENG30-14213199-n  0.00  0.62500
# 10  ENG30-02482425-v  0.00  0.62500
# 11  ENG30-00220956-a  0.00  0.37500
# 12  ENG30-00364881-a  0.00  0.62500
# 13  ENG30-00220522-n  0.00  0.37500
# 14  ENG30-04834605-n  0.00  0.00000
# 15  ENG30-00735936-n  0.00  0.62500
# 16  ENG30-00193480-a  0.00  0.62500
# 17  ENG30-09369169-n  0.00  0.00000
# 18  ENG30-00223983-n  0.00  0.00000
# 19  ENG30-13990675-n  0.00  0.62500
# 20  ENG30-02466111-a  0.00  0.00075
# 21  ENG30-00736786-n  0.00  0.00000
# 22  ENG30-07427060-n  0.00  0.50000
# 23  ENG30-02463582-a  0.00  0.62500
# 24  ENG30-04709253-n  0.00  0.12500
# 25  ENG30-00402539-v  0.00  0.12500
# 26  ENG30-07533877-n  0.00  0.50000
# 27  ENG30-14365741-n  0.00  0.12500
# 28  ENG30-01792567-v  0.00  0.37500
#
#                                                 Lemme  \
# 0       uništavati,uništiti,upropaštavati,upropastiti
# 1                       likvidirati,ucmekati,skembati
# 2                                   teškoća,neprilika
# 3                                         tuga,žalost
# 4   odbaciti,odbacivati,odbijati,odbiti,prezirati,...
# 5                                 uznemiriti,uzrujati
# 6                  praviti se,činiti se,izmotavati se
# 7                            krivica,osećanje krivice
# 8                                          beznadežan
# 9                                 muka,fizička patnja
# 10                        ubiti,ukloniti s ovog sveta
# 11                                              ružan
# 12                       deprimirajući,tmuran,sumoran
# 13                                            ubistvo
# 14                                          sebičnost
# 15                                      nepristojnost
# 16                                        užasavajući
# 17                                             gnezdo
# 18           klanica,klanje,krvoproliće,masakr,pokolj
# 19                                            krivica
# 20                                          nepouzdan
# 21             impulsivnost,raspojasanost,razuzdanost
# 22                                        atrofiranje
# 23                 ciničan,mizantropski,mizantropičan
# 24                                            teškoća
# 25                              komplikovati,zamrsiti
# 26                                  patnja,paćeništvo
# 27                                           atrofija
# 28                                  nauditi,naškoditi
#
#                                            Definicija Vrsta
# 0       ukinuti, čega uništenje ili opoziv uzrokovati     v
# 1                       Otarasiti se nekoga ubistvom.     v
# 2   Stanje stvari koje je skoro izvan nečije moguć...     n
# 3   Osećanja koja se javljaju kada osoba nije u sr...     n
# 4                                  odbiti s gnušanjem     v
# 5                                     Duboko dirnuti.     v
# 6                                         Simulirati.     v
# 7   griža savesti kada se neko oseća krivim za pre...     n
# 8   koji je označen beznadežnošću ili ispoljava be...     a
# 9          stanje bola ili patnje zbog lošeg zdravlja     n
# 10              Usmrtiti namerno i sa predumišljajem.     v
# 11      Koji je moralno odbojan ili neugodan za čula.     a
# 12                           koji izaziva potištenost     a
# 13  Nezakonito ubijanje s predumišljajem jednog čo...     n
# 14  škrtost koja proizilazi iz brige za sopstvenu ...     n
# 15                  nedolično ili nemoralno ponašanje     n
# 16                        koji izaziva osećanje užasa     a
# 17  Struktura u kojoj životinje ležu jaja i legu s...     n
# 18       divljačko i prekomerno ubijanje mnogih ljudi     n
# 19                   Stanje kada je učinjen prekršaj.     n
# 20  onaj kojem se ne može ukazati poverenje, u kog...     a
# 21                       bučno i neobuzdano ponašanje     n
# 22  Slabljenje ili degeneracije, posebno usled nek...     n
# 23  koji misli najgore o ljudskoj prirodi i motivi...     a
# 24                        Osobina onoga što je teško.     n
# 25                                Učiniti složenijim.     v
# 26                               intenzivna ojađenost     n
# 27  smanjenje u veličini organa usled bolesti ili ...     n
# 28                         uzrokovati bol, unesrećiti     v

# %%
pos_value_counts = df_POS['Vrsta'].value_counts()
neg_value_counts = df_NEG['Vrsta'].value_counts()
obj_value_counts = df_OBJ['Vrsta'].value_counts()

# Combine the value counts from all DataFrames
combined_value_counts = pos_value_counts.add(neg_value_counts, fill_value=0).add(obj_value_counts, fill_value=0)

# Print the combined value counts
print(combined_value_counts)
# Out:
# n    147
# v     47
# a     24
# Name: Vrsta, dtype: int64

# %%
rem_obj = ["ENG30-05528604-n",
"ENG30-00749767-n",
"ENG30-09593651-n",
"ENG30-13250542-n",
"ENG30-13132338-n",
"ENG30-05943066-n",
"ENG30-03123143-a",
"ENG30-10104209-n",
"ENG30-12586298-n",
"ENG30-01971094-n",
"ENG30-00759269-v",
"ENG30-00948206-n",
"ENG30-01039307-n",
"ENG30-02041877-v",
"ENG30-00023271-n",
"ENG30-13509196-n",
"ENG30-09450866-n",
"ENG30-03947798-n",
"ENG30-08589140-n"
          ]

# %%
len(rem_obj)
# Out:
# 19

# %%
# Initialize a dictionary to store the counts
type_counts = {}

# Iterate through the list and count the word types
for word in rem_obj:
    word_type = word[-1]  # Get the last character
    
    if word_type in type_counts:
        type_counts[word_type] += 1
    else:
        type_counts[word_type] = 1

# Print the counts for each type
print(type_counts)
# Out:
# {'n': 16, 'a': 1, 'v': 2}

# %%
for rem_id in rem_obj:
    syn = swordnet.synset_from_ID(rem_id)
    print(syn)
    print(syn.lemma_names())
    print(syn.definition())
# Out:
# Synset: ID is ENG30-05528604-n
# ['nosna šupljina']
# either of the two cavities lying between the floor of the cranium and the roof of the mouth and extending from the face to the pharynj
# Synset: ID is ENG30-00749767-n
# ['izdaja', 'verolomstvo']
# čin namernog izdajstva
# Synset: ID is ENG30-09593651-n
# ['Tantal']
# u grčkoj mitologiji zli kralj, Zevsov sin; osuđen da stoji u Hadu u vodi koja bi se povukla kada bi on želeo da pije i ispod voćke koja bi se povukla kada bi on posegao za njom
# Synset: ID is ENG30-13250542-n
# ['novac', 'imetak']
# Bogatstvo izraženo kroz novac.
# Synset: ID is ENG30-13132338-n
# ['?flower cluster']
# an inflorescence consisting of a cluster of flowers
# Synset: ID is ENG30-05943066-n
# ['vera', 'poverenje']
# Potpuno verovanje u osobu ili plan itd.
# Synset: ID is ENG30-03123143-a
# ['tarzalni', 'nožji']
# of or relating to or near the tarsus of the foot; "tarsal bones"
# Synset: ID is ENG30-10104209-n
# ['gazda', 'šef', 'pretpostavljeni']
# Osoba koja upravlja radom radnika.
# Synset: ID is ENG30-12586298-n
# ['?calamus']
# any tropical Asian palm of the genus Calamus; light tough stems are a source of rattan canes
# Synset: ID is ENG30-01971094-n
# ['?decapod']
# cephalopods having eight short tentacles plus two long ones
# Synset: ID is ENG30-00759269-v
# ['preklinjati']
# učtivo se obraćati s molbom nekome
# Synset: ID is ENG30-00948206-n
# ['iskorišćavanje']
# Čin kojim neki deo zemlje postaje produktivniji, korisniji ili profitabilniji.
# Synset: ID is ENG30-01039307-n
# ['ispoved']
# čin pokajnika kojim on otkriva svoje grehe pred sveštenikom u svetoj tajni pokajanja u nadi za oproštajem (u Rimokatoličkoj crkvi)
# Synset: ID is ENG30-02041877-v
# ['srušiti se', 'kolabirati', 'propasti']
# raspasti se; i u prenesenom značenju
# Synset: ID is ENG30-00023271-n
# ['saznanje']
# Psihološki rezultat opažanja i učenja i rezonovanja.
# Synset: ID is ENG30-13509196-n
# ['gubitak']
# pad aktivnosti
# Synset: ID is ENG30-09450866-n
# ['superior planet']
# any of the planets whose orbit lies outside the earth's orbit
# Synset: ID is ENG30-03947798-n
# ['pique']
# tightly woven fabric with raised cords
# Synset: ID is ENG30-08589140-n
# ['irredenta', 'irridenta']
# a region that is related ethnically or historically to one country but is controlled politically by another

# %%
Synset_Sentiment_set_2 = PolaritySets(swordnet, 0)
Synset_Sentiment_set_2.addWSWN()

# %%
defi2 = Synset_Sentiment_set_2.getDef()
defi2
# Out:
# {'POS': [],
#  'NEG': [],
#  'OBJ': [{'ID': 'ENG30-09354984-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Galaktika,Gospina kruna,Kumova slama,Mlečni put,Rimska cesta',
#    'Definicija': 'galaksija koja sadrži Sunčev sistem (sastoji se od miliona zvezda koje se mogu posmatrati kao difuzna traka svetlosti koja se proteže preko noćnog neba)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02067240-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ulješura,glavata uljarka,Physeter catodon',
#    'Definicija': 'Veliki kit sa velikom šupljinom u glavi u kojoj se nalazi ulje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00090253-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prijem,primanje',
#    'Definicija': 'Čin primanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01540090-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poljski vrabac,brdski vrabac,dživdžan,Passer montanus',
#    'Definicija': 'mali evroazijski vrabac, manji od domaćeg vrapca',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01436003-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kratak',
#    'Definicija': 'Osnovno prostorno značenje; koji ima malu dužinu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07684289-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nan',
#    'Definicija': 'Hleb koji se priprema sa kvascem i peče u zemljanoj pećnici u Indiji; obično je u obliku suze.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10513120-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'redaktor',
#    'Definicija': 'neko ko dovodi tekst u prihvatljiv oblik za štampu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11450566-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'električna energija,struja',
#    'Definicija': 'energija koju oslobađa protok električnog naboja kroz provodnik',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12102133-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trava',
#    'Definicija': 'Zelena travnata biljka sa uskim lišćem, uzgaja se u travnjacima; koristi se za ispašu životinja preživara; kosi se i suši za seno.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13128365-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gomolj',
#    'Definicija': 'Mesnata podzemna stabljika ili koren koji ima reproduktivnu ulogu i služi kao spremište hrane.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15209706-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mesec po Gregorijanskom kalendaru',
#    'Definicija': 'Kalandar koji je uveden s reformom pape Gregorija XIII godine 1582.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02776825-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'avijatičarska kapa',
#    'Definicija': 'kapu koja odgovara i vunena je i pokriva celu glavu osim lice',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01528845-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'livadna cipica,Anthus pratensis',
#    'Definicija': 'obična vodarica, gore smeđa, dole bela; široko rasprostranjena u centralnoj Evropi i Aziji',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15210870-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mart,ožujak',
#    'Definicija': 'Mesec koji dolazi posle februara a pre aprila u kalendaru.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07713895-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kupus',
#    'Definicija': 'Neki od mnogih vrsta kupusa.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07928998-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sarsaparila',
#    'Definicija': 'gazirano piće sa ukusom korena sarsaparile ili sa uljem breze ili lovora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13980845-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'konflikt,suprotstavljenost',
#    'Definicija': 'Stanje u kome su ljudi, ideje ili interesi suprotstavljeni.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04474466-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klopka',
#    'Definicija': 'uređaj pomoću koga nešto može da se ulovi (obično se misli na životinje)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00153288-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prenatalna dijagnostika',
#    'Definicija': 'Skup dijagnostičkih metoda kojima je moguće utvrditi promene  na fetusu pre rođenja i  utvrditi postojanje hromozomskih aberacija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05275905-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'donja vilica,mandibula',
#    'Definicija': 'donja vilica kod kičmenjaka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09249155-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kolektor',
#    'Definicija': 'krater u kome je prikupljen kosmički materijal koji je pao na zemlju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01687009-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tupinambis,rod Tupinambis',
#    'Definicija': 'teju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07186148-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poziv',
#    'Definicija': 'Izgovoren ili pisani zahtev da se učestvuje ili da se bude prisutna na nečemu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08064130-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odbrana',
#    'Definicija': 'Organizacija branilaca koja obezbeđuje otpor protiv napada.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01073995-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ometanje',
#    'Definicija': 'Čin ometanja, sprečavanja ili zadržavanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01819115-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kakadu',
#    'Definicija': 'Papagaj sa krestom iz Australije, beo ili živih boja; često se gaji u kavezu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14482620-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'potencijal',
#    'Definicija': 'Urođeni kapacitet za nastanak nečega.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05220461-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'deo tela',
#    'Definicija': 'Bilo koji deo organizma, kao što su organ ili ekstremitet.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14646942-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'niobijum,Nb,atomski broj 41',
#    'Definicija': 'mekan, sivi metal koji se koristi u legurama; ranije se zvao kolumbijum',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09724785-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Nigerijac',
#    'Definicija': 'stanovnik Nigerije ili poreklom iz Nigerije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10452432-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mnogoženac',
#    'Definicija': 'čovek koji istovremeno ima više žena',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02170269-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Dermestidae,porodica Dermestidae',
#    'Definicija': 'kožuškari',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02766534-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dečja kolica',
#    'Definicija': 'malo vozilo na četiri točka u kome se voze bebe',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02992211-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čelo,violončelo',
#    'Definicija': 'Veći žičani instrument, manji od kontrabasa; drži se između kolena; ton mu odgovara čovečjem glasu; solistički instrument.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02744451-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'priuštiti',
#    'Definicija': 'imati finansijska sredstva za nešto, ili kupiti nešto',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03083842-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'malteški',
#    'Definicija': 'koji se tiče ostrva ili države Malte i njenih ljudi',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-03109881-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ugao,ćošak',
#    'Definicija': 'unutrašnji ugao koji obrazuju dva susedna zida',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07919055-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Tom and Jeri piće',
#    'Definicija': 'vruć rum sa mućenim jajima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01693334-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zelembać,Lacerta viridis',
#    'Definicija': 'Običan evroazijski gušter, oko stopu dugačak.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03877845-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dvorac',
#    'Definicija': 'zvanična rezidencija neke uvaxene osobe',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05700087-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'preokupiranost,zaokupljenost',
#    'Definicija': 'Stanje duha u kome ste nečim preokupirani.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01448951-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'topminnow,poeciliid fish,poeciliid,live-bearer',
#    'Definicija': 'small usually brightly-colored viviparous surface-feeding fishes of fresh or brackish warm waters; often used in mosquito control',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10103485-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stranac,neznanac,tuđinac',
#    'Definicija': 'osoba koja dolazi iz strane zemlje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01202184-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'aparthejd,odvajanje,razdvajanje,segregacija,separatizam',
#    'Definicija': 'čin segregacije ili razdvajanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06811283-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'heksadecimalna notacija',
#    'Definicija': 'notacija koja koristi 16 različitih simbola',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12098227-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Plumbago',
#    'Definicija': 'Grmlje, zeljaste biljke i povijuše toplih predela: vranemil.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07806879-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Cezar salata',
#    'Definicija': 'obično se sastoji od prženih krutona sa prelivom od sirovih jaja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10189776-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'domaćica,gazdarica',
#    'Definicija': 'supruga koja se stara o kući dok joj muž zarađuje za porodicu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02164531-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'blenuti,zevati,zijati',
#    'Definicija': 'Gledati sa čuđenjem; gledati glupavo.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00414823-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'iščašiti,dislocirati',
#    'Definicija': 'Pomeriti iz položaja; o zglobovima.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08890097-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Škotska',
#    'Definicija': 'Jedna od četiri države koje čine Ujedinjeno Kraljevstvo Velike Britanije i Severne Irske; smeštena na severnom delu ostrva Velika Britanija; poznata po gajdama i kiltovima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01562584-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Sylviidae,porodica Sylviidae,grmuše',
#    'Definicija': 'U nekim klasifikacijama smatra se podporodicom (Sylviinae) porodice Muscicapidae: maslinica, ??',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14717275-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bronza',
#    'Definicija': 'legura bakra i kalaja i ponekad još nekih elemenata',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03453809-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'likovna umetnost',
#    'Definicija': 'Umetnost crtanja ili slikanja ili štampanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05554189-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mlečna žlezda',
#    'Definicija': 'Organ ženke sisara koji luči mleko kojim se hrane mladunci.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00683771-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'biti saglasan,držati,smatrati',
#    'Definicija': 'tvrditi ili potvrditi',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02091410-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'koraknuti,kročiti',
#    'Definicija': 'Spustiti nogu, smestiti nogu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03509025-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sistem za grejanje,grejanje',
#    'Definicija': 'aparat koji greje zgradu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13139055-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'komuška,komusixna,mahuna',
#    'Definicija': 'Plod s većim brojem semenki koje su odeljene u dva pretinca.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00185438-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'karlični porođaj,izlazak deteta iz materice u obrnutom položaju',
#    'Definicija': 'Karlični položaj je položaj bebe u materici zadnjicom ili nogama nadole, odnosno kada se u donjem delu materice napipavaju zadnjica ili noge ploda, i sreće se prosečno kod 3-4 odsto žena. Samim tim dolazi do karličnog porođaja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02319824-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poskupiti',
#    'Definicija': 'Povećati cenu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06309931-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'subjekat,subjekt',
#    'Definicija': '(gramatika) jedan od dva glavna rečenična konstituenta o kojem se nešto kazuje putem predikata',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09161803-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Venecuela,Bolivarska Republika Venecuela',
#    'Definicija': 'VE',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05316175-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'okularni  mišić',
#    'Definicija': 'Jedan od malih mišića oka koji služe za rotiranje očne jabučice.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02499700-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Galago',
#    'Definicija': 'galago',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06345441-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tekući naslov,zaglavlje',
#    'Definicija': 'naziv (ili skraćeni naslov) knjige korišćen u zaglavlju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01540233-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'batokljunac',
#    'Definicija': 'vrsta zebe iz Evrope ili Amerike sa velikim i snažnim kljunom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05425910-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kapilar',
#    'Definicija': 'Bilo koji od malih krvnih sudova.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06958417-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vepski,vepsijski',
#    'Definicija': 'finski jezik kojim govore Vepsi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08292756-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ratna flota',
#    'Definicija': 'Grupa ratnih brodova koja se organizuje kao taktička jedinica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04764412-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'generalnost,opštost',
#    'Definicija': 'kvalitet da je šta opšte ili široko rasprostranjeno ili da ima opštu primenljivost',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07663360-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'saće škembići',
#    'Definicija': 'Sluznica retikuluma (ili drugog želudca) preživara koja se koristi u ishrani',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02483362-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'beloruki gibon,Hylobates lar',
#    'Definicija': 'Najmanji čovekoliki majmun koji živi na drvetu ima duge ruke i nema rep.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03276179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'elektromagnet',
#    'Definicija': 'privremeni magnet napravljen od žice obmotane oko gvozdenog jezgra; kada struka prolazi kroz žicu, gvožđe postaje magnet',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01762525-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod artropoda',
#    'Definicija': 'Rod artropoda.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07832416-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pesto,pesto sos',
#    'Definicija': 'sos koji se po pravilu služi s testeninom; sdrži seckani list bosiljka, beli luk, pinjole, sir parmezan i maslinovo ulje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13840553-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odnos nastavnik i studenta',
#    'Definicija': 'Akademski odnos između nastavnika i njihovih studenata.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02018049-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'penjati se na,popeti se na,ući u,ukrcati se,ukrcavati se,ulaziti u',
#    'Definicija': 'ući u (voz, autobus, brod, letelicu itd)',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08790353-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Arkadija',
#    'Definicija': 'grčki departman u centralnom Peloponezu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00023271-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'saznanje',
#    'Definicija': 'Psihološki rezultat opažanja i učenja i rezonovanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02205896-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Hymenoptera,red Hymenoptera',
#    'Definicija': 'Red insekata koji uključuje pčele,ose, mrave; itd.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12015959-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zlatnica',
#    'Definicija': 'Biljke iz roda Solidago koje cvetaju uglavnom u leto i jesen.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08920381-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Japanski arhipelag',
#    'Definicija': 'niz od više od 3000 ostrva istočno od Azijskog kopna, imzeđu Japanskog mora i zapadnog Pacifika',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07874343-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pica sa inćunima',
#    'Definicija': 'pica sa paradajzom, sirom i inćunima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12567768-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Robinia,rod Robinia',
#    'Definicija': 'Listopadno drveće i žbunje koje cveta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07909811-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'liker od pomorandže',
#    'Definicija': 'liker sa ukusom pomorandže',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02727883-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prodavati se',
#    'Definicija': 'Biti prodavan za određenu cenu ili na određeni način.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04499300-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tursko kupatilo',
#    'Definicija': 'parno kupatilo sa dodatnim mogućnostima za tuširanje i masažu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02110958-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mops',
#    'Definicija': 'Mali čvrsti pas glatke dlake, poreklom iz Azije; ima uvijen rep i široku naboranu njušku.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09549416-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Hijade',
#    'Definicija': 'u grčkoj mitologiji sedam kćeri Atlasa, polusestre Plejada; one su hranile bebu Dionisa pa ih je Zevs za nagradu stavio među zvezde',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01940736-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mekušac,moluska',
#    'Definicija': 'Beskičmenjak koji ima meko nesegmentirano telo koje je obično zatvoreno u oklop.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03375694-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'folija',
#    'Definicija': 'Komad tankog i fleksibilnog metalnog lista.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06352117-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'armenijski alfabet',
#    'Definicija': 'pismo od 38 slova kojim je zapisan armenijski jezik',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09315159-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jon',
#    'Definicija': 'naelektrisani atom ili grupa atoma; jonsko naelektrisanje potiče od gubitka ili dobitka elektrona',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12345136-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Punica,rod Punica',
#    'Definicija': 'Podudara se sa familijom Punicaceae.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02380583-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mustang',
#    'Definicija': 'Konj uvezen iz Evrope u Ameriku gde je ponovo postao divlji.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01742172-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zmijski car,Constrictor constrictor',
#    'Definicija': 'Veoma velika boa tropske Amerike i Brazila.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12359952-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Begonia',
#    'Definicija': 'Velikii rod sočnih tropskih biljaka koje se široko gaje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07779747-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'morski đavo',
#    'Definicija': 'vrsta ribe morski đavo sa velikom glavom; nalazi se u severozapadnom Atlantiku',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02419773-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'crnčiti,rintati,kulučiti,tegliti,konjosati,dirinčiti',
#    'Definicija': 'Teško raditi.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03080492-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'romanski',
#    'Definicija': 'koji se odnosi na judi koji govore romanskim jezicima',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-12441958-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pečak,bren',
#    'Definicija': 'Neka od mnogih pretežno mediteranskih biljaka iz rodova Asphodeline i Asphodelus koje imaju pravo lišće i grozdaste cvati belik, ružičastih ili žutih cvetova.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06613056-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'navod,citat',
#    'Definicija': 'pasaž ili izraz koje se navodi ili citira',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06912638-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'koasati',
#    'Definicija': 'muskogijski jezik kojim govori narod Koasati',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07131169-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'homofon',
#    'Definicija': 'Dve reči su homofoni ako se izgovaraju isto ali imaju različito značenje i/ili se pišu različito.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02417663-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bezoarka,Capra aegagrus',
#    'Definicija': 'Divlja koza iz Irana i susednih predela.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06500448-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fonetski alfabet',
#    'Definicija': 'alfabet koji čine karakteri koji treba da predtave specifične glasove govora',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07663592-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'govedina,goveđe meso',
#    'Definicija': 'meso odraslog domaćeg govečeta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10237069-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rođaka,rođakinja',
#    'Definicija': 'Ženski rođak.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12260593-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Fagus,rod Fagus',
#    'Definicija': 'Bukva.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13698327-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'katarski rijal,QAR',
#    'Definicija': 'osnovna novčana jedinica Katara',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02683840-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'obustaviti se,obustavljati se,prekidati se,prekinuti se,prestajati,prestati,stati,zaustaviti se,zaustavljati se',
#    'Definicija': 'dolaziti ili biti na kraju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-09004068-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Moskva,prestonica Rusije,glavni grad Rusije',
#    'Definicija': 'Grad u centralnoj evropskoj Rusiji; bivša prestonica i Sovjetskog Saveza i Sovjetske Rusije; od 1991. godine je prestonica Ruske Federacije.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07186828-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'apel',
#    'Definicija': 'iskren ili hitan zahtev',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14680514-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'magnezit',
#    'Definicija': 'crni magnetni mineral koji se sastoji od magnezijum karbonata',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01699831-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dinosaurus',
#    'Definicija': 'Neki od mnogobrojnih izumrlih suvozemnih gmizavaca iz ere Mezozoika.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02346998-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bodljivac',
#    'Definicija': 'Bodljivac Starog sveta živi na zemlji ili pod zemljom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13558490-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sorpcija',
#    'Definicija': 'međusobno inkorporiranje materija, upijanje materija jednu uz drugu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11815194-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Silene',
#    'Definicija': 'Veliki rasprostranjeni ro biljaka sa raznobojnim upadljivim cvećem: pucavac.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00217152-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poplaviti,preplaviti,potopiti,plaviti',
#    'Definicija': 'prekriti tečnošću, obično vodom',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02327200-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'snabdeti,dobaviti',
#    'Definicija': 'Snabdeti nečim ili dobaviti nešto.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-13805179-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'durativnost,nesvršenost',
#    'Definicija': 'vid glagola kojim se izražava imperfektivnost neke radnje s akcentom na njenom trajanju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00023100-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'psihičko svojstvo,mentalna osobina',
#    'Definicija': 'Svojstvo mentalnog života živog organizma.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02510769-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'škrge',
#    'Definicija': 'Respiratorni organ vodenih životinja koje udišu kiseonik iz vode.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00325328-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pržiti',
#    'Definicija': 'Kuvati na vreloj površini koristeći masnoću.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01356459-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Bacillaceae,porodica Bacillaceae',
#    'Definicija': 'tipične štapičaste obično grampozitivne bakterije koje proizvode endospore',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00699815-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odrediti,ustanoviti',
#    'Definicija': 'Utvrditi konačno ili merodavno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02480673-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Gorilla',
#    'Definicija': 'Gorile',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06839858-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fonetski simbol',
#    'Definicija': 'pisani karakter koji se u fonetskoj transkripciji koristi za označavanje određenog glasa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05980875-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'cilj',
#    'Definicija': 'Stanje stvari koje neki plan treba da postigne i koje, kada bude ostvareno, završava ponašanje koje je do njega dovelo.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06957524-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'baltičko-finski jezici,balto-finski jezici,baltsko-finski jezici',
#    'Definicija': 'grupa finskih jezika koja sadrži finski i estonski',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02124096-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izdržljiv,nepoderiv',
#    'Definicija': 'podesan za dugotrajno korišćenje, nošenje i trošenje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-08759684-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Porto Novo,glavni grad Benina,prestonica Benina',
#    'Definicija': 'glavni grad Benina, na jugozapadu zemlje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10649962-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'državni javni tužilac,republički javni tužilac',
#    'Definicija': 'Javni tužilac jede države.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02169891-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slušati',
#    'Definicija': 'osluškivati sa namerom',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02477755-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'otkazati,otkazivati,poništiti',
#    'Definicija': 'šta na neodređeno vreme odložiti ili šta što je bilo zakazano poništiti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06924895-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'maidu,pudžunski',
#    'Definicija': 'penutski jezik kojim govori narod Maidu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07704305-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'retka kaša',
#    'Definicija': 'retka kaša ili supa (često ovsena kaša i voda začinjema mesom)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07640844-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'blini',
#    'Definicija': 'Ruske palacinke koje se prave od heljdinog brašna i kvasca; obično se služe sa kavijarom i kiselom pavlakom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00916464-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'poljoprivreda',
#    'Definicija': 'Praksa obrade zemlje ili gajenja stoke.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07734183-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'paradajz jabučar',
#    'Definicija': 'veliki crveni paradajz čvrstog mesnatog sadržaja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07918706-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'svizl',
#    'Definicija': 'vrsta penušavog mešanog pića koje se najčešće pravi od ruma, soka od lajma i šećera, promućkano sa ledom, u visokoj čaši',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13804085-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'konjugacija,glagolska promena',
#    'Definicija': 'fleksija glagola',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02180529-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oglašavati,oglasiti',
#    'Definicija': 'kakvim zvukom najavljivati',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02083038-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Canidae,familija Canidae,psi',
#    'Definicija': 'Psi, vukovi, šakali i lisice.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02376542-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ždrebe',
#    'Definicija': 'mladunče konja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06963292-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'narodni latinski,niski latinski',
#    'Definicija': 'bilo koji neklasični dijalekat latinskog',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07777735-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'velikousti bas,velikousti pastrmski grgeč',
#    'Definicija': 'slatkovodna riba koja je u naše krajeve stigla sa severnoameričkog kontinenta',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12607198-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Ananas,rod Ananas',
#    'Definicija': 'Rod propske američke biljke, sa sabljastim lišćem i mesnatim plodom koji se dobija od ploda više cvetova.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14362373-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'atrijalna fibrilacija,treperenje pretkomora,fibrillatio cordis',
#    'Definicija': 'Stanje kada deo srčane muskulature treperi umesto da izvodi, kao normalno, kontrakcije. Može se lokalizovati u pretkomorama ili u komorama.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00232386-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'otkaz',
#    'Definicija': 'Čin otkazivanja; opozivanje nekog dogovora.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13591761-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'broj',
#    'Definicija': 'Ukupno izbrojana veličina.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02635499-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'opšti,zajednički',
#    'Definicija': 'koji se odnosi na ili se tiče ili se koristi kao zajednička imenica',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-03007130-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kapela',
#    'Definicija': 'mesto bogosluženja koje ima svoj oltar',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06078511-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'neurobiologija',
#    'Definicija': 'grana biologije koja se bavi anatomijom, fiziologijom i patologijom nervnog sistema',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06304576-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'govor',
#    'Definicija': 'reč koja se govori naglas',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07643764-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'marmelada',
#    'Definicija': 'Ukuvano voće napravljeno od njihovog mesa i kore.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10566072-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'skulptor,vajar',
#    'Definicija': 'Umetnik koji pravi skulpture.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09500003-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Belerofont',
#    'Definicija': 'u grčkoj mitologiji mitski korintski junak koji je izvodio čuda na krilatom konju Pegazu (ubio je čudovište Himeru)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05898568-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'plan',
#    'Definicija': 'Niz koraka koje treba učiniti ili ciljeva koje treba postići.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06270541-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'novo izdanje,izmenjeno izdanje',
#    'Definicija': 'izdanje (kao npr. knjiga) koje je izmenjeno ili dopunjeno i stavljeno u prodaju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02750377-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'međupršljenski',
#    'Definicija': 'koji se odnosi na prostor između dva pršljena',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01489332-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oslobađati,osloboditi,otpuštati,otpustiti',
#    'Definicija': 'oduzeti kakvo zaduženje od koga',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03087909-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mongoloidni',
#    'Definicija': 'koji je karakterističan za ili podseća na Mongola',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00370261-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odsecanje',
#    'Definicija': 'čin kojim se nešto smanjuje sečenjem krajeva',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12869248-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Teucrium,rod Teucrium',
#    'Definicija': 'Veliki rasprostranjeni rod višegodišnjih biljaka i žbunja; od Mediterana do zapadne Azije.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09904837-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'centrist,moderat,umerenjak',
#    'Definicija': 'osoba čije političke pozicije odgovaraju političkom centru',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05137165-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'visina',
#    'Definicija': 'Vertikalna dimenzija, udaljenost od osnove do vrha nečega.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12557681-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'skerletni pasulj,Phaseolus coccineus,Phaseolus multiflorus',
#    'Definicija': 'Tropski američki visokopenjajući pasulj sa crvenim cvećem i prošaranim crnim zrnom; najčešće korišćeni pasulj u Velikoj Britaniji.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02931417-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'diskoteka,kabare,klub,noćni klub',
#    'Definicija': 'mesto koje je otvoreno do kasno noću i koji pruža zabavu (npr. pevače ili plesače), kao i ples, hranu i piće',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03122748-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pokrivač,omotač',
#    'Definicija': 'Tvorevina kojom se nešto pokriva, obično da bi se ono zaštitilo ili sakrilo.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08965958-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Bamako,prestonica Malija,glavni grad Malija',
#    'Definicija': 'glavni grad Malija, na reci Niger',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03533972-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'alka,karika,prsten',
#    'Definicija': 'čvrsti okrugli pojas od metala ili drveta ili drugog materijala koji se koristi za drxanje ili vezivanje ili vešanje ili vuču',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07739506-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jabuka za jelo,dezertna jabuka',
#    'Definicija': 'jabuke koje se najčešće jedu nekuvane i nepečene',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01187740-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izgladneti,umoriti glađu',
#    'Definicija': 'Lišiti hrane.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07919310-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fiz',
#    'Definicija': 'šumeće piće (obično alkoholno)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13437902-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'obrada po partijama',
#    'Definicija': 'serijsko izvršavanje računarskih programa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02582721-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'brama,Brama raii',
#    'Definicija': 'Srebrnasta riba; živi na dubini od oko 900 metara; ima ukusno meso.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03074380-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stub',
#    'Definicija': 'Vertikalna struktura koja samostalno stoji i ništa ne podržava, kao spomenik.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11262574-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Rilke,Rajner Maria Rilke,Rainer Maria Rilke',
#    'Definicija': 'Nemački pesnik (rođen u Austriji) čiji je mistični lirizam uticao na nemačku literaturu 20. veka (1875-1926).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07920222-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'espreso sa mlekom',
#    'Definicija': 'jaka espreso kafa prelivena penom od mleka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08698379-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'afrička zemlja,afrička država',
#    'Definicija': 'Države koje zauzimaju afrički kontinent.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06357424-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'korekcioni kod,ECC',
#    'Definicija': 'u telekomunikacijama, kodni sistem u koji je ugrađen dodatni bit parnosti da bi se otkrila greška',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08896327-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sultanat',
#    'Definicija': 'država kojom upravlja sultan',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00832092-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kardiografija,elektrokardiografija,EKG',
#    'Definicija': 'Dijagnostička procedura koja prati rad srca. Eletrokardiografijom se korišćenjem aparata elektrokardiograma prate električni impulsi srca i dobija crtež elektrokardiograf  - EKG.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01419444-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rod Costia',
#    'Definicija': 'rod bičarskin protocista',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01321230-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mužjak',
#    'Definicija': 'Bilo koja životinja koja proizvodi polne ćelije (spermatozoide) koji mogu da oplode žense polne ćelije (jaja).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03600977-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'spajalica,spoj,spojnica,zglob',
#    'Definicija': 'spoj kojim su delovi ili predmeti spojeni ',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06292836-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hiperonim',
#    'Definicija': 'Reč koja je opštija od date reči.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08641113-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'susedstvo,blizina',
#    'Definicija': 'Regija u okruženju ili u blizini.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07452074-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'svadba',
#    'Definicija': 'Društvena prilika u kojoj se vrši ceremonija sklapanja braka.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07770289-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kisela tikva',
#    'Definicija': 'kiselkasto australijsko voće nalik na tikvu sa drvenkastom korom i velikim semenkama',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02963272-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kirgistanski,kirgijski,kirgiški',
#    'Definicija': 'koji se tiče Kirgistana, njegovih ljudi i kulture',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-08163792-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zbor',
#    'Definicija': 'grupa ljudi koja se okupila zbog nekog zajedničkog cilja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01195804-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'rasuti,tratiti,dokoličiti',
#    'Definicija': 'Trošiti neoprezno i lakomisleno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01856626-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'migrirati,seliti se',
#    'Definicija': 'Premestiti se iz jedne države ili regiona u drugi i nastaniti se tamo.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02056728-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'veliki pingvin,veliki tučnjak,Aptenodžtes forsteri',
#    'Definicija': 'najveći pingvin s Antarktika',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07879450-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'suši',
#    'Definicija': 'pirinač sa sirovom ribom umotan u morsku travu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02263378-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mrežokrilac',
#    'Definicija': 'insekt sa dva para krilaca u kojima se razabira mrežast splet žilica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06171040-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lingvistika',
#    'Definicija': 'Naučno izučavanje jezika.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04069276-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'reflektor',
#    'Definicija': 'Uređaj koji reflektuje zračenje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13733818-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'množilac,množenik,multiplikand',
#    'Definicija': 'Broj koji množi drugi broj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06980971-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gondi,gondijski',
#    'Definicija': 'dravidski jezik kojim govore Gondi u južnom delu centralne Indije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05397468-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'telesna tečnost',
#    'Definicija': 'Tečni delovi tela.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01849466-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'morska utva',
#    'Definicija': 'Patka koja nalikuje guski, malo veća od divlje patke, sa šarenim, uglavnom crno-belim perjem i crvenim kljunom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03422589-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': '?gas-discharge tube',
#    'Definicija': 'cev kod koje se električno pražnjenje odvija kroz gas',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03636649-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'lampa',
#    'Definicija': 'komad nameštaja koji sadrži jednu ili više sijalica',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10370381-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'okultista',
#    'Definicija': 'čovek koji veruje u okutizam i koji verziran u okultne postupke',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09423943-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Sargasko more,Sargaško more',
#    'Definicija': 'široko prostranstvo u severnom Atlantiku u kome su jake okeanske struje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03071374-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gvajanski',
#    'Definicija': 'koji se tiče Gvajane, njenih stanovnika i kulture',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00249852-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sazreti,dozreti,prispeti',
#    'Definicija': 'Postati zreo.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06978656-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'abhaski',
#    'Definicija': 'čerkeski jezik kojim govore Abhazi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01297484-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Termopilska bitka',
#    'Definicija': 'čuvena bitka koja se oigrala 480 p.n.e. između Grka i Persijanaca u kojoj se proslavio Spartanac Leonida',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02117135-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hijena',
#    'Definicija': 'životinja iz reda averova koja se hrani strvinom i zudara.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09733243-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Španac,Španjolac',
#    'Definicija': 'ljudi Španije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02238085-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dobiti',
#    'Definicija': 'Doći u posed nečega.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-05581693-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'nokat',
#    'Definicija': 'rožnata ploča koja pokriva i štiti dorzalni deo prstiju',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02511303-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'škržni luk',
#    'Definicija': 'jedan od koštanih ili rskavičavih lukova sa svake strane ždrela koji podržavaju škrge riba i vodenih vodozemaca',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07915491-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'džulep,džulep od mente',
#    'Definicija': 'burbon, šećer i menta preko mrvljenog leda',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10241300-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fizički radnik',
#    'Definicija': 'radnik koji posao obavlja svojim rukama',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01541579-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'liti,proliti,prolivati,prosipati,prosuti,razliti,razlivati',
#    'Definicija': 'uzrokovati ili dozvoliti da (kakva čvrsta supstanca) teče ili istekne ili pretekne',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06069886-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pomologija',
#    'Definicija': 'grana botanike koja se bavi pročavanjem i gajenjem voća',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00594621-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'znati',
#    'Definicija': 'Biti svestan neke činjenice ili određene informacije; imati znanje ili informaciju o nečemu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-09786338-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'alumnus,diplomac',
#    'Definicija': 'osoba koja je stekla diplomu neke škole (srednje škole, koledža ili fakulteta)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00962722-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'revolucija',
#    'Definicija': 'Svrgavanje vlade od strane podanika.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07851926-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'topljeni sir',
#    'Definicija': 'sir pravljen mešanjem više sira',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06410655-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kritika,kritika knjige,prikaz,prikaz knjige,recenzija',
#    'Definicija': 'kritički prikaz knjige (obično nedavno objavljene knjige)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01013040-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zakleti se',
#    'Definicija': 'Dati izjavu pod zakletvom; izjaviti pod zakletvom.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02306462-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'naplatiti',
#    'Definicija': 'Zaračunati i prikupiti zaračunati novac.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-11896365-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Sinapis,rod Sinapis',
#    'Definicija': 'Mali rod zeljastih biljaka iz starog sveta, obično uključuje i rod Brassica.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13674350-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'američki dolar,USD,dolar,zelena novčanica',
#    'Definicija': 'osnovna novčana jedinica u SAD-u',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00151855-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gluvonem,nem',
#    'Definicija': 'koji ne može da govori zbog urođene gluvoće',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02373785-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'istaknuti se,afirmisati se',
#    'Definicija': 'iskazati se: insistirati da se sopstvena mišljenja i prava poštuju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08286163-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'univerzitet',
#    'Definicija': 'fakultet i studenti na univerzitetu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12711596-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'limun,Citrus limon',
#    'Definicija': 'Malo zimzeleno drvo poreklom iz Azije koje se veoma gaji zbog svog ploda.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15123996-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'istorija,povest',
#    'Definicija': 'Kontinuitet događaja koji se sukcesivno dešavaju od prošlosti do sadašnjosti i vode čak u budućnost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02175057-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čegrtati',
#    'Definicija': 'Proizvoditi kratke uzastopne zvukove.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00903559-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'fotografisanje',
#    'Definicija': 'Čin pravljenja fotografija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07816164-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bosiljak,bazilika',
#    'Definicija': 'Lišće bosiljka koje se upotrebljava sveže i suvo.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02824858-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zvono',
#    'Definicija': 'Široki otvor cevastog predmeta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07112364-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'diftong,dvoglasnik',
#    'Definicija': 'samoglasnički zvuk čiji izgovor počinje blizu artikulacionog položaja za jedan samoglasnik, pa se okrene prema položaju za drugi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09328746-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'laguna',
#    'Definicija': 'vodena površina odvojena od veće površine peščanim ili koralnim sprudom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10897312-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Čerčil,Vinston Čerčil,Churchill,Winston Churchill,Winston S. Churchill,Sir Winston Leonard Spenser Churchill',
#    'Definicija': 'Britanski državnik i lider za vreme Drugog svetskog rata; dobio Nobelovu nagradu za literaturu 1953. godine (1874-1965).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00303661-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'proširti',
#    'Definicija': 'napraviti širim',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02389128-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'đogat',
#    'Definicija': 'konj belac',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02206624-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Apoidea,superporodica Apoidea',
#    'Definicija': 'Pčele.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02046916-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'parabolički,parabolični',
#    'Definicija': 'koji ima oblik parabole',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-10472274-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prvorotka',
#    'Definicija': 'U akušerstvu, žena koja se porodila po prvi put.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10741493-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'urolog',
#    'Definicija': 'Specijalista za urologiju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08719100-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Šri Lanka,Demokratska Socijalistička Republika Šri Lanka,Cejlon',
#    'Definicija': 'Republika na ostrvu Cejlon; postala nezavisna od Ujedinjenog Kraljevstva 1948. godine.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06302381-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kvantifikator',
#    'Definicija': 'U gramatici reč pomoću koje se izražava količina, kao "petnaest" i "mnogi".',
# ...
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Piperales,red Piperales',
#    'Definicija': 'Piperaceae; Saururaceae; Chloranthaceae.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13943400-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slučaj',
#    'Definicija': 'poseban splet okolnosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03046349-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bangladeški',
#    'Definicija': 'koji se odnosi na Bangladeš, njegove ljude ili jezik',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-03069643-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gotički,gotski',
#    'Definicija': 'koji se odnosi na jezik drevnih Gota',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04328946-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'skladišni prostor',
#    'Definicija': 'bilo koja građevina koja daje prostor za skladištenje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00235368-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ograničiti',
#    'Definicija': 'Postaviti ograničenje.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00104868-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'izbaciti,izrigati,izbljunuti',
#    'Definicija': 'izbaciti telesne tvari',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-08110373-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vrsta',
#    'Definicija': 'Klasifikaciona grupa čiji članovi mogu da se razmnožavaju između sebe (biologija).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02055803-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pingvin',
#    'Definicija': 'Ptica hladnog, posebno arktičkog, područja koja ne leti ali vešto pliva, ima kratke noge, krila su modifikovana u peraje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05989479-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'teorija',
#    'Definicija': 'Dobroutemeljeno objašnjenje nekog aspekta pirodnog sveta; organizovani sistem priznatog znanja koji se može primeniti u različitim okolnostima da bi se objasnio specifični skup fenomena.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07665713-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'teleći vrat,kraj telećeg vrata',
#    'Definicija': 'tanak kraj telećeg vrata',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06927952-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čuvaški,čuvaš',
#    'Definicija': 'turkijski jezik kojim govore Čuvaši',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-15075141-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'toaletni papir,toalet papir',
#    'Definicija': 'meki upijajući papir koji se koristi u toaletima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06255777-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'list papira,list',
#    'Definicija': 'Koristi se za pisanje ili štampanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01054545-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bivanje,boravljenje',
#    'Definicija': 'čin stalnog ili privremenog bivanja na nekom mestu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06327551-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'relativna zamenica,odnosna zamenica',
#    'Definicija': "zamenica (kao 'koji' ili 'čiji') kojom se odnosna rečenica uvodi u imeničku sintagmu, pri čemu upućuje na centar te sintagme",
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04221823-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'simulator',
#    'Definicija': 'mašina koja simulira neko okruženje radi obuke ili istraživanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12123741-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'osjača,popino prase,Hordeum murinum',
#    'Definicija': 'Vrsta ječma, divlji jeyam.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13730584-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'iracionalni broj',
#    'Definicija': 'realni broj koji se ne može pretstaviti u obliku razlomka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11630017-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kedar,cedar',
#    'Definicija': 'drvo iz porodica Cupressaceae',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14450691-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'neophodnost,nužda',
#    'Definicija': 'Stanje u kome je nešto važno ili preko potrebno.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00845523-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'seksualni odnos,seksualni čin,koitus,kopulacija',
#    'Definicija': 'fizički odnos između muškarca i žene',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11492014-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'polarizacija',
#    'Definicija': 'Pojava pri kojoj se talasi svetlosti ili drugog zračenja ograničavaju u smeru vibracija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11825351-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tratorak,petlova kresta,Celosia cristata,Celosia argentea cristata',
#    'Definicija': 'Godišnja baštenska biljka sa crvenim ili žutim cvetovima ukupljenim u svasti koje nalikuju perima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02840619-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'povez,omot,korica',
#    'Definicija': 'prednja i zadnja korica knjige',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-08756735-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Kipar',
#    'Definicija': 'ostrvo u istočnom Mediteranu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07770571-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jestivo seme',
#    'Definicija': 'Seme koje se uglavnom koristi kao začin.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13705674-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'indonežanska rupija,IDR',
#    'Definicija': 'osnovna novčana jedinica Indonezije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00637354-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'istraga',
#    'Definicija': 'istraživanje koje traži odgovore',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01720642-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ortogonalan,pravougaoni',
#    'Definicija': 'koji ima skup uzajamno norlanih osa; seče se pod pravim uglom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00628491-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'razmišljati',
#    'Definicija': 'Koristiti um ili nečiju sposobnost da rezonuje da bi se zaključivalo, odlučivalo, ili dolazilo da rešenja i sudova.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07904637-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'džin od trnjina',
#    'Definicija': 'džin s ukusom trnjine, divlje šljive',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01912152-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'hidra',
#    'Definicija': 'Slatkovodni polip iz kola dupljara.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02690809-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dušek na naduvavanje',
#    'Definicija': 'dušek koji može da se naduva, a kda se ne koristi onda se izduva i tako čuva',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05385534-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jetra,Hepar',
#    'Definicija': 'Veliki i komplikovan crvenkasto-braon žlezdani organkoji se  nalazi u gornjem desnom delu trbušne duplje. Luči žuč i ima funkcije u metabolizmu proteina,ugljenih hidrata i masti. Sintetiše supstance uključene u zgrušavanje krvi, vitamin A, detoksifikuje otrovne supstance i razgrađuje  eritrocita koji su nefunkcionalni.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07968702-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'interesna grupa',
#    'Definicija': 'Obično u množini, društvena grupa čiji članovi kontrolišu neko polje rada i koji imaju zajedničke ciljeve.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01351170-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'iščupati,počupati,opleviti',
#    'Definicija': 'Izvaditi nešto, obično sa snagom ili naporom; koristi se i u prenesenom značenju.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-03045992-a',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'bahamski',
#    'Definicija': 'koji se tiče Bahamskih ostrva i njihovih stanovnika',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-03925226-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'slajd,dijapozitiv,fotografija',
#    'Definicija': 'slika osobe ili prizora u štampanom ili providnom obliku; snimljena kamerom na fotoosetljivom materijalu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03563967-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'oruđe,rekvizit',
#    'Definicija': 'Instrument, npr. deo opreme ili alata, koji se koristi da bi se nešto obavilo.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02708711-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'analizator',
#    'Definicija': 'instrument koji obavlja analize',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01873982-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': '?metatherian',
#    'Definicija': 'Primitivni ?pouched sisari, ima ih uglavnom u Australiji i Americi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07831955-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sos od hleba',
#    'Definicija': 'kremasti beli sos koji sadrži hleb umesto brašna, začinjen karanfilićem i crnim lukom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-09699403-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Čeh',
#    'Definicija': 'stanovnik Ceške ili poreklom iz Češke',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05198427-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'jurisdikcija',
#    'Definicija': '(pravo) pravo i ovlašćenje za tumačenje i primenu zakona',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01033903-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mala služba',
#    'Definicija': 'Rimska katolička služba obožavanja Device Marije, slična ali kraća u odnosu na božansku službu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02944459-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kamuflaža',
#    'Definicija': 'sredstvo ili strategija za prikrivanje ili prevaru',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04020298-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kotur',
#    'Definicija': 'jednostavna mašina koja se sastoji od točka sa žljebom u kome se konop može pokrenuti da promijeni pravac ili tačku primjene sile koja se nanosi na konopac',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00528397-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'umetnički ples',
#    'Definicija': 'Predstava koja uključuje umetnički ples',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07634406-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mramorni kolač',
#    'Definicija': 'pravi se od lagane i tamne smese',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01841679-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'vijoglavka,mravinac,zmajica,zmijoglava,Jynj torquilla',
#    'Definicija': 'detlić iz Starog sveta koji ima neobičnu naviku da uvrće vrat',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06940854-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'atajalski',
#    'Definicija': 'jezik kojim govore Maležani na Formozi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02511510-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'peristom,ivica usta,obušće',
#    'Definicija': 'oblast oko usta kod raznih beskičmenjaka',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11818069-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mišjakinja,Stellaria media',
#    'Definicija': 'Rasprostranjenja niska jednogodišnja korovska biljka čija cvetna krunica liči na zvezdu.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01692864-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'pravi gušter',
#    'Definicija': 'Gušter iz starog sveta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05859991-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sadržalac',
#    'Definicija': 'proizvod veličine celim brojem',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01932936-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trihina,vlasac,Trichinella spiralis',
#    'Definicija': 'Parazitski crv koji se javlja u crevina svinja, pacova i l ljudil proizvodi larve koje obrazuju ciste u skeletnim mišićima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12501202-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tamarind,indijska urma,Tamarindus indica',
#    'Definicija': 'Dugovečno tropsko zimzeleno drvo sa raširenom koršnjom i perastim zimzelenim lišćem i mirisnim cvećem; ime žćkasto tvrdo drvo; rađa izdužene jestive plodove čokoladne boje sa kiselim mesom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12009250-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Santolina,rod Santolina',
#    'Definicija': 'Rod mediteranskog žbunja čiji cvetovi nemaju zrakaste glavice.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00104409-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kotrljanje',
#    'Definicija': 'Čin kotrljanja nečega (kao loptu u kuglanju).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02352591-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'puh,puhać',
#    'Definicija': 'Mali glodar iz Starog sveta koji nalikuje veverici i ima krzneni rep koji spava zimskim snom u hladnoj vodi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07729000-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'južnoamerički pasulj',
#    'Definicija': 'Široki pljosnati pasulj, nikad se ne jede sirov.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13796779-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'gramatički odnos,gramatička relacija',
#    'Definicija': 'lingvistički odnos koji je uspostavljen gramatičkim sredstvima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01006810-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'dopisivati se',
#    'Definicija': 'razmeniti poruke',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-06933022-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kačinski,kačin',
#    'Definicija': 'tibetsko-burmanski jezici kojima se govori na krajnjem severu Burme i u susednim oblastima Kine i Indije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07751858-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'šljiva renkolada',
#    'Definicija': 'Slatki varijetet šljive, zelen ili zeleno žut.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12960729-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'Botrychium,rod Botrychium',
#    'Definicija': 'Mesečinac.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06963082-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'klasični latinski',
#    'Definicija': 'jezik obrazovanog sveta u starom Rimu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-03929660-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'trzalica',
#    'Definicija': 'mali tanak uređaj (od metala ili plastike ili slonovače) koji se koristi za trzanje gudačkih instrumenata',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10484858-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'tužilac,javni tužilac',
#    'Definicija': 'Državni službenik koji vodi optužnicu u ime države.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13561896-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'stohastički proces',
#    'Definicija': 'statistički proces u kome određene nasumične varijable zavise od promenljivog parametra (koji je obično vreme)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01481647-v',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'zakačiti',
#    'Definicija': 'Staviti pomoću šarke u položaj da se dozvoli slobodno kretanje u jednom pravcu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14651479-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'prometijum,Pm,atomski broj 61',
#    'Definicija': 'mekan srebrnkast metal iz grupe retke zemlje bey stabilnog iyotopa; pronađen u radioaktivnom obliku kao fisioni proizvod uranijuma',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04350905-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'odelo,garnitura',
#    'Definicija': 'skup odevnih predmeta za nošenje na otvorenom, iste tkanine i boje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01894207-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'čekinjasti jež',
#    'Definicija': 'imaju bodlje, čekinje ili svilastu dlaku; žive na Madagaskaru.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12709901-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'mandarina,mandarinka,Citrus reticulata',
#    'Definicija': 'Grm ili alo drvo koje rađa spljošetene okrugle plodove, koji imaju slatko i aromatično meso i tanku žutonarandžastu ili jarkonarandžastu koru koja se može lako odstraniti; poreklom iz jugoistočne Azije.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07917618-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'sling',
#    'Definicija': 'Piće koje se pravi od alkoholnog pića, vode sa šećerom i sokom od limuna ili lajma',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-11636566-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kleka,klek,borovica,smreka,smrča,homar',
#    'Definicija': 'Grm iz porodice čempresa s tvrdim šiljastim iglicama',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05581349-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'ploča',
#    'Definicija': 'bilo koja telesna struktura ili deo nalik na ploču',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06948260-n',
#    'POS': 0.0,
#    'NEG': 0.0,
#    'Lemme': 'kraljevski engleski',
#    'Definicija': 'standardni engleski kojim se govori na jugu Engleske',
#    'Vrsta': 'n'},
#   ...],
#  'iteration': 0}

# %%
df_OBJ2 = pd.DataFrame(defi2["OBJ"])

# %%
df_OBJ2
# Out:
#                      ID  POS  NEG  \
# 0      ENG30-09354984-n  0.0  0.0
# 1      ENG30-02067240-n  0.0  0.0
# 2      ENG30-00090253-n  0.0  0.0
# 3      ENG30-01540090-n  0.0  0.0
# 4      ENG30-01436003-a  0.0  0.0
# ...                 ...  ...  ...
# 19502  ENG30-02488415-n  0.0  0.0
# 19503  ENG30-07420991-n  0.0  0.0
# 19504  ENG30-06971872-n  0.0  0.0
# 19505  ENG30-06813700-n  0.0  0.0
# 19506  ENG30-00941346-v  0.0  0.0
#
#                                                    Lemme  \
# 0      Galaktika,Gospina kruna,Kumova slama,Mlečni pu...
# 1              ulješura,glavata uljarka,Physeter catodon
# 2                                        prijem,primanje
# 3      poljski vrabac,brdski vrabac,dživdžan,Passer m...
# 4                                                 kratak
# ...                                                  ...
# 19502  sveti hulman,Presbytes entellus,Semnopithecus ...
# 19503                                             impuls
# 19504                                        indoiranski
# 19505  notacija s pokretnim zarezom,notacija u pokret...
# 19506                                           izustiti
#
#                                               Definicija Vrsta
# 0      galaksija koja sadrži Sunčev sistem (sastoji s...     n
# 1      Veliki kit sa velikom šupljinom u glavi u kojo...     n
# 2                                          Čin primanja.     n
# 3       mali evroazijski vrabac, manji od domaćeg vrapca     n
# 4      Osnovno prostorno značenje; koji ima malu dužinu.     a
# ...                                                  ...   ...
# 19502  Hulman iz južne Azije, smatra se svetom životi...     n
# 19503  Oštar prolazan talas u normalnom električnom s...     n
# 19504  grana indoevropske jezičke porodice koja sadrž...     n
# 19505  pozicioni brojni sistem kod koga je lokacija d...     n
# 19506                         Izgovoriti ili reći nešto.     v
#
# [19507 rows x 6 columns]

# %%
Synset_Sentiment_set_2.removeSynIDs(rem_obj)
defi3 = Synset_Sentiment_set_2.getDef()
df_OBJ3 = pd.DataFrame(defi3["OBJ"])

# %%
df_OBJ3
# Out:
#                      ID  POS  NEG  \
# 0      ENG30-09354984-n  0.0  0.0
# 1      ENG30-02067240-n  0.0  0.0
# 2      ENG30-00090253-n  0.0  0.0
# 3      ENG30-01540090-n  0.0  0.0
# 4      ENG30-01436003-a  0.0  0.0
# ...                 ...  ...  ...
# 19483  ENG30-02488415-n  0.0  0.0
# 19484  ENG30-07420991-n  0.0  0.0
# 19485  ENG30-06971872-n  0.0  0.0
# 19486  ENG30-06813700-n  0.0  0.0
# 19487  ENG30-00941346-v  0.0  0.0
#
#                                                    Lemme  \
# 0      Galaktika,Gospina kruna,Kumova slama,Mlečni pu...
# 1              ulješura,glavata uljarka,Physeter catodon
# 2                                        prijem,primanje
# 3      poljski vrabac,brdski vrabac,dživdžan,Passer m...
# 4                                                 kratak
# ...                                                  ...
# 19483  sveti hulman,Presbytes entellus,Semnopithecus ...
# 19484                                             impuls
# 19485                                        indoiranski
# 19486  notacija s pokretnim zarezom,notacija u pokret...
# 19487                                           izustiti
#
#                                               Definicija Vrsta
# 0      galaksija koja sadrži Sunčev sistem (sastoji s...     n
# 1      Veliki kit sa velikom šupljinom u glavi u kojo...     n
# 2                                          Čin primanja.     n
# 3       mali evroazijski vrabac, manji od domaćeg vrapca     n
# 4      Osnovno prostorno značenje; koji ima malu dužinu.     a
# ...                                                  ...   ...
# 19483  Hulman iz južne Azije, smatra se svetom životi...     n
# 19484  Oštar prolazan talas u normalnom električnom s...     n
# 19485  grana indoevropske jezičke porodice koja sadrž...     n
# 19486  pozicioni brojni sistem kod koga je lokacija d...     n
# 19487                         Izgovoriti ili reći nešto.     v
#
# [19488 rows x 6 columns]

# %%
df_OBJ3[df_OBJ3["ID"]=="ENG30-05528604-n"]
# Out:
# Empty DataFrame
# Columns: [ID, POS, NEG, Lemme, Definicija, Vrsta]
# Index: []

# %%
df_OBJ3['Vrsta'].value_counts()
# Out:
# n    16349
# v     2083
# a     1056
# Name: Vrsta, dtype: int64

# %%
positive_seed_IDS = ["ENG30-01828736-v",
                     "ENG30-13987905-n",
                     "ENG30-01777210-v",
                     "ENG30-13987423-n",
                     "ENG30-01128193-v",
                     "ENG30-02355596-v",
                     "ENG30-00271946-v",
                    ]

# %%
Synset_Sentiment_set_3 = PolaritySets(swordnet, 0)

# %%
negative_seed_IDS = ["ENG30-01510444-a",
                     "ENG30-01327301-v",
                     "ENG30-00735936-n",
                     "ENG30-00220956-a",
                     "ENG30-02463582-a",
                     "ENG30-01230387-a",
                     "ENG30-00193480-a",
                     "ENG30-00364881-a",
                     "ENG30-14213199-n",
                     "ENG30-01792567-v",
                     "ENG30-07427060-n",
                     "ENG30-14408086-n",
                     "ENG30-14365741-n",
                     "ENG30-02466111-a",
                     "ENG30-14204950-n",
                     "ENG30-10609960-n",
                     "ENG30-02319050-v",
                     "ENG30-02495038-v",
                     "ENG30-01153548-n",
                     "ENG30-00751944-n",
                    ]

# %%
Synset_Sentiment_set_3.addPOSIDall(positive_seed_IDS)
Synset_Sentiment_set_3.addNEGIDall(negative_seed_IDS)

# %%
defi4 = Synset_Sentiment_set_3.getDef()

# %%
df_POS4 = pd.DataFrame(defi4["POS"])
df_NEG4 = pd.DataFrame(defi4["NEG"])

# %%
df_POS4
# Out:
#                  ID  POS   NEG  \
# 0  ENG30-01828736-v  1.0  0.00
# 1  ENG30-02355596-v  0.0  0.00
# 2  ENG30-01128193-v  0.0  0.75
# 3  ENG30-01777210-v  1.0  0.00
# 4  ENG30-13987423-n  1.0  0.00
# 5  ENG30-13987905-n  1.0  0.00
# 6  ENG30-00271946-v  0.0  0.00
#
#                                                Lemme  \
# 0                                     voleti,uživati
# 1  dobijati,dobiti,dostići,dostignuti,postići,pos...
# 2                                            štititi
# 3                             dopadati se,sviđati se
# 4                                              sreća
# 5                  blaženstvo,sedmo nebo,deveto nebo
# 6                        stabilizovati se,smiriti se
#
#                                           Definicija Vrsta
# 0                   osećati zadovoljstvo zbog nečega     v
# 1                               postići bod ili cilj     v
# 2  Zaklanjati od opasnosti, povrede, uništenja il...     v
# 3         Nalaziti da je nešto zabavno ili prijatno.     v
# 4  Stanje pozitivnih osećanja, od zadovoljstva do...     n
# 5                             Stanje izuzetne sreće.     n
# 6                   Postati stabilan ili stabilniji.     v

# %%
swordnet.synsets("sreća")
# Out:
# [<SrbSynset ID:ENG30-11418460-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-11418460-n>]"
#          "Definition- nepoznata i nepredvidljiva prirodna pojava koja vodi do povoljnog ishoda"
#
#          ,
#  <SrbSynset ID:ENG30-14473222-n>
#          "Lemma - [<SrbLemma name:okolnosti synset:Synset: ID is ENG30-14473222-n>, <SrbLemma name:sudbina synset:Synset: ID is ENG30-14473222-n>, <SrbLemma name:sreća synset:Synset: ID is ENG30-14473222-n>]"
#          "Definition- Nečije opšte okolnosti ili uslovi u životu (uključujući sve što vam se dešava)."
#
#          ,
#  <SrbSynset ID:ENG30-11418138-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-11418138-n>]"
#          "Definition- Nepoznat i nepredvidiv fenomen koji uzrokuje da neki događaj ima jedan, a ne drugi, rezultat."
#
#          ,
#  <SrbSynset ID:ENG30-07526757-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-07526757-n>]"
#          "Definition- Osećanja proživljena kada je neko u zadovoljnom stanju."
#
#          ,
#  <SrbSynset ID:ENG30-13987423-n>
#          "Lemma - [<SrbLemma name:sreća synset:Synset: ID is ENG30-13987423-n>]"
#          "Definition- Stanje pozitivnih osećanja, od zadovoljstva do jakog ushićenja."
#
#          ]

# %%
swordnet.synsets("voleti")
# Out:
# [<SrbSynset ID:ENG30-01775164-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01775164-v>]"
#          "Definition- Gajiti nežna osećanja prema nekome."
#
#          ,
#  <SrbSynset ID:ENG30-01824736-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01824736-v>, <SrbLemma name:želeti synset:Synset: ID is ENG30-01824736-v>]"
#          "Definition- Želeti nešto uraditi."
#
#          ,
#  <SrbSynset ID:ENG30-01824339-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01824339-v>]"
#          "Definition- nadati se nećemu, imati želju"
#
#          ,
#  <SrbSynset ID:ENG30-01775535-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01775535-v>]"
#          "Definition- biti zaljubljen ili u ljubavi s nekim"
#
#          ,
#  <SrbSynset ID:ENG30-01828736-v>
#          "Lemma - [<SrbLemma name:voleti synset:Synset: ID is ENG30-01828736-v>, <SrbLemma name:uživati synset:Synset: ID is ENG30-01828736-v>]"
#          "Definition- osećati zadovoljstvo zbog nečega"
#
#          ,
#  <SrbSynset ID:ENG30-01776952-v>
#          "Lemma - [<SrbLemma name:dopadati se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:dopasti se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:sviđati se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:svideti se synset:Synset: ID is ENG30-01776952-v>, <SrbLemma name:voleti synset:Synset: ID is ENG30-01776952-v>]"
#          "Definition- voleti"
#
#          ]

# %%
df_NEG4
# Out:
#                   ID   POS      NEG  \
# 0   ENG30-02495038-v  0.00  0.00000
# 1   ENG30-01327301-v  0.00  0.50000
# 2   ENG30-14408086-n  0.00  0.25000
# 3   ENG30-02319050-v  0.00  0.00000
# 4   ENG30-01230387-a  0.00  0.37500
# 5   ENG30-14213199-n  0.00  0.62500
# 6   ENG30-00220956-a  0.00  0.37500
# 7   ENG30-00364881-a  0.00  0.62500
# 8   ENG30-00735936-n  0.00  0.62500
# 9   ENG30-10609960-n  0.00  0.00000
# 10  ENG30-01153548-n  0.00  0.00000
# 11  ENG30-00193480-a  0.00  0.62500
# 12  ENG30-02466111-a  0.00  0.00075
# 13  ENG30-14204950-n  0.75  0.12500
# 14  ENG30-07427060-n  0.00  0.50000
# 15  ENG30-00751944-n  0.00  0.00000
# 16  ENG30-02463582-a  0.00  0.62500
# 17  ENG30-14365741-n  0.00  0.12500
# 18  ENG30-01792567-v  0.00  0.37500
# 19  ENG30-01510444-a  0.25  0.25000
#
#                                                 Lemme  \
# 0                             lišiti slobode,zatočiti
# 1                       likvidirati,ucmekati,skembati
# 2                                   teškoća,neprilika
# 3   čerupati,drati,očerupati,odrati,opljačkati,tra...
# 4                                          beznadežan
# 5                                 muka,fizička patnja
# 6                                               ružan
# 7                        deprimirajući,tmuran,sumoran
# 8                                       nepristojnost
# 9                                        gonič robova
# 10                                     diskriminacija
# 11                                        užasavajući
# 12                                          nepouzdan
# 13                                         patologija
# 14                                        atrofiranje
# 15                                   izmišljotina,laž
# 16                 ciničan,mizantropski,mizantropičan
# 17                                           atrofija
# 18                                  nauditi,naškoditi
# 19                                        velik,težak
#
#                                            Definicija Vrsta
# 0                    lišiti slobode; držati u zatvoru     v
# 1                       Otarasiti se nekoga ubistvom.     v
# 2   Stanje stvari koje je skoro izvan nečije moguć...     n
# 3   koga odrati (po pitanju cene); za šta nerazumn...     v
# 4   koji je označen beznadežnošću ili ispoljava be...     a
# 5          stanje bola ili patnje zbog lošeg zdravlja     n
# 6       Koji je moralno odbojan ili neugodan za čula.     a
# 7                            koji izaziva potištenost     a
# 8                   nedolično ili nemoralno ponašanje     n
# 9   Okrutni poslodavac koji od zaposleni traži da ...     n
# 10  Nepravedno postupanje prema nekoj osobi ili gr...     n
# 11                        koji izaziva osećanje užasa     a
# 12  onaj kojem se ne može ukazati poverenje, u kog...     a
# 13    svako odstupanje od zdravog ili normanog stanja     n
# 14  Slabljenje ili degeneracije, posebno usled nek...     n
# 15                  čin namernog odstupanja od istine     n
# 16  koji misli najgore o ljudskoj prirodi i motivi...     a
# 17  smanjenje u veličini organa usled bolesti ili ...     n
# 18                         uzrokovati bol, unesrećiti     v
# 19                               Velika (glavobolja).     a

# %%
swordnet.synsets("atrofiranje")
# Out:
# [<SrbSynset ID:ENG30-07427060-n>
#          "Lemma - [<SrbLemma name:atrofiranje synset:Synset: ID is ENG30-07427060-n>]"
#          "Definition- Slabljenje ili degeneracije, posebno usled nekorišćenja."
#
#          ]

# %%
Synset_Sentiment_set_4 = PolaritySets(swordnet, 0)
positive_seed_words = ["dobar",
                       "dobrota",
                       "lep",
                       "čudesno",
                       "dragocen",
                       "anđeoski",
                       "izobilje",
                       "izbavljenje",
                       "tešiti",
                       "ispravnost",
                       "oduševiti se",
                       "slast",
                       "uveseljavajući",
                       "napredovati",
                       "proslavljen",
                       "usrećiti",
                       "uspešnost"]

negative_seed_words = ["zao",
                       "antipatija",
                       "beda",
                       "bedan",
                       "bol",
                       "laž",
                       "lažno",
                       "korupcija",
                       "krivica",
                       "prezreti",
                       "tuga",
                       "nauditi",
                       "sebičnost",
                       "paćeništvo",
                       "ukloniti s ovog sveta",
                       "masakr",
                       "ratovanje"]
Synset_Sentiment_set_4.addPOSall(positive_seed_words)
Synset_Sentiment_set_4.addNEGall(negative_seed_words)
Synset_Sentiment_set_4.addPOSIDall(positive_seed_IDS)
Synset_Sentiment_set_4.addNEGIDall(negative_seed_IDS)

# %%
pos_df = pd.read_csv(RES_DIR + "pos.csv" )
neg_df = pd.read_csv(RES_DIR + "neg.csv" )

# %%
pos_df
# Out:
#                    ID    POS  NEG                    Lemme  \
# 0    ENG30-00431005-n  0.875  0.0  šala,pošalica,sprdačina
# 1    ENG30-00064504-n  0.625  0.0                      hit
# 2    ENG30-06206800-n  0.750  0.0       poštovanje,respekt
# 3    ENG30-02674564-v  0.625  0.0         iskakati,štrčati
# 4    ENG30-02737724-v  0.750  0.0              uklapati se
# ..                ...    ...  ...                      ...
# 116  ENG30-04670022-n  0.625  0.0               pouzdanost
# 117  ENG30-00254415-n  0.625  0.0             sanitizacija
# 118  ENG30-00363031-a  0.750  0.0          nasmejan,ozaren
# 119  ENG30-02526925-a  0.625  0.0          željen,potreban
# 120  ENG30-05145891-n  0.625  0.0                  skupoća
#
#                                             Definicija
# 0           radnja koju karakteriše dobro raspoloženje
# 1                                      Upadljiv uspeh.
# 2                       Stav divljenja ili poštovanja.
# 3                                 Biti veoma primetan.
# 4                        Biti prihvatljiv ili pristao.
# ..                                                 ...
# 116  osobina onoga na šta se može osloniti, što je ...
# 117  učiniti da nešto postane sanitarno (bez bacila...
# 118              na čijem se licu očitava zadovoljstvo
# 119                                koji se želi, traži
# 120                 kvalitet onoga što ima veliku cenu
#
# [121 rows x 5 columns]

# %%
Synset_Sentiment_set_5 = PolaritySets(swordnet, 0)
Synset_Sentiment_set_5.addPOSIDall(pos_df["ID"])
Synset_Sentiment_set_5.addNEGIDall(neg_df["ID"])

# %%
defi5 = Synset_Sentiment_set_5.getDef()

# %%
defi5
# Out:
# {'POS': [{'ID': 'ENG30-01865197-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'productivan',
#    'Definicija': 'koji proizvodi ili je sposoban da proizvodi (posebno u velikim količinama)',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07500414-n',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'naklonost,naklonjenost',
#    'Definicija': 'osećanje naklonjenosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00885695-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'oduševljen',
#    'Definicija': 'koji oseća ili ispoljava veliko uzbuđenje ili zainteresovanost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07489714-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'razbludnost,pohota',
#    'Definicija': 'Jak seksualni nagon.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01430111-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'logički',
#    'Definicija': 'sposoban za korektno i validno rezonovanje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01807605-a',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'izvrstan',
#    'Definicija': 'koji inavodi na divljenje ili odobravanje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01148283-a',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'srećan',
#    'Definicija': 'Onaj koji uživa ili pokazuje radost, zadovoljstvo ili srešu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01357342-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'razveseljavajući,stimulišući',
#    'Definicija': 'koji čini živahnim i veselim',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02702830-v',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'odgovarati',
#    'Definicija': 'Biti nekome prihvatljiv ili odgovarajući.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04846770-n',
#    'POS': 0.875,
#    'NEG': 0.125,
#    'Lemme': 'moralnost,pravičnost',
#    'Definicija': 'briga o razlikovanju dobra i zla ili pravednog i nepravednog; dobro ili pravedno ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02496425-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'netrošiv',
#    'Definicija': 'koji može ponovo da se koristi',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14447908-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'zdravlje',
#    'Definicija': 'Stanje zadovoljstva jer nema bolesti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00519668-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'posvećen',
#    'Definicija': 'revnostan u posvećenosti i privrženosti',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07545833-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'dobrotvornost',
#    'Definicija': 'činjenje dobra; osećaj dobrotvornosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00362892-a',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'blistav',
#    'Definicija': 'veseo i ozaren',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-10115748-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'redovni profesor',
#    'Definicija': 'Profesor najvišeg ranga.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10280130-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'maestro,majstor',
#    'Definicija': 'Umetnik nenadmašnih veština.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01817500-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'pozitivan',
#    'Definicija': 'Koga karakteriše ili koji pokazuje prihvatanje, slaganje ili uverenost.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00995775-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'povoljan,pogodan',
#    'Definicija': 'koji ohrabruje, odobrava ili zadovoljava',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04869569-n',
#    'POS': 0.875,
#    'NEG': 0.125,
#    'Lemme': 'integritet',
#    'Definicija': 'moralna ispravnost',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02737724-v',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'uklapati se',
#    'Definicija': 'Biti prihvatljiv ili pristao.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01996377-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'odgovoran',
#    'Definicija': 'Koji odgovara za svoje postupke.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05155821-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'prednost,premoć',
#    'Definicija': 'nadmoćan ili povoljniji položaj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04847733-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'prirodna vrlina',
#    'Definicija': 'U skolastici, jedna od četiri vrline koje dolaze od prirode.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04626280-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'emocionalnost',
#    'Definicija': 'Priroda ili svojstvo onoga ko je emocionalan.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13987423-n',
#    'POS': 1.0,
#    'NEG': 0.0,
#    'Lemme': 'sreća',
#    'Definicija': 'Stanje pozitivnih osećanja, od zadovoljstva do jakog ushićenja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00512522-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'koketiranje,flert,kaćiperstvo',
#    'Definicija': 'Nestašno ponašanje sa namerom da pobudi seksualno zanimanje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00362467-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'uveseljavajući',
#    'Definicija': 'koji je pun pozitivne energije i širi dobro raspoloženje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04812268-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'elegancija,gracioznost,otmenost',
#    'Definicija': 'osobina prefinjene uglađenosti i dobrog ukusa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07543288-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'ljubav',
#    'Definicija': 'Jako pozitivno osećanje poštovanja i privreženosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01807882-v',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'privući,dopasti se',
#    'Definicija': 'biti privlačan kome',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01372948-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'milostiv',
#    'Definicija': 'koji pokazuje ili je motivisan saosećanjem, razumevanjem i velikodušnošću',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01218593-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'divljenje,uvažavanje',
#    'Definicija': 'blagonaklona procena',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01282510-a',
#    'POS': 0.875,
#    'NEG': 0.125,
#    'Lemme': 'zapanjujući,izuzetan',
#    'Definicija': 'koji pobuđuje poštovanje, divljenje ili čuđenje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00583239-a',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'konstantan,stalan,postojan',
#    'Definicija': 'osobina onoga koji ne odustaje od svoje ideje, osećanja ili namere',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01367651-a',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'raspoložen,vedar',
#    'Definicija': 'koji oseća ili pokazuje dobro raspoloženje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07487955-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'požuda',
#    'Definicija': 'Nagon za polnom prisnošću.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00860620-v',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'slaviti,veličati,glorifikovati,uzdizati',
#    'Definicija': '"slaviti vrline svoje dece"',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07529245-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'radost',
#    'Definicija': 'veselo osećanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07491981-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'polet,oduševljenje,slast',
#    'Definicija': 'energično i oduševljeno uživanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00363031-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'nasmejan,ozaren',
#    'Definicija': 'na čijem se licu očitava zadovoljstvo',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02339577-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'visokorazinski,visokonivojski',
#    'Definicija': 'na visokom nivou po rangu ili značaju',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04670022-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'pouzdanost',
#    'Definicija': 'osobina onoga na šta se može osloniti, što je pouzdano',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01193886-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'oslobađajuća presuda',
#    'Definicija': 'presuda(odluka) da optuženi nije kriv, odluka o nepostojanju krivice,o oslobađanju od krivice',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01332386-a',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'intelektualan,uman',
#    'Definicija': 'Koji koristi intelekt ili je privlačan intelektu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01777210-v',
#    'POS': 1.0,
#    'NEG': 0.0,
#    'Lemme': 'dopadati se,sviđati se',
#    'Definicija': 'Nalaziti da je nešto zabavno ili prijatno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-09573405-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'Fortuna',
#    'Definicija': 'u rimskoj mitologiji boginja sreće i sretne slučajnosti; u grčkoj mitologiji joj odgovara nTiha',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00166146-a',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'atraktivan,privlačan',
#    'Definicija': 'Prijatan za oči ili dušu, posebno jer je lep ili šarmantan.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01373545-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'milostiv',
#    'Definicija': 'koji ima urođenu sklonost prema dobroti',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07501420-n',
#    'POS': 0.875,
#    'NEG': 0.125,
#    'Lemme': 'obožavanje',
#    'Definicija': 'osećanje duboke ljubavi i divljenja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00254415-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'sanitizacija',
#    'Definicija': 'učiniti da nešto postane sanitarno (bez bacila), npr.sterilizacijom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05141683-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'cena',
#    'Definicija': 'Visoka vrednost nečega.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07527061-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': '?bonheur',
#    'Definicija': 'francuska reč za sreću i dobro raspoloženje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01130733-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'iskupljući',
#    'Definicija': 'koji donosi spasenje ili iskupljenje od greha',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00031820-v',
#    'POS': 0.8,
#    'NEG': 0.0,
#    'Lemme': 'nasmejati se',
#    'Definicija': 'Proizvesti smeh.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01676517-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'fantastičan,veličanstven,izvanredan,sjajan,izvrstan,izuzetan,predivan,čdesan',
#    'Definicija': 'izuzetno dobar; ove reči se koriste za naglašavanje značenja drugih reči',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04827652-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'nepoštenost',
#    'Definicija': 'Ne pridržavanje moralnim principima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00224031-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'povoljan',
#    'Definicija': 'koji ispoljava pogodan ili povoljan uticaj',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00904290-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'izvanredan',
#    'Definicija': 'koji zaslužuje najviše poštovanje i divljenje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00217728-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'lep',
#    'Definicija': 'Koji ushićuje čula, uzbuđuje duh ili izaziva emocionalno divljenje.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00223802-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'dobrotvoran',
#    'Definicija': 'koji čini ili donosi dobro',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07544213-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'zaljubljenost',
#    'Definicija': 'osećanje seksualne ljubavi',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01463965-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'brižan,blag,topao',
#    'Definicija': 'koji oseća ili pokazuje ljubav i naklonost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05138958-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'vrlina',
#    'Definicija': 'Neki cenjeni atribut ili kvalitet.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02679012-v',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'zadovoljiti,kvalifikovati se',
#    'Definicija': 'Ispuniti očekivanja.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-15245515-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'pravo vreme,trenutak,pravi čas',
#    'Definicija': 'Pogodan trenutak.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01689880-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'pravoveran',
#    'Definicija': 'Pristajanje uz ono što je opšte prihvaćeno.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00431005-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'šala,pošalica,sprdačina',
#    'Definicija': 'radnja koju karakteriše dobro raspoloženje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-06206800-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'poštovanje,respekt',
#    'Definicija': 'Stav divljenja ili poštovanja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04814238-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'veličanstvenost,briljantnost',
#    'Definicija': 'Osobina nekoga ko je veličanstven, briljantan',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01871774-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'lukrativan,moneymaking,remunerative',
#    'Definicija': 'koji donosi dobar profit',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01227495-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'milosrđe',
#    'Definicija': 'Ublažavanje patnje; pokazivanje velike dobrote prema izmučenima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01372049-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'ljubazan',
#    'Definicija': 'Onaj ko ima nežnu, pažljivu i obzirnu prirodu; koristi se za osobe i njihovo ponašanje.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04616916-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'karakter',
#    'Definicija': 'Inherentni kompleks atributa koji određuju moralne i etičke akcije i reakcije osoba.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00065495-v',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'biti dobro,osećati se dobro',
#    'Definicija': 'Biti zdrav, osećati se dobro.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-13987905-n',
#    'POS': 1.0,
#    'NEG': 0.0,
#    'Lemme': 'blaženstvo,sedmo nebo,deveto nebo',
#    'Definicija': 'Stanje izuzetne sreće.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01361705-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'drag',
#    'Definicija': 'koji oseća ili izražava radost i veselje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14460565-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'celovitost,jedinstvenost',
#    'Definicija': 'Nesmanjena i nenarušena celovitost ili ukupnost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04668819-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'pouzdanost',
#    'Definicija': 'Osobina onoga što zaslužuje poverenje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00479330-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'ugodan,spokojan',
#    'Definicija': 'koji je oslobođen stresa ili pogoduje mentalnoj opuštenosti; koji ima ili pruža duševni mir',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02526925-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'željen,potreban',
#    'Definicija': 'koji se želi, traži',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01781478-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'pobožan',
#    'Definicija': 'Koji izražava ili propoveda obožavanje božanstva.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02674564-v',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'iskakati,štrčati',
#    'Definicija': 'Biti veoma primetan.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01170243-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'zdrav',
#    'Definicija': 'Koji ima ili ukazuje na dobro zdravlje tela ili duha, kod koga nema upale ili bolesti.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01133876-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'dobrodušan',
#    'Definicija': 'Koji ima veseo karkater, nije sklon brigama.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00705336-a',
#    'POS': 0.875,
#    'NEG': 0.125,
#    'Lemme': 'obradovan,oraspoložen',
#    'Definicija': 'kojeg je neko uveselio',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01465061-a',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'zaljubljiv',
#    'Definicija': 'koji je sklon ljubavi ili ispoljavanju ljubavi',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07551890-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'raspoloženost',
#    'Definicija': 'osećati se veselo i biti ispunjen dobrim raspoloženjem',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00922344-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'uzbuđujući',
#    'Definicija': 'prijatno i površno uzbuđujući',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05138208-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'vrednost',
#    'Definicija': 'Kvalitet koji čini daa je nešto poželjno, vredno ili korisno.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07545415-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'obzir,poštovanje',
#    'Definicija': 'osećanje prijateljstva i uvažavanja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00883611-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'reduktibilan',
#    'Definicija': 'koji može da se redukuje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01778568-v',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'strahopoštovati,uvažavati',
#    'Definicija': 'gajiti osećanja dubokog poštovanja i straha pred autoritetom.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-10676018-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'nadređeni,starešina',
#    'Definicija': 'Neko višeg ranga ili položaja ili kvaliteta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04826235-n',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'ispravnost,pravednost',
#    'Definicija': 'držanje do moralnih principa',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01775535-v',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'voleti',
#    'Definicija': 'biti zaljubljen ili u ljubavi s nekim',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-05154517-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'preimućstvo,plus',
#    'Definicija': 'Korisna ili vredna osobina',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02492362-v',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'razonoditi',
#    'Definicija': 'Zaokupiti na prijatan ili zabavan način.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01246579-a',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'prijateljski',
#    'Definicija': 'okarakterisan prijateljstvom i dobrom voljom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14447525-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'ugodnost',
#    'Definicija': 'Zadovoljno stanje sreće, zdravlja i prosperiteta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04895246-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'poverenje',
#    'Definicija': 'osobina ljudi da veruju u poštenje i pouzdanost drugih',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05138488-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'vrednost',
#    'Definicija': 'Pozitivan ili negativan kvalitet nečega što ga čini poželjnim ili vrednim.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07509996-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'čuđenje,zaćuđenost',
#    'Definicija': 'osećanje izazvano nečim čudnim i iznenađujućim',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07508486-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'ponos,dika',
#    'Definicija': 'Osećanje samopoštovanja i lične vrednosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05168261-n',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'važnost',
#    'Definicija': 'Kvalitet nekoga ili nectega što je važno ili vredno pažnje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07500159-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'odobravanje',
#    'Definicija': 'osećanje naklonosti prema nekome ili nećemu dobrom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14474052-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'prosperitet,uspešnost',
#    'Definicija': 'Stanje kada je neko prosperitetan i uspešan.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07530478-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'veselje',
#    'Definicija': 'osećaj spontano dobrog rapoloženja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07602279-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'gorka čokolada,čokolada za kuvanje',
#    'Definicija': 'Čista nezaslađena čokolada koja se koristi za kuvanje (za pravljenje kolača).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02164694-v',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'diviti se',
#    'Definicija': 'Gledati nekoga sa divljenjem.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04849241-n',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'dobrota',
#    'Definicija': 'Moralna izvanrednost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05145891-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'skupoća',
#    'Definicija': 'kvalitet onoga što ima veliku cenu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04847482-n',
#    'POS': 0.75,
#    'NEG': 0.125,
#    'Lemme': 'vrlina',
#    'Definicija': 'Izuzetna moralna vrednost.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04808639-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'popularnost',
#    'Definicija': 'Osobina onog ko je široko prihvaćen i čije se društvo traži.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01828736-v',
#    'POS': 1.0,
#    'NEG': 0.0,
#    'Lemme': 'voleti,uživati',
#    'Definicija': 'osećati zadovoljstvo zbog nečega',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07289588-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'čudo',
#    'Definicija': 'nešto što izaziva osećanje čuđenja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01580050-a',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'neophodan',
#    'Definicija': 'Apolutno važno.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04686003-n',
#    'POS': 0.75,
#    'NEG': 0.0,
#    'Lemme': 'atraktivnost,privlačnost',
#    'Definicija': 'Lepota koja je privlačna čulima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00064504-n',
#    'POS': 0.625,
#    'NEG': 0.0,
#    'Lemme': 'hit',
#    'Definicija': 'Upadljiv uspeh.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02735282-v',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'odgovarati,pasati',
#    'Definicija': 'Biti prihvatljiv ili odgovarajući.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01275562-a',
#    'POS': 0.875,
#    'NEG': 0.0,
#    'Lemme': 'važan',
#    'Definicija': 'Od velikog značaja ili važnosti.',
#    'Vrsta': 'a'}],
#  'NEG': [{'ID': 'ENG30-01752167-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'nesavršen',
#    'Definicija': 'Koji nije savršen; defektan ili neadekvatan.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07534430-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'tuga',
#    'Definicija': 'Osećanje velike žalosti povezano sa gubitkom ili lišavanjem.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02451951-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nepopustljiv',
#    'Definicija': 'Koji nije popustljiv, kojim se teško upravlja.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01077829-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'neprijateljski',
#    'Definicija': 'koji ne pripada snagama sopstvene zemlje ili snagama saveznika',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01534147-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'uprljati,isprljati,ubrljati,ukaljati',
#    'Definicija': 'Zaprljati, onečistiti.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14541044-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'opasnost',
#    'Definicija': 'Stanje podložnosti povredi ili ozledi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00835609-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'neefikasan',
#    'Definicija': 'Koji ne proizvodi nameravani efekat.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01230616-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'bespomoćan,izgubljen',
#    'Definicija': 'nesposoban da deluje: bez pomoći',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00078401-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'patiti',
#    'Definicija': 'Ne osecati se dobro ili udobno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00865620-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'zaveden,osvojen,šarmiran,zanesen,zaluđen',
#    'Definicija': 'ispunjen divljenjem i ushićenjem',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01364008-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'žalostan',
#    'Definicija': 'koji oseća ili ispoljava žalost, naročito zbog nepovratnog gubitka',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07536245-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'krivica,osećanje krivice',
#    'Definicija': 'griža savesti kada se neko oseća krivim za prekršaj',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01793177-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'povrediti',
#    'Definicija': 'povrediti nečija osećanja',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01818234-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'negativan',
#    'Definicija': 'Koga karakeriše ili koji pokazuje odbijanje, poricanje ili suprotstavljanje; koji nema pozitivna svojstva.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00927049-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'spekulirati,spekulisati,nagađati',
#    'Definicija': 'Pričati na besposlen ili neobavezan način sa elementom sumnje ili bez dovoljno razloga da se dođe do zaključka.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01361863-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'tužan',
#    'Definicija': 'koji oseća ili ispoljava žalost i tugu',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07524529-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'briga,zabrinutost',
#    'Definicija': 'Osećanje zabrinutosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01626562-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'odvratan,gnusan',
#    'Definicija': 'izuzetno uvredljiv za moral; koji izaziva užas',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01794668-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'patiti,trpeti',
#    'Definicija': 'Biti podvrgnut (emocionalnom bolu).',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07533097-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'melanholija',
#    'Definicija': 'osećanje misaone tuge',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14213199-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'muka,fizička patnja',
#    'Definicija': 'stanje bola ili patnje zbog lošeg zdravlja',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05139094-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'mana,nedostatak',
#    'Definicija': 'Kvalitet nečega što nije adekvatno ili perfektno.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07502241-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'neprijaznost',
#    'Definicija': 'Odbojnost doživljena kao odsustvo druželjubivosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01780202-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'strahovati,bojati se',
#    'Definicija': 'biti uplašen, plašiti se',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07537068-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'neveselost',
#    'Definicija': 'osećanje uporne tuge',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04752221-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nejednakost',
#    'Definicija': 'kada nema jednakosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01625063-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'mrzak,bestidan,oduran',
#    'Definicija': 'veoma odbojan',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01257612-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'hladan',
#    'Definicija': 'Prošireno značenje; posebno se odnosi na psihološku hladnoću; bez ljudske topline i emocija.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01986349-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'ograničen,uskogrud',
#    'Definicija': 'osoba koja ne prihvata nove ideje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07533492-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'ojađenost',
#    'Definicija': 'osećanje velike utučenosti i melanholije',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00115494-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'ogorčen,razdražen,pobesneo,uvredžen',
#    'Definicija': 'razgnevxlen nečim nepravednim ili pogrešnim',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05144079-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'nevaljalost',
#    'Definicija': 'ono što je ispod standarda i očekivanja u pogledu morala ili pristojnosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07535670-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'žaljenje,žal',
#    'Definicija': 'Tuga povezana sa nekim učinjenim zlom ili nekim razočaranjem.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00620585-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nekooperativan',
#    'Definicija': 'koji nije raspoložen da sarađuje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00674340-v',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'ne odobravati,zamerati',
#    'Definicija': 'Smatrati da je nešto loše ili pogrešno.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00364881-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'deprimirajući,tmuran,sumoran',
#    'Definicija': 'koji izaziva potištenost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04625284-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nemir',
#    'Definicija': 'Nemogućnost da se odmori, opusti ili bude miran.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01797051-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'oplakati,tugovati,jadikovati,ožaliti',
#    'Definicija': 'Osećati tugu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-04714440-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'inkompatibilnost,neusklađenost',
#    'Definicija': 'Kvalitet onoga što ne može da postoji ili radi u usklađenoj kombinaciji.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04690196-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'ružnoća',
#    'Definicija': 'Kvalitet koji ne pruža zadovoljstvo čulima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01743217-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'pokajan',
#    'Definicija': 'koji oseća ili ispoljava kajanje zbog nedela',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00193799-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'strašan,strahovit,užasan,užasavajući',
#    'Definicija': 'koji izaziva strah ili užas',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14189204-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'bolest krvi,krvna bolest',
#    'Definicija': 'Bolest krvi ili narušavanje funkcionisanja krvnih ćelija.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00985909-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'neprobirljiv,neosetljiv',
#    'Definicija': 'koji ne traži, ne iziskuje specijalne nutricione potrebe',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05161614-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nedostatak,nepovoljan položaj',
#    'Definicija': 'Kvalitet nekog ili nečega što ima slabiju ili manje poželjnu poziciju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01131043-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'zao,loš',
#    'Definicija': 'Koji je moralno lož ili pogrešan.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01244410-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'neprijateljski',
#    'Definicija': 'okarakterisan neprijateljstvom ili zlovoljom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04658106-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'odbojnost,neprijateljstvo',
#    'Definicija': 'odbojno, vrlo neprijateljsko ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02527651-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'uprskati,upropastiti,zabrljati,zakrmačiti,zasvinjiti,zajebati,usrati,unerediti',
#    'Definicija': 'Napraviti nered, uništiti.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07501545-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nedopadanje',
#    'Definicija': 'Osećanje averzije ili antipatije.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00025654-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'opustiti,relaksirati',
#    'Definicija': 'Ućiniti da se neko oseti opuštenim.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14052046-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'zdravstveni problem,loše zdravstveno stanje',
#    'Definicija': 'Stanje u kome čovek ne može da funkcioniše normalno i bez bola.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14478433-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'bankrot',
#    'Definicija': 'nemogućnost da se otplate svi dugovi kada dospeju za naplatu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00258857-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'oštetiti,pokvariti',
#    'Definicija': 'Izazvati štetu na nečemu.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01090993-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nefunkcionalan',
#    'Definicija': 'Koji nema ili ne obavlja funkciju.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07532832-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'setnost',
#    'Definicija': 'tuga izazvana bolom i tugom',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07535430-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'tuxznost',
#    'Definicija': 'ispoljavanje rastuženosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00735336-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'izgoreo,sagoreo',
#    'Definicija': 'uništen ili veoma oštećen vatrom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01365544-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'skrhan,srceparajući',
#    'Definicija': 'koji ispoljava ili je označen tugom i bolom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07539367-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'disforija',
#    'Definicija': 'nenormalna depresija i nezadovoljstvo',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00002098-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nesposoban',
#    'Definicija': 'Koji nema potrebne sposobnosti, veštinu ili znanje.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07535532-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'muka',
#    'Definicija': '(poetski) muka',
#    'Vrsta': 'n'},
#   {'ID': 'BILI-00000306',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nositi crninu',
#    'Definicija': 'Oblačiti se u crno kao znak žalosti.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02575082-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'varati,podvaliti',
#    'Definicija': 'Biti lažljiv, neiskrene prema nekome.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01366525-a',
#    'POS': 0.125,
#    'NEG': 0.875,
#    'Lemme': 'paćenički',
#    'Definicija': 'pod uticajem patnje i tuge ili ispunjen ovim osećanjima',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01181475-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ustaljeni proces,ustaljeni zakonski proces',
#    'Definicija': 'Izvršenje pravde u skladu sa ustanovljenim pravilima i principima.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01230153-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'potišten',
#    'Definicija': 'bez nade ili skoro bez nade',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01050890-a',
#    'POS': 0.125,
#    'NEG': 0.875,
#    'Lemme': 'jadan,bedan,patetičan',
#    'Definicija': 'koji zaslužuje sažaljenje ili podstiče na sažaljenje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00567593-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nepovezan',
#    'Definicija': 'Koji nije spojen ili vezan.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02363358-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'neprijemčiv',
#    'Definicija': 'Ne biti podložan nečemu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01262611-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nečovečan,nehuman,neljudski',
#    'Definicija': 'Onaj koji nema ili ne pokazuje sažaljenje ili saosećanje.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05042871-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'ranjivost',
#    'Definicija': 'osetljivost na povrede ili napada',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-04664964-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'nebrižljivost',
#    'Definicija': 'Kvalitet onog ko nije brižljiv.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01566705-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'smrskati,skršiti',
#    'Definicija': 'Uništiti ili oštetiti na nasilan način.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01774136-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'mrzeti,ne podnositi',
#    'Definicija': 'Osećati snažnu antipatiju i odbojnost prema nekome.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00758972-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'gnev,jarost',
#    'Definicija': 'ratobornost izazvana stvarnom ili pretpostavljenom nepravdom (predstavljena kao jedan od smrtnih grehova)',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13990675-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'krivica',
#    'Definicija': 'Stanje kada je učinjen prekršaj.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14563564-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'mrak,tama,pokvarenost',
#    'Definicija': 'odsustvo moralnih ili duhovnih vrednosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01127147-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'zastrašujući,strahovit',
#    'Definicija': 'izuzetno nelagodan',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00225564-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'pakostan,zlonameran',
#    'Definicija': 'Koji drugima želi zlo; koji nastaje iz velike zlobe ili mržnje.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00066191-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'plakati',
#    'Definicija': 'Prolivati suze zbog tuge, besa ili bola.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07206096-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'povlačenje,poricanje',
#    'Definicija': 'Opovrgavanje ili povlačenje prethodne tvrdnje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00781644-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'mutan',
#    'Definicija': 'neraspoznatljiv, nejasnih obrisa',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14285662-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'povreda,ozleda',
#    'Definicija': 'Bilo kakva oštetočina na telu izazvana nasiljem, nezgodom ili prelomom.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05829480-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'negativni stimulans',
#    'Definicija': 'stimulans sa nepoželjnim posledicama',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07535209-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'rastuženost,ojađenost',
#    'Definicija': 'stanje sumorne žalosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01126291-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'rđav,svirep,neopisiv',
#    'Definicija': 'izuzetno loš ili nezadovoljavajući',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02359464-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'iznenađujući',
#    'Definicija': 'koji izaziva iznenađenje, čuđenje ili zadivljenost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01549291-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'nemoralan',
#    'Definicija': 'Koji narušava principe dobra i zla.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00419908-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'zlostavljanje,zlostava',
#    'Definicija': 'okrutno ili nehumano postupanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07535010-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'skrhanost,bol',
#    'Definicija': 'Velika tuga uzrokovana gubitkom voljene osobe (posebno smrću).',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07289014-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nevolja,teškoća',
#    'Definicija': 'Ono što izaziva bol ili patnju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13988663-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nesreća',
#    'Definicija': 'Stanje koje karakterišu osećanja u rasponu od blagog nezadovoljstva do dubokog bola.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01362387-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'žaloban',
#    'Definicija': 'koji je tužan ili priziva tugu',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-05942888-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ubeđenje,uverenje',
#    'Definicija': 'nepokolebljivo verovanje u nešto bez potrebe za dokazima ili nalazima',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02123424-v',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'probosti,žigati',
#    'Definicija': 'uzrokovati probadanje',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01780434-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'strepeti',
#    'Definicija': 'biti zabrinut i prestrašen zbog nečega',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01366157-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'ožalošćen',
#    'Definicija': 'koji ispoljava žalost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07506149-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'bezdušnost,hladnokrvnost',
#    'Definicija': 'nedostatak brige za dobrobit drugih',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-12819953-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'Hackelia,rod Hackelia,Lappula,rod Lappula',
#    'Definicija': 'Čičkovac.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07305234-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nedaća,beda',
#    'Definicija': 'Uzrok velikih patnji i nesreće.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00070965-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'greška,pogreška',
#    'Definicija': 'Pogrešna akcija koja se može pripisati lošoj proceni, neznanju ili nepažnji.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00704270-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'smrknut,natmuren',
#    'Definicija': 'koji odražava sumornost i smrknutost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01064286-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'neslobodan',
#    'Definicija': 'Onemogućen i nije slobodan; ne mpože da deluje po sopstvenoj volji.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01364817-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ucveljen,ojađen',
#    'Definicija': 'žalostan zbog gubitka ili uskraćenosti',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-13968308-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nezaposlenost',
#    'Definicija': 'Stanje biti nezaposlen ili nemati posao.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00419289-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'prljav',
#    'Definicija': 'Koji na sebi ima prljavštinu ili nečistoću.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14322699-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'bol',
#    'Definicija': 'Simptom neke fizičke povrede ili poremećaja.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07523905-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'teskoba,uznemirenost',
#    'Definicija': 'nejasno i neprijatno osećanje koje se ima u iščekivanju nekog lošeg ishoda',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02124332-v',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'vonjati',
#    'Definicija': 'loše mirisati',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02581276-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'podsticati na izvršenje krivičnog dela',
#    'Definicija': 'podsticati nekog da počini zločin ili neko krivično delo',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00194924-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'jezivo,grozno',
#    'Definicija': 'tako strašno da izaziva grozu i jezu',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07534108-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'napuštenost,usamljenost',
#    'Definicija': 'tuga onoga koga je neko napustio ili ostavio',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01743506-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'pokajnički',
#    'Definicija': 'koji oseća ili ispoljava bol ili žalost zbog greha ili uvreda',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01161161-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'telesna kazna,fizičko kažnjavanje',
#    'Definicija': 'nanošenje telesnih povreda licu koje je osuđeno za izvršen zločin',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07298982-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'udarac,udar,šok',
#    'Definicija': 'neprijatno ili razočaravajuće iznenađenje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00424599-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'okrutnost,nečovečno postupanje',
#    'Definicija': 'Okrutan čin; namerno izazivanje bola ili patnje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01595596-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nenormalan,anormalan',
#    'Definicija': 'Koji nije normalan, tipičan, uobičajen, regularan ili nije u saglasnosti sa normom.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02482425-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ubiti,ukloniti s ovog sveta',
#    'Definicija': 'Usmrtiti namerno i sa predumišljajem.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00969103-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'gotski',
#    'Definicija': 'koji je okarakterisan mračnim, mističnim i groteskom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04670531-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nepouzdanost',
#    'Definicija': 'Osobina onoga što ne zaslužuje poverenje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05645597-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'glupost',
#    'Definicija': 'Slaba sposobnost da se razume iskustvo ili profitira iz njega.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00735936-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nepristojnost',
#    'Definicija': 'nedolično ili nemoralno ponašanje',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00118238-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'neživ,mrtav',
#    'Definicija': 'U kome nema života.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00078851-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'uzbunjen',
#    'Definicija': 'koji oseća nadolazeću opasnost',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00687181-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'odbaciti',
#    'Definicija': 'odbaciti (dokument) kao nevažeci',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-00193480-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'užasavajući',
#    'Definicija': 'koji izaziva osećanje užasa',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00726317-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'bespomoćan',
#    'Definicija': 'koji je nesposoban da se sam snađe',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02449952-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'otrovni',
#    'Definicija': 'Koji je otrovan ili proizvodi otrov.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00703615-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'snužden,depresivan,slomljen,klonuo duhom',
#    'Definicija': 'koji je klonuo duhom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02124106-v',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'bazdeti,smrdeti,zaudarati',
#    'Definicija': 'Ispuštati vonj.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07505538-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nebriga',
#    'Definicija': 'Osećanje pomanjkanja brige.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00909363-a',
#    'POS': 0.125,
#    'NEG': 0.875,
#    'Lemme': 'disforičan',
#    'Definicija': 'uopštenih osećanja tuge',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07506569-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'stid,sramota',
#    'Definicija': 'bolan osećaj koji proizlazi iz svesti o nedovoljnosti ili krivici',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-13989051-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'jad,tugovanje',
#    'Definicija': 'Stanje u kome je neko tužan.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07386920-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'mumljanje,mumlanje,mrmljanje',
#    'Definicija': 'Tih neprekidan nerazumljiv zvuk; obično ga prati kretanje usana koje ne proivodi artikulisani govor.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02085132-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nenaučan,neznanstven',
#    'Definicija': 'Koji nije u skladu sa metodama ili principima nauke.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00478015-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'neudoban',
#    'Definicija': 'Koji dovodi (pričinjava) fizičku neudobnost.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00606602-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nekonvencionalan',
#    'Definicija': 'Koji se ne povinuje prihvaćenim pravilima i standardima.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00744131-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'šteta',
#    'Definicija': 'svaka šteta proistekla iz povrede prava',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00725772-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'zavisan',
#    'Definicija': 'Koji nije nezavisan.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01587787-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'loš',
#    'Definicija': 'okarakterisan zlobom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07532440-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'tuga,žalost',
#    'Definicija': 'Osećanja koja se javljaju kada osoba nije u srećnom stanju.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14336539-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'zapaljenje,upala',
#    'Definicija': 'Odgovor telesnog tkiva na povredu ili nadržaj; karakteriše ga bol, otok, crvenilo i pečenje.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01190993-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'slab',
#    'Definicija': 'Koji nije vlik po količini, broju ili stepenu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01805064-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'neprijatan',
#    'Definicija': 'koji izaziva neprijatnost; na primer, neprijatna istina',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01368192-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'neveseo',
#    'Definicija': 'koji nije veseo niti izaziva veselje',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00802238-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'rizik',
#    'Definicija': 'poduhvat koji se preduzima bez obzira na mogući gubitak ili povredu',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-14493145-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'siromaštvo',
#    'Definicija': 'Stanje u kome se malo novca i materijalnih dobara.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00065370-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'bolovati od,imati',
#    'Definicija': 'Patiti od nečega; bolovati od nečega.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01158020-a',
#    'POS': 0.125,
#    'NEG': 0.875,
#    'Lemme': 'okoreo,bezdušan',
#    'Definicija': 'koji nema osećanja sažaljenja i topline',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00927578-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nepostojeći',
#    'Definicija': 'Koji ne postoji u stvarnosti.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04711256-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'suptilnost',
#    'Definicija': 'Kvalitet onoga što je teško otkriti ili analizirati.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00116529-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'ozlojeđen',
#    'Definicija': 'pun ili označen ozlojeđenošću ili zlovoljom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07534278-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'uplakanost',
#    'Definicija': 'tuga izražena plakanjem',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07519253-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'strah,strahota,bojazan',
#    'Definicija': 'Osećaj koji se doživljava u očekivanju nekog određenog bola ili opsasnosti i obično ga prati želja da se pobegne.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01172889-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'bolestan',
#    'Definicija': 'Koji nije u dobrom zdravlju tela ili duha.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-04657876-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'nedruželjubivost',
#    'Definicija': 'neprijateljski stav',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01799794-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'poniziti,ojaditi,osramotiti,uniziti',
#    'Definicija': 'Posramiti nekoga; povrediti nečiji ponos.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07532276-n',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'naslađivanje',
#    'Definicija': 'zlonamerno zadovoljstvo',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05006285-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'beživotnost',
#    'Definicija': 'svojstvo onoga kome nedostaje živost',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01808769-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'odbijati,odbiti',
#    'Definicija': 'biti odbojan; izazivati averziju',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-02513989-v',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'postupiti nepravično,učiniti nažao',
#    'Definicija': 'naneti nekome nepravdu',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07533978-n',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'beda',
#    'Definicija': 'osećanje intezivne nesreće',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00744916-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'težak',
#    'Definicija': 'Ono što nije lako, zahteva veliki fizički ili mentalni napor da bi se ostvarilo. razumelo ili izdržalo.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02340878-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'niskorazinski',
#    'Definicija': 'na nižem nivou po rangu ili značaju',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01150475-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': '?ispunjen žaljenjem',
#    'Definicija': 'žalovati, tugovati, ili osećati gubitak zbog nečega što je učinjeno ili nije učinjeno',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01688271-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'neoriginalan',
#    'Definicija': 'Koji nije originalan; nije produktivan, ne donosi ništa neobično niti sveže.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01396047-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nezakonit',
#    'Definicija': 'protivno zakonu ili zakonom zabranjeno',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01513050-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'užasan,grozan',
#    'Definicija': 'Intenzivno ili preterano loš ili neprijatan po kvalitetu ili stepenu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01362684-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'melanholičan',
#    'Definicija': 'koji je tužan ili izaziva tugu',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-00060063-v',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'prekinuti,prekratiti',
#    'Definicija': 'Završiti pre kraja, kao računarski proces, misiju itd.',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-14171682-n',
#    'POS': 0.222,
#    'NEG': 0.778,
#    'Lemme': 'zapalenje',
#    'Definicija': 'bolest koju karakteriše neki zapaljenski proces',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02566015-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'neraspoložen,nevoljan',
#    'Definicija': 'Koji nije naklonjen prea nečemu.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-14425974-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nezrelost',
#    'Definicija': 'Stanje koje još ne odgovara zrelosti.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00822907-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'teskoban',
#    'Definicija': 'mentalno uznemiren zbog moguće nesreće ili opasnosti; zabrinut',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07301336-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nesreća',
#    'Definicija': 'Nezgoda, posebno ona koja prouzrokuje povredu ili smrt.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02579447-v',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'pokvariti,iskvariti,korumpirati,demoralisati,pervertirati,profanisati',
#    'Definicija': 'moralno iskvariti',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-07510625-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'šok',
#    'Definicija': 'iznenadno stanje žestoke emocionalne uznemirenosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-10205231-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'podređen,potčinjen',
#    'Definicija': 'Neko nižeg ranga ili položaja ili kvaliteta.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-00095280-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'mrtav',
#    'Definicija': 'Koji više nema životne funkcije (ili bar tako izgleda).',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-07520507-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'histerija',
#    'Definicija': 'preteran ili nekontrolisan strah',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-07523760-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'zaplašenost',
#    'Definicija': 'osećanje zaplašenosti',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-05645199-n',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'blokada,mentalna blokada',
#    'Definicija': 'Nesposobnost osobe da se seti ili uradi ono što obično može; često uzrokovana emoionalnom napetošću.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-01246697-n',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'teroristički napad',
#    'Definicija': 'Iznenadni napad koji uključuje namernu upotrebu nasilja prema civilima da bi se postigli politički ili religiozni ciljevi.',
#    'Vrsta': 'n'},
#   {'ID': 'ENG30-02463582-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'ciničan,mizantropski,mizantropičan',
#    'Definicija': 'koji misli najgore o ljudskoj prirodi i motivima; koji ima podrugljivu nevericu u, npr. u nesebičnost drugih',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02347086-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'bedan,kukavan,oplačljiv',
#    'Definicija': 'veoma lošeg kvaliteta ili u veoma lošem stanju',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01150205-a',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'mizeran',
#    'Definicija': 'veoma nesrećan; ispunjen mizerijom',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01823092-a',
#    'POS': 0.0,
#    'NEG': 0.75,
#    'Lemme': 'nemoguć',
#    'Definicija': 'Koji ne može da se desi ili ostvari ili s kojim se ne može rukovati.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-01564073-a',
#    'POS': 0.0,
#    'NEG': 0.625,
#    'Lemme': 'nepokretan',
#    'Definicija': 'Koji s ne pokreće.',
#    'Vrsta': 'a'},
#   {'ID': 'ENG30-02114924-v',
#    'POS': 0.0,
#    'NEG': 0.875,
#    'Lemme': 'desenzitivisati',
#    'Definicija': 'učiniti da neko ili nešto ne bude osetljiv ili osetljivo',
#    'Vrsta': 'v'},
#   {'ID': 'ENG30-01805889-a',
#    'POS': 0.125,
#    'NEG': 0.75,
#    'Lemme': 'nezadovoljan',
#    'Definicija': 'koji nije zadovoljan; koji doživljava ili ispoljava nezadovoljstvo',
#    'Vrsta': 'a'}],
#  'OBJ': [],
#  'iteration': 0}

# %%
enSent =swordnet.sentiment_df()

# %%
posKandidat =enSent[enSent["POS"] - enSent["NEG"] >0.5]

# %%
missing_ids = posKandidat[~posKandidat['ID'].isin(pos_df['ID'])]

# %%
missing_ids
# Out:
#                      ID    POS    NEG  \
# 2009   ENG30-00971650-v  0.625  0.000
# 2231   ENG30-02338615-a  0.625  0.000
# 2497   ENG30-07480068-n  0.625  0.000
# 3241   ENG30-00549766-n  0.625  0.000
# 3631   ENG30-05616786-n  0.625  0.000
# 4343   ENG30-02702332-a  0.750  0.000
# 5374   ENG30-02064745-a  0.625  0.000
# 6251   ENG30-00394135-a  0.625  0.000
# 6626   ENG30-00745637-n  0.750  0.000
# 7597   ENG30-10523076-n  1.000  0.000
# 7675      BILI-00000163  1.000  0.000
# 7966   ENG30-00853776-a  0.625  0.000
# 7980   ENG30-01905377-a  0.625  0.000
# 9278   ENG30-12980478-n  0.625  0.000
# 9551   ENG30-07723330-n  0.625  0.000
# 9875   ENG30-13012613-n  0.625  0.000
# 10918  ENG30-02776576-a  0.625  0.000
# 11244  ENG30-09312843-n  0.750  0.000
# 11345  ENG30-01421496-n  0.625  0.000
# 11494  ENG30-00789871-a  0.750  0.000
# 13060  ENG30-01203676-n  0.625  0.000
# 13874  ENG30-00839834-v  0.625  0.000
# 16545  ENG30-00104318-a  0.625  0.000
# 16819  ENG30-14204950-n  0.750  0.125
# 17159  ENG30-01464700-a  0.625  0.000
# 17641  ENG30-01987856-a  0.875  0.000
# 17642  ENG30-00251809-a  0.625  0.000
# 17644  ENG30-00156839-a  0.625  0.000
# 17965  ENG30-05962602-n  0.625  0.000
# 18479  ENG30-07668588-n  0.625  0.000
# 18492  ENG30-07668215-n  0.750  0.000
# 18534  ENG30-07741888-n  0.625  0.000
# 18613  ENG30-07647321-n  0.625  0.000
# 18694  ENG30-07646067-n  0.625  0.000
# 19081  ENG30-00897759-a  0.625  0.000
# 19503  ENG30-07702509-n  0.625  0.000
# 22548  ENG30-00343700-a  0.625  0.000
# 22565  ENG30-02287878-a  0.625  0.000
# 24449  ENG30-06160055-n  0.625  0.000
#
#                                                    Lemme  \
# 2009                   oceniti,okvalifikovati,proglasiti
# 2231                                            nadmoćan
# 2497                               emocija,jako osećanje
# 3241                               metod,metoda,postupak
# 3631                              znanje i veština,umeće
# 4343                                    konstitucionalan
# 5374                                            različit
# 6251                                koloran,kolor,u boji
# 6626                                         zlo,nemoral
# 7597                                          istraživač
# 7675                                        istraživački
# 7966                                            emotivan
# 7980                                       nečist,prljav
# 9278            Peronosporaceae,porodica Peronosporaceae
# 9551                                       zelena salata
# 9875                    Lepiotaceae,porodica Lepiotaceae
# 10918                                        fagocitozan
# 11244                                   infektivni agens
# 11345                            Sporozoa,klasa Sporozoa
# 11494                                            crvolik
# 13060                            konformizam,povinovanje
# 13874                        preuveličavati,preuveličati
# 16545  agresivan,preduzimljiv,prodoran,poletan,nametljiv
# 16819                                         patologija
# 17159      affectionate,caring,fond,lovesome,tender,warm
# 17641                                          nenapadan
# 17642                                          bojažljiv
# 17644                                          nenapadan
# 17965                                          imitacija
# 18479                                 jagnjeća noga,noga
# 18492                 jagnjeće pečenje,pečena jagnjetina
# 18534                             Stayman Winesap jabuka
# 18613                                     meso prepelice
# 18694                                       meso kokoške
# 19081                                             brisiv
# 19503                                         brza hrana
# 22548                                  izbeživ,izbežljiv
# 22565                                zaustavljiv,zadrživ
# 24449                                         ?casuistry
#
#                                               Definicija
# 2009                                Izreći sud o nekome.
# 2231                                                None
# 2497                            Bilo koje jako osećanje.
# 3241   Način da se nešto uradi, posebno na sistematič...
# 3631   Obično tehničko znanje i veština koji su potre...
# 4343              O koristi od nečijeg fizičkog sastava.
# 5374   Koji nije nalik po prirodi, kvalitetu, oblik i...
# 6251           Koji ima boju ili može da proizvede boju.
# 6626                         Ponašanje za moralnu osudu.
# 7597              Naučnik koji je posvećen istraživanju.
# 7675                      Koji se odnosi na istraživače.
# 7966   Koji pokazuje više osećanja nego što je uobiča...
# 7980   Koristi se za ljude ili njihovo ponasanje; koj...
# 9278                     Parazitske gljive: peronospore.
# 9551   Zeleniš koji može da se jede nekuvan i pogodan...
# 9875   Porodica gljiva koje imaju slobodne režnjeve i...
# 10918                sposoban da funkcioniše kao fagocit
# 11244              Agens koji može da izazove infekciju.
# 11345  isključivo parazitske protozoe koje su obično ...
# 11494                                   potpuno podložan
# 13060      ponašanje u skladu sa prihvaćenim standardima
# 13874                    u izjavi otići daleko od istine
# 16545  marked by aggressive ambition and energy and i...
# 16819    svako odstupanje od zdravog ili normanog stanja
# 17159           having or displaying warmth or affection
# 17641                   koji pokazuje skromnu uzdržanost
# 17642  koji ispoljava strah ili nedostatak samopouzdanja
# 17644    koji je plašljiv ili mu nedostaje samopouzdanja
# 17965  doktrina da predstavljanje prirode i ljudskog ...
# 18479                   jagnjeća noga pogodna za pečenje
# 18492                   jagnjeće meso pogodno za pečenje
# 18534        kisela jabuka; dobra i za jelo i za kuvanje
# 18613  meso prepelice; pogodno za pečenje i kuvanje u...
# 18694         meso starije kokoške, pogodno za dinstanje
# 19081                              koji može da se briše
# 19503  hrana dobrog ukusa ali je puna kalorija i ima ...
# 22548                                koji se može izbeći
# 22565                       onaj koji se može zaustaviti
# 24449  ?moral philosophy based on the application of ...

# %%
missing_ids.shape[0]
# Out:
# 39

# %%
negKandidat =enSent[enSent["NEG"] - enSent["POS"] >0.5]

# %%
missing_ids_NEG = negKandidat[~negKandidat['ID'].isin(neg_df['ID'])]

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None
pd.options.display.width = None
pd.options.display.max_colwidth = None
missing_ids_NEG
# Out:
#                      ID    POS    NEG  \
# 200    ENG30-00046344-n  0.000  0.625
# 727    ENG30-05821246-n  0.000  0.625
# 2094   ENG30-02295867-a  0.125  0.750
# 2153   ENG30-01821996-v  0.000  0.875
# 2171   ENG30-01128193-v  0.000  0.750
# 2515   ENG30-14496193-n  0.125  0.750
# 2729   ENG30-07553301-n  0.000  0.625
# 2876   ENG30-05888929-n  0.000  0.625
# 3246   ENG30-05945642-n  0.000  0.625
# 3312   ENG30-00202284-n  0.000  0.750
# 4000   ENG30-07261300-n  0.000  0.625
# 4797   ENG30-00927832-a  0.000  0.625
# 5263   ENG30-02135913-a  0.000  0.625
# 5307   ENG30-10250527-n  0.000  0.750
# 5359   ENG30-04800359-n  0.000  0.625
# 5692      BILI-00001027  0.000  0.625
# 6179   ENG30-13366693-n  0.000  0.750
# 6252   ENG30-00394331-a  0.000  0.625
# 6443   ENG30-13332670-n  0.000  0.625
# 6690   ENG30-04673470-n  0.000  0.750
# 7490   ENG30-01944955-n  0.000  0.625
# 7955   ENG30-01251128-a  0.000  0.750
# 7957   ENG30-00476819-a  0.000  0.750
# 7994   ENG30-01818992-a  0.125  0.750
# 7996   ENG30-00484333-a  0.000  0.750
# 8002   ENG30-02297166-a  0.125  0.875
# 8711   ENG30-09816654-n  0.125  0.750
# 9134   ENG30-10509389-n  0.000  0.625
# 9392   ENG30-11876976-n  0.000  0.625
# 9662   ENG30-13065902-n  0.000  0.625
# 10036  ENG30-07898745-n  0.000  0.625
# 10876  ENG30-01546593-a  0.000  0.750
# 10948  ENG30-05451099-n  0.000  0.625
# 10986  ENG30-14123510-n  0.000  0.750
# 11044  ENG30-01363887-n  0.000  0.750
# 11050  ENG30-01364866-n  0.000  0.625
# 11088  ENG30-01380754-n  0.000  0.625
# 11233  ENG30-01341090-n  0.000  0.750
# 11267  ENG30-01327028-n  0.000  0.625
# 11281  ENG30-01372544-n  0.000  0.625
# 11387  ENG30-01338178-n  0.000  0.625
# 11456  ENG30-00320985-a  0.000  0.625
# 11499  ENG30-14140176-n  0.000  0.625
# 11502  ENG30-02389220-a  0.000  0.750
# 11603  ENG30-02445863-a  0.000  0.750
# 11923  ENG30-05641432-n  0.000  0.625
# 11969  ENG30-02005460-a  0.000  0.750
# 12975  ENG30-02092987-a  0.000  0.625
# 12976  ENG30-02093134-a  0.000  0.625
# 13076  ENG30-00179486-a  0.000  0.875
# 13123  ENG30-10940669-n  0.000  0.625
# 13206  ENG30-14349807-n  0.000  0.625
# 13591  ENG30-06380373-n  0.000  0.625
# 15063  ENG30-07692614-n  0.000  0.625
# 16376  ENG30-01272367-n  0.000  0.625
# 16548  ENG30-01825125-v  0.000  0.875
# 16599  ENG30-01822536-v  0.000  0.625
# 16723  ENG30-14265508-n  0.000  0.750
# 16832  ENG30-00254166-n  0.000  0.750
# 17430  ENG30-01158453-a  0.000  0.875
# 17506  ENG30-01363936-a  0.000  0.750
# 17922  ENG30-03755712-n  0.000  0.625
# 18051  ENG30-14135277-n  0.000  0.750
# 18058  ENG30-01406961-a  0.000  0.625
# 19116  ENG30-01349041-a  0.000  0.625
# 19120  ENG30-02094514-a  0.000  0.750
# 19189  ENG30-01102058-a  0.000  0.750
# 19316  ENG30-01397125-a  0.000  0.750
# 19714  ENG30-02911488-a  0.000  0.625
# 19741  ENG30-01650752-a  0.000  0.625
# 19798  ENG30-01754421-a  0.000  0.625
# 19855  ENG30-01884930-a  0.000  0.750
# 19861  ENG30-01872645-v  0.000  0.625
# 19867  ENG30-00347707-a  0.000  0.750
# 19963  ENG30-01853461-a  0.000  0.750
# 19992  ENG30-01252151-a  0.000  0.750
# 19994  ENG30-00157389-a  0.000  0.625
# 20220  ENG30-00660551-a  0.000  0.625
# 20329  ENG30-07922512-n  0.000  0.625
# 20448  ENG30-07864756-n  0.000  0.625
# 20860  ENG30-07698401-n  0.000  0.750
# 22539  ENG30-11476430-n  0.000  0.625
# 22562  ENG30-04977561-n  0.000  0.625
# 24591  ENG30-06714976-n  0.000  1.000
# 24593  ENG30-06719579-n  0.000  0.625
# 24998  ENG30-10350896-n  0.000  0.625
# 25137  ENG30-13951215-n  0.000  0.625
#
#                                                               Lemme  \
# 200                                          vratolomija,egzibicija
# 727                                                        izuzetak
# 2094                                                   nestandardan
# 2153                                        saučestvovati,saosećati
# 2171                                                        štititi
# 2515                                                        čistoća
# 2729                                                    razumevanje
# 2876                                                       hipoteza
# 3246                                     mišljenje,shvatanje,pogled
# 3312                                                          otpor
# 4000                                                       doba,era
# 4797                                                        odsutan
# 5263                                                       bespolni
# 5307                                      laičko lice,svetovno lice
# 5359                                                   originalnost
# 5692                                                  stara štednja
# 6179                                                    akumulacija
# 6252                                                      crno-beli
# 6443                                      nematerijalno dobro,dobro
# 6690                                                  nonšalantnost
# 7490                                                      vrtni puž
# 7955                                                         hladan
# 7957                                                         udoban
# 7994                                                      neutralan
# 7996                                                 nekomercijalan
# 8002                                                   nestandardan
# 8711                                                         docent
# 9134                                                       realista
# 9392                        lisnati kelj,Brassica oleracea acephala
# 9662                                Ustilaginales,red Ustilaginales
# 10036                                                    stono vino
# 10876                                                   univalentan
# 10948                                             fiksirani fagocit
# 10986                                                     difterija
# 11044                      bakterija mišje groznice,Spirillum minus
# 11050                                   Bacteroides,rod Bacteroides
# 11088                            pneumokokus,Diplococcus pneumoniae
# 11233                                                     rotavirus
# 11267                                                       anaerob
# 11281                                                 rod Chlamydia
# 11387                                 Coxsackie virus,koksaki virus
# 11456                                                        bezrep
# 11499                           poliomielitis,polio,dečija paraliza
# 11502                                                        divalj
# 11603                                                    hrskavičav
# 11923                                                  koordinacija
# 11969                                                nerestriktivan
# 12975                                              nedenominacijski
# 12976                                                nedominacijski
# 13076                                                  neopunomoćen
# 13123  Dostojevski,Fjodor Dostojevski,Fjodor Mihajlovič Dostojevski
# 13206                                                   mastoiditis
# 13591                                                 slobodan stih
# 15063                                                  slatka kifla
# 16376                                            Bitka kod Bosvorta
# 16548                                               begrudge,resent
# 16599                                 kondolirati,izjaviti saučešće
# 16723                                 Lajmska bolest,Lyme arthritis
# 16832                                  pasterizacija,pasterizovanje
# 17430                                                     meka srca
# 17506                                                     preserćan
# 17922                                       metotreksat,ametopterin
# 18051                                  mononukleoza,bolest poljupca
# 18058                                      morganatski,morganatički
# 19116                                                      primesni
# 19120                                                     neotkaziv
# 19189                                                 opštenamenski
# 19316                                                     bezolovni
# 19714                                                neparametarski
# 19741                                             van linije,oflajn
# 19798                                            permanentan,stalan
# 19855                                                      zaštićen
# 19861                                                gurati,gurnuti
# 19867                                               fiksan,zamrznut
# 19963                                                    sekundaran
# 19992                                 arktički,leden,polaran,ledeni
# 19994                                                  asocijativan
# 20220                                        dvodimenzionalan,ravan
# 20329                                                        rotgut
# 20448                                             kijevska piletina
# 20860                     sendvić sa slaninom, salatom i paradajzom
# 22539                                                luminiscencija
# 22562                                       bledilo,bledoća,bledost
# 24591                                      ?disrespect,?discourtesy
# 24593       ?defamation,?calumny,?obloquy,?traducement,?hatchet job
# 24998                                                ?necessitarian
# 25137                                                   ?low status
#
#                                                                                                                                                                                                      Definicija
# 200                                                                                                                                         Teška ili neobična majstorija, obično urađena da se privuče pažnja.
# 727                                                                                                                                                   Slučaj koji se ne saglašava sa pravilom ili uopštavanjem.
# 2094                                                                                                                                                        not standard; not accepted as a model of excellence
# 2153                                                                                                                                                                                      Deliti nečije patnje.
# 2171                                                                                                                                                     Zaklanjati od opasnosti, povrede, uništenja ili štete.
# 2515                                                                                                                                                  Stanje čiste osobe; bez prljavštine ili drugih nečistoća.
# 2729                                                                                                                                                       Deljenje osećanja drugih (posebno osećanja žalosti).
# 2876                                                           Moguća teorija o prirodnom svetu; koncept koji još nije dokazan, ali koji bi, ako bi se pokazao tačnim objasnio određene činjenice ili fenomene.
# 3246                                                                                                                                   Lična verovanja i stavovi koji se ne zasnivaju na dokazu ili izvesnosti.
# 3312                                                                                                                           Akcija kojom se suprotsavljate nečemu što ne odobravate ili s čim se ne slažete.
# 4000                                                                                                                                       Period koji ima svoje karakteristike ili je označen nekim događajem.
# 4797                                                                                                                                                            Koji nije na određenom mestu fizički ili duhom.
# 5263                                                                                                                                                                            Koji nema ili ne uključuje pol.
# 5307                                                                                                                                                 Neko ko nije svešteno lice ni pripadnik uvažene profesije.
# 5359                                                                                                                                 Kvalitet onoga što je novo i originalno (nije izvedeno iz nečeg poznatog).
# 5692                                                                                Devizna štednja građana koja je zamrznuta faktičkim bakrotstvom banaka raspadom Jugoslavije, i koja se postepeno servisira.
# 6179                                                                                                                    (finansije) profit koji se ne isplaćuje kao dividende, nego se dodaju osnovi kompanije.
# 6252                                                                                                                                                              Koji nema boju ili ne može da proizvede boju.
# 6443                                                                                                                                                                Nematerijalna dobra koja se mogu prodavati.
# 6690                                                                                                                                                       Osobina onoga koji ostaje miran i naizgled ne brine.
# 7490                                                                                                                                       Neki od više jestivih puževa iz roda Helix; obično su velika napast.
# 7955                                                    Koristi se za fizičku hladnoću; koji ima nisku ili neadekvatnu temperaturu ili ima osećaj hladnoće ili koji je ohlađen (uz pomoć leda ili u frižideru).
# 7957                                                                                                                                                   Koji obezbeđuje ili oseća fizičku udbnost ili opuštanje.
# 7994                                                                                                                                                      Koji nema neke izrazite kvalitete ili karakteristike.
# 7996                                                                                                                                                Koji nije uključen ili povezan sa komercijalnom delatnošću.
# 8002                                                                                                                                                    Koji uzima različite oblike; ne pridržava se standarda.
# 8711                                                                                                                                                               Profesor nižeg ranga od vanrednog profesora.
# 9134                                                                                                                       Slikar koji svet prestavlja realsitično, a ne u idealizovanom ili romantičnom stilu.
# 9392                                                                                                                                             Tvrdi kupus sa grbim uvijenim lišćem koje ne obrazuje glavice.
# 9662                                                                                                                                      Parazitske gljive iz porodice stapčara; žive pretežno na višem bilju.
# 10036                                                                                                                         Vino koje ne sadrži više od 14 procenata alkohola i koje se obično služi uz jelo.
# 10876                                                                                                                      hromozom koji nije sparen ili ujedinjen sa svojim homologim hromozomom tokom sinapse
# 10948                                                                                                               fagocit koje ne cirkuliše u krvi već je fiksiran u jetri ili slezini ili koštanoj srži itd.
# 10986                                                                Akutna zarazna bolest koju izaziva bakterija Corynebacterium diphtheriae; karakteriše je formiranje membrane u grlu koja sprečava disanje.
# 11044                                                                                                                                                                     bakterija koja izaziva mišju groznicu
# 11050                                                            tipski rod Bacteroidaceae; rod gramnegativnih štapičastih bakterija koje ne proizvode endospore ni pigment i žive u crevima čoveka i životinja
# 11088                                                                                                                                        bakterija koja izaziva pneumoniju (upalu pluća) kod miševa i ljudi
# 11233                                                                                                                                             reovirus koji izaziva enteritis kod novorođenčadi i male dece
# 11267                                                                                                           organizam (naročito bakterija) kojoj nije potreban vazduh ili svež (slobodan) kiseonik za život
# 11281                                                                                                                                         tipski rod porodice Chlamydiaceae:paraziti koji izazivaju bolesti
# 11387                                                                                                                           enterovirus koji izaziva bolest koja je slična poliomijelitisu ali bez paralize
# 11456                                                                                                                                                                                             koji nema rep
# 11499                                                                                                                   Akutno virusno oboljenje koga karakteriše upala nervnih ćelija mozga i kičmene moždine.
# 11502                                                                                                                                                 u prirodnom obliku, koji nije pripiromljen ili kultivisan
# 11603                                                                                                                                                                                       koji se teško žvaće
# 11923                                                                                                                                         gramatički odnos između dva konstituenta istog gramatičkog oblika
# 11969                                                                                                                                             koji ne ograničava referenciju modifikovane reči ili sintagme
# 12975                                                                                                                                                   koji nije ograničen na određenu religijsku denominaciju
# 12976                                                                                                                      koji nije vezan za unapređenje (ili nije posvećen unapređenju) određene denominacije
# 13076                                                                                                                                                       koji nije dobio punomoć od odgovarajućeg autoriteta
# 13123                                                                                                                               Ruski pisac, pisao o ljudskoj patnji i anaizirao je psihološki (1821-1881).
# 13206                                                                                                                                                                            akutna upala mastoidnih ćelija
# 13591                                                                                                                                                              nerimovan stih bez čvrstog metričkog obrasca
# 15063                                                                                                                                     pecivo sa kvascem, može da sadrži suvo grožđe, orahe ili druge začine
# 16376                                                                                           bitka kojom su okončani Ratovi dveju ruža (1485); Ričard III je ubijen a Henri Tjudor je krunisan kao Henri VII
# 16548                                                                                                                                                                             wish ill or allow unwillingly
# 16599                                                                                                                                         izraziti saučestvovanje u nečijem bolu (obično kada je neko umro)
# 16723  akutna zapaljenska bolest koju karakteriše osip sa oticanjem zglobova i groznicom; izaziva je baktrerija koju prenosi ujed krpeljalling and fever; caused by bacteria carried by the bite of a deer tick
# 16832                                                                                              delimična sterilizacija hrane kojom se toplotom uklanjajau mikroorganizmi bez veće promene hemijskog sastava
# 17430                                                                                                                                                                                koji lako žali i sažaljeva
# 17506                                                                                                                                                                                            veoma radostan
# 17922                 ttoksični antimetabolit koji ograničava reprodukciju ćelija tako što inhibira metabolizma folne kiseline; koristi se za lečenje određenih vrsta kancera, psorijaze i reumatskog artritisa
# 18051                                                                           zarazna bolest uzrokovana Epštajn-Barovim virusom; simptomi: povišena telesna temperatura, uvećani limfni čvorovi i upala grla.
# 18058                                                                                                                                                          o braku između osoba nejednakog društvenog ranga
# 19116                                                                                                                                                       koji ne čini suštinski deo nečega ili dolazi spolja
# 19120                                                                                                                                                                                 garantovano neće otkazati
# 19189                                                                                                                                                              kome nije ograničeno korišćenje ili funkcije
# 19316                                                                                                                                                                                  kome nije dodavano olovo
# 19714                                                                                                                                                           koji ne uključuje procenu parametara statistike
# 19741                                                                                                                                                                                koji nije povezan na mrežu
# 19798                                                                                                                                            koji traje bez uočljivih promena u statusu, uslovima ili mestu
# 19855                                                                                                                                                   koji se čuva i brani pod opasnosti, povrede ili gubitka
# 19861                                                                                                                                                      pritisnuti prema nečemu tako da ne može da se pomera
# 19867                                                                                                                                                       koji ne može da se menja, pomera ili vrati na staro
# 19963                                                                                                                                       drugi po rangu, značaju ili vrednosti; nije direktan ili neposredan
# 19992                                                                                                                                                                                              veoma hladan
# 19994                                                                                                                                        koga karakteriše ili koji izaziva ili koje je rezultat asocijacija
# 20220                                                                                                                                  koji nema očekivanu dubinu; koji nije projektovan da da impresiju dubine
# 20329                                                                                                                                                                          alkoholno piće lošijeg kvaliteta
# 20448                                                                                            izlupane pileće šnicle obmotane oko putera (koji je prethodno začinjen biljem) onda uvaljane u prezle i pržene
# 20860                                                                                                                                                sendvič sa parčićima slanine, paradajzom i zelenom salatom
# 22539                                                                                                         svetlost do koje dolazi bez grejanja, pod uticajem raznih uzroka; dešava se an niskoj temperaturi
# 22562                                                                                                                                 neprirodni nedostatak boje kože, usled bolesti ili emocionalnog uzbuđenja
# 24591                                                                                                                                                                         ?an expression of lack of respect
# 24593                                                                                                                                                                                       ?a malicious attack
# 24998                                                                                                                                                   ?someone who does not believe the doctrine of free will
# 25137                                                                                                                                                                            ?a position of inferior status

# %%
missing_ids_NEG.shape[0]
# Out:
# 87

# %%
pos_df.shape[0]
# Out:
# 121

# %%
neg_df.shape[0]
# Out:
# 192

# %%
negKandidat.shape[0]
# Out:
# 279

# %%
posKandidat.shape[0]
# Out:
# 160

# %%
len(Synset_Sentiment_set_4.getDef()["POS"])
# Out:
# 36

# %%
len(Synset_Sentiment_set_4.getDef()["NEG"])
# Out:
# 44

# %%
import pprint
