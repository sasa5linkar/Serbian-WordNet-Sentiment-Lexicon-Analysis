# %% [markdown]
# # Analiza Sentiment leksikona -SVM + NB

# %%
import pandas as pd

# %%
RES_DIR = "..\\resources\\"
MOD_DIR = "..\\ml_models\\"

# %% [markdown]
# Odve se učitava leksikon. Svi leksikoni su snimljeni us dva falja. Falj sa _a ima i vrste reči radi analize.

# %%
sent_an = pd.read_csv(RES_DIR + "srbsentiwordnet_a1.cvs",  index_col=0)

# %%
sent_an["OBJ"] = 1-( sent_an["NEG"]+sent_an["POS"])

# %%
sent_an
# Out:
#                      ID    POS    NEG  \
# 0      ENG30-03574555-n  0.000  0.000
# 1      ENG30-07810907-n  0.000  0.000
# 2      ENG30-00721431-n  0.000  0.500
# 3      ENG30-00473799-v  0.000  0.250
# 4      ENG30-00903385-v  0.000  0.250
# ...                 ...    ...    ...
# 25315  ENG30-15266265-n  0.000  0.250
# 25316  ENG30-15266685-n  0.125  0.000
# 25317  ENG30-15266911-n  0.000  0.125
# 25318  ENG30-15276642-n  0.000  0.000
# 25319  ENG30-15291498-n  0.000  0.125
#
#                                                 Lemme  \
# 0                                            ustanova
# 1                                               začin
# 2                                               mesto
# 3                obnoviti,doterati,uglancati,uljuditi
# 4                                           oprostiti
# ...                                               ...
# 25315                                          mandat
# 25316                                         sredina
# 25317  gotovo,konac,kraj,prestanak,svršetak,završetak
# 25318                            b/s,bitova u sekundi
# 25319                                          mandat
#
#                                               Definicija Vrsta    OBJ
# 0      zgrada u kojoj se nalazi organizaciona jedinic...     n  1.000
# 1         pripremljeni dodatak jelu za poboljšanje ukusa     n  1.000
# 2                      u nečijim prilikama, mogućnostima     n  0.500
# 3      Ostalo je još samo da se doteraju neke finese ...     v  0.750
# 4      Zapad mu je oprostio što se nekada računao u S...     v  0.750
# ...                                                  ...   ...    ...
# 25315                                 mandat predsednika     n  0.750
# 25316    vreme između početka i kraja vremenskog perioda     n  0.875
# 25317             tačka u vremenu kada se nešto završava     n  0.875
# 25318  (računarstvo) brzina prenosa podataka (npr. ko...     n  1.000
# 25319      mandast tokom kojeg se drži određena pozicija     n  0.875
#
# [25320 rows x 7 columns]

# %% [markdown]
# ## Statistike

# %% [markdown]
# Raspored reči prema pozitivnom polaritetu

# %%
sent_an["POS"].value_counts()
# Out:
# 0.000    20259
# 0.125     2471
# 0.250     1694
# 0.375      581
# 0.500      213
# 0.625       61
# 0.750       23
# 0.875       15
# 1.000        3
# Name: POS, dtype: int64

# %%
sent_an[sent_an["POS"]>.9]["Lemme"]
# Out:
# 17664    fantastičan,veličanstven,izvanredan,sjajan,izv...
# 22455                       nekomunikativan,nerazgovorljiv
# 25269                                               humati
# Name: Lemme, dtype: object

# %% [markdown]
# Raspored reči prema negativnom polaritetu

# %%
sent_an["NEG"].value_counts()
# Out:
# 0.000    9378
# 0.125    7556
# 0.250    6736
# 0.375     960
# 0.500     439
# 0.625      97
# 0.750      59
# 0.875      50
# 1.000      45
# Name: NEG, dtype: int64

# %%
sent_an[sent_an["NEG"]>.9]["Lemme"]
# Out:
# 540                                        udarac,udar,šok
# 903                                      tugovati,žalovati
# 933                                               odsustvo
# 2041                                          pogoršati se
# 2043              odbaciti,odstraniti,zanemariti,rešiti se
# 2727                                          žaljenje,žal
# 3199                                               bankrot
# 3364                                        povreda,ozleda
# 4000                                              doba,era
# 4159                                       loše postupanje
# 5357                                           nepopularan
# 6312                                 odreći se,razvesti se
# 6661                                          neprijaznost
# 6748                             trpeti,tolerisati,podneti
# 6832                                  uništiti,upropastiti
# 7735                                         nositi crninu
# 13742                                             elegičar
# 15955                                neraspoložen,nevoljan
# 16555    razgnevljen,razgoropađen,pobesneo,razbesneo,po...
# 16568                                            ozlojeđen
# 17499                                            gaditi se
# 17644                                            nenapadan
# 17679                                             strepeti
# 17699                                              okrutan
# 17710                                 rđav,svirep,neopisiv
# 17712                                            strahotan
# 17718                                   zlostavljan,kinjen
# 17762                                           uplakanost
# 17769                                             snuždeno
# 17771                                                tužno
# 17800                              napuštenost,usamljenost
# 17809                                     smrknut,natmuren
# 17814                                              žaloban
# 19086                                    hardverska greška
# 19087                                      greška na disku
# 19899                                      izgoreo,sagoreo
# 22474                                             dostupan
# 22769    gadan,išaran,neprijatan,odbojan,odvratan,otuža...
# 22949        nametati,nametnuti,naneti,naneti bol,nanositi
# 23001                                     povlačiti,povući
# 23438                              diskreditovan,oklevetan
# 23439                       neugledan,ozloglašen,zloglasan
# 24840                                               nizina
# 25191    ljaga,loš glas,nepopularnost,notornost,ozlogla...
# 25200           loš glas,loša reputacija,nečasnost,sramota
# Name: Lemme, dtype: object

# %%
(sent_an["NEG"]>.9).sum()
# Out:
# 45

# %%
sent_an[sent_an["POS"]>.9]["Lemme"]
# Out:
# 17664    fantastičan,veličanstven,izvanredan,sjajan,izv...
# 22455                       nekomunikativan,nerazgovorljiv
# 25269                                               humati
# Name: Lemme, dtype: object

# %%
(sent_an["POS"]>.9).sum()
# Out:
# 3

# %% [markdown]
# Raspored reči prema objektivnosti

# %%
sent_an["OBJ"].value_counts()
# Out:
# 0.750    7390
# 1.000    7236
# 0.875    6648
# 0.625    2373
# 0.500    1106
# 0.375     314
# 0.250     123
# 0.125      80
# 0.000      50
# Name: OBJ, dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Histogrami

# %% [markdown]
# ### Celog leksikona

# %%
sent_an.hist(bins=8)
# Out:
# array([[<AxesSubplot: title={'center': 'POS'}>,
#         <AxesSubplot: title={'center': 'NEG'}>],
#        [<AxesSubplot: title={'center': 'OBJ'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
sent_an[sent_an["POS"]>.1]["POS"].hist(bins=8)
# Out:
# <AxesSubplot: >

# %%
sent_an[sent_an["POS"]>.2]["POS"].hist(bins=8)
# Out:
# <AxesSubplot: >

# %%
sent_an[sent_an["NEG"]>.1]["NEG"].hist(bins=8)
# Out:
# <AxesSubplot: >

# %%
sent_an[sent_an["NEG"]>.2]["NEG"].hist(bins=8)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Po Vrsti
# a - pridev <br>
# v - glagol <br>
# n - imenica <br>

# %%
sent_an["Vrsta"].value_counts(sort=True)
# Out:
# n    20080
# v     2896
# a     2202
# b      142
# Name: Vrsta, dtype: int64

# %%
sent_an["Vrsta"].value_counts(sort=True).plot(kind ="pie")
# Out:
# <AxesSubplot: ylabel='Vrsta'>

# %%
sent_an.hist(bins=8, by="Vrsta", legend =True, column= ["POS", "NEG"] )
# Out:
# array([[<AxesSubplot: title={'center': 'a'}>,
#         <AxesSubplot: title={'center': 'b'}>],
#        [<AxesSubplot: title={'center': 'n'}>,
#         <AxesSubplot: title={'center': 'v'}>]], dtype=object)

# %%
sent_an[sent_an["POS"]>.1].hist(bins=8, by="Vrsta", column="POS")
# Out:
# array([[<AxesSubplot: title={'center': 'a'}>,
#         <AxesSubplot: title={'center': 'b'}>],
#        [<AxesSubplot: title={'center': 'n'}>,
#         <AxesSubplot: title={'center': 'v'}>]], dtype=object)

# %%
sent_an[sent_an["POS"]>.2].hist(bins=8, by="Vrsta", column="POS")
# Out:
# array([[<AxesSubplot: title={'center': 'a'}>,
#         <AxesSubplot: title={'center': 'b'}>],
#        [<AxesSubplot: title={'center': 'n'}>,
#         <AxesSubplot: title={'center': 'v'}>]], dtype=object)

# %%
sent_an[sent_an["NEG"]>.1].hist(bins=8, by="Vrsta", column="NEG")
# Out:
# array([[<AxesSubplot: title={'center': 'a'}>,
#         <AxesSubplot: title={'center': 'b'}>],
#        [<AxesSubplot: title={'center': 'n'}>,
#         <AxesSubplot: title={'center': 'v'}>]], dtype=object)

# %%
sent_an[sent_an["NEG"]>.2].hist(bins=8, by="Vrsta", column="NEG")
# Out:
# array([[<AxesSubplot: title={'center': 'a'}>,
#         <AxesSubplot: title={'center': 'b'}>],
#        [<AxesSubplot: title={'center': 'n'}>,
#         <AxesSubplot: title={'center': 'v'}>]], dtype=object)

# %% [markdown]
# Ovde se prikazuje raspored vresnosti u odnsu na oba polariteta, ali bez vrednosti (0,0) zbog preglednosti

# %%
import numpy as np
import matplotlib.pyplot as plt

sent_bez0 = sent_an[np.logical_xor(((sent_an["POS"] ==0) & (sent_an["NEG"] == 0)), 1)]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
x, y = sent_bez0["POS"], sent_bez0["NEG"]
hist, xedges, yedges = np.histogram2d(x, y, bins=64, range=[[0, 1], [0, 1]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] , yedges[:-1] , indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 64 bars.
dx = dy = 0.125 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

plt.show()

# %%
((sent_an["POS"] ==0) & (sent_an["NEG"] == 0)).value_counts(sort=True).plot(kind ="pie")
# Out:
# <AxesSubplot: >

# %%
sent_an["NEG"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot: >

# %%
sent_an["POS"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot: >

# %%
a = sent_an[["POS","NEG"]].value_counts(sort=True)

# %%
a.plot(kind ="pie")
# Out:
# <AxesSubplot: >

# %%
sent_an["Vrsta"].value_counts()
# Out:
# n    20080
# v     2896
# a     2202
# b      142
# Name: Vrsta, dtype: int64

# %%
sent_an[sent_an["Vrsta"] == 'n']["NEG"].value_counts().plot(kind = "bar", title = "imenice-negativno")
# Out:
# <AxesSubplot: title={'center': 'imenice-negativno'}>

# %%
sent_an[sent_an["Vrsta"] == 'n']["POS"].value_counts().plot(kind = "bar", title = "imenica-positivno")
# Out:
# <AxesSubplot: title={'center': 'imenica-positivno'}>

# %%
sent_an[sent_an["Vrsta"] == 'v']["NEG"].value_counts().plot(kind = "bar", title = "glagol-negativno")
# Out:
# <AxesSubplot: title={'center': 'glagol-negativno'}>

# %%
sent_an[sent_an["Vrsta"] == 'v']["POS"].value_counts().plot(kind = "bar", title = "glagol-positivno")
# Out:
# <AxesSubplot: title={'center': 'glagol-positivno'}>

# %%
sent_an[sent_an["Vrsta"] == 'a']["NEG"].value_counts().plot(kind = "bar", title = "pridev-negativno")
# Out:
# <AxesSubplot: title={'center': 'pridev-negativno'}>

# %%
sent_an[sent_an["Vrsta"] == 'v']["POS"].value_counts().plot(kind = "bar", title = "pridev-positivno")
# Out:
# <AxesSubplot: title={'center': 'pridev-positivno'}>

# %%
fig = plt.figure()
b =pd.DataFrame(a).reset_index()
ax = plt.axes(projection ='3d')
ax.scatter(b["POS"],b["NEG"],b[0], color ='green')

# %%
a = sent_an[["POS","NEG", "Vrsta"]].value_counts(sort=True)
a
# Out:
# POS    NEG    Vrsta
# 0.000  0.000  n        6149
#        0.125  n        5186
#        0.250  n        4489
#               v         901
#        0.000  a         788
#                        ...
# 0.625  0.250  v           1
#               a           1
# 0.500  0.250  v           1
#        0.375  n           1
# 1.000  0.000  n           1
# Length: 127, dtype: int64

# %%
fig = plt.figure()
c =pd.DataFrame(a).reset_index()
ax = plt.axes(projection ='3d')

b =c [c["Vrsta"]=="n"] 
ax.scatter(b["POS"],b["NEG"],b[0], color ='green')
b =c [c["Vrsta"]=="v"] 
ax.scatter(b["POS"],b["NEG"],b[0], color ='blue')
b =c [c["Vrsta"]=="a"] 
ax.scatter(b["POS"],b["NEG"],b[0], color ='red')

# %%
# srbsentiwordnet2.cvs
# srbsentiwordnet_a2.cvs
