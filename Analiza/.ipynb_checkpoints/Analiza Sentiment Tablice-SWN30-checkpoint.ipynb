# %% [markdown]
# # Analiza Sentiment leksikona -ADA + NB

# %%
import pandas as pd

# %%
RES_DIR = "..\\resources\\"
MOD_DIR = "..\\ml_models\\"

# %% [markdown]
# Odve se učitava leksikon. Svi leksikoni su snimljeni us dva falja. Falj sa _a ima i vrste reči radi analize.

# %%
sent_an = pd.read_csv(RES_DIR + "srbsentiwordnet_a2.csv",  index_col=0)

# %%
sent_an["OBJ"] = 1-( sent_an["NEG"]+sent_an["POS"])

# %%
sent_an
# Out:
#                      ID  POS  NEG  \
# 0      ENG30-03574555-n  0.0  0.0
# 1      ENG30-07810907-n  0.0  0.0
# 2      ENG30-00721431-n  0.0  0.0
# 3      ENG30-00473799-v  0.0  0.0
# 4      ENG30-00903385-v  0.0  0.0
# ...                 ...  ...  ...
# 25315  ENG30-15266265-n  0.0  0.0
# 25316  ENG30-15266685-n  0.0  0.0
# 25317  ENG30-15266911-n  0.0  0.0
# 25318  ENG30-15276642-n  0.0  0.0
# 25319  ENG30-15291498-n  0.0  0.0
#
#                                                 Lemme  \
# 0                                            ustanova
# 1                                               začin
# 2                                               mesto
# 3                obnoviti,doterati,uglancati,uljuditi
# 4                                           oprostiti
# ...                                               ...
# 25315                                          mandat
# 25316                                         sredina
# 25317  gotovo,konac,kraj,prestanak,svršetak,završetak
# 25318                            b/s,bitova u sekundi
# 25319                                          mandat
#
#                                               Definicija Vrsta  OBJ
# 0      zgrada u kojoj se nalazi organizaciona jedinic...     n  1.0
# 1         pripremljeni dodatak jelu za poboljšanje ukusa     n  1.0
# 2                      u nečijim prilikama, mogućnostima     n  1.0
# 3      Ostalo je još samo da se doteraju neke finese ...     v  1.0
# 4      Zapad mu je oprostio što se nekada računao u S...     v  1.0
# ...                                                  ...   ...  ...
# 25315                                 mandat predsednika     n  1.0
# 25316    vreme između početka i kraja vremenskog perioda     n  1.0
# 25317             tačka u vremenu kada se nešto završava     n  1.0
# 25318  (računarstvo) brzina prenosa podataka (npr. ko...     n  1.0
# 25319      mandast tokom kojeg se drži određena pozicija     n  1.0
#
# [25320 rows x 7 columns]

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Statistike

# %% [markdown]
# Raspored reči prema pozitivnom polaritetu

# %%
sent_an["POS"].value_counts()
# Out:
# POS
# 0.000    23656
# 0.125      864
# 0.250      324
# 0.375      197
# 0.500      137
# 0.750       58
# 0.625       44
# 1.000       23
# 0.875       17
# Name: count, dtype: int64

# %%
sent_an[sent_an["POS"]>.9]["Lemme"]
# Out:
# 701                 poštovanje,respekt
# 1355                         diviti se
# 2714         prijaznost,druželjubivost
# 2778                          karakter
# 5238                           važnost
# 5352      veličanstvenost,briljantnost
# 5389                               lep
# 7975                        dobrodušan
# 12070                         ljubazan
# 12961                       iskupljući
# 12970        strahopoštovati,uvažavati
# 17133                       izvanredan
# 17150                          ushićen
# 17446                       uzbuđujući
# 17460                    zaljubljenost
# 17470                   uveseljavajući
# 17472         polet,oduševljenje,slast
# 17475            divljenje,idolizacija
# 17479                          veselje
# 18156    koketiranje,flert,kaćiperstvo
# 21171                  nasmejan,ozaren
# 23193             častan,dobar,pouzdan
# 25214            ispravnost,korektnost
# Name: Lemme, dtype: object

# %% [markdown]
# Raspored reči prema negativnom polaritetu

# %%
sent_an["NEG"].value_counts()
# Out:
# NEG
# 0.000    23354
# 0.125      916
# 0.250      413
# 0.375      198
# 0.500      178
# 0.625       76
# 0.750       71
# 1.000       65
# 0.875       49
# Name: count, dtype: int64

# %%
sent_an[sent_an["NEG"]>.9]["Lemme"]
# Out:
# 37             oplakati,tugovati,jadikovati,ožaliti
# 141                                     nedaća,beda
# 540                                 udarac,udar,šok
# 541                               ubeđenje,uverenje
# 903                               tugovati,žalovati
# 2041                                   pogoršati se
# 2496                                  jad,tugovanje
# 2505                                      nesavršen
# 2695                                greška,pogreška
# 2726                                       nesrećan
# 2727                                   žaljenje,žal
# 2730                           teskoba,uznemirenost
# 3199                                        bankrot
# 3364                                 povreda,ozleda
# 3623                               zapaljenje,upala
# 4779                             teroristički napad
# 4957                                       opasnost
# 4977                                     odvojenost
# 5856                                  užasan,grozan
# 6589                                       odbaciti
# 6661                                   neprijaznost
# 6714                                        nesreća
# 9020                                       neudoban
# 11462                                   atrofiranje
# 13907                                     zapalenje
# 15955                         neraspoložen,nevoljan
# 16549           ogorčen,razdražen,pobesneo,uvredžen
# 16629                                nekooperativan
# 16882                           muka,fizička patnja
# 17353                                dati naslutiti
# 17404                                   nevaljalost
# 17670                               okoreo,bezdušan
# 17696                                      teskoban
# 17710                          rđav,svirep,neopisiv
# 17724                                    neprijatan
# 17725                                      nesrećan
# 17726                                         tužan
# 17727                                    disforičan
# 17729                                  rastužiti se
# 17731                                  melanholičan
# 17733                                          muka
# 17734                                       setnost
# 17738                                       žalobno
# 17741                                    neveselost
# 17746                                   melanholija
# 17751                           skrhan,srceparajući
# 17762                                    uplakanost
# 17764                       bedan,kukavan,oplačljiv
# 17769                                      snuždeno
# 17771                                         tužno
# 17774                           ?ispunjen žaljenjem
# 17783                                    beznadežan
# 17800                       napuštenost,usamljenost
# 17812                                     paćenički
# 17813                                       mizeran
# 17814                                       žaloban
# 17817                                     ožalošćen
# 19176                                         mutan
# 20649                                     ranjivost
# 22717                                 lažno,prljavo
# 22921                                     nestašluk
# 23439                neugledan,ozloglašen,zloglasan
# 24304           altruizam,nesebičnost,velikodušnost
# 24305                                     sebičnost
# 25200    loš glas,loša reputacija,nečasnost,sramota
# Name: Lemme, dtype: object

# %% [markdown]
# Raspored reči prema objektivnosti

# %%
sent_an["OBJ"].value_counts()
# Out:
# OBJ
# 1.000    22107
# 0.875     1221
# 0.750      731
# 0.625      489
# 0.500      334
# 0.250      136
# 0.375      134
# 0.000       91
# 0.125       77
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Histogrami

# %% [markdown]
# ### Celog leksikona

# %%
sent_an.hist(bins=8)
# Out:
# array([[<Axes: title={'center': 'POS'}>, <Axes: title={'center': 'NEG'}>],
#        [<Axes: title={'center': 'OBJ'}>, <Axes: >]], dtype=object)

# %%
sent_an[sent_an["POS"]>.1]["POS"].hist(bins=8)
# Out:
# <Axes: >

# %%
sent_an[sent_an["POS"]>.2]["POS"].hist(bins=8)
# Out:
# <Axes: >

# %%
sent_an[sent_an["NEG"]>.1]["NEG"].hist(bins=8)
# Out:
# <Axes: >

# %%
sent_an[sent_an["NEG"]>.2]["NEG"].hist(bins=8)
# Out:
# <Axes: >

# %% [markdown]
# ### Po Vrsti
# a - pridev <br>
# v - glagol <br>
# n - imenica <br>

# %%
sent_an["Vrsta"].value_counts(sort=True)
# Out:
# Vrsta
# n    20080
# v     2896
# a     2202
# b      142
# Name: count, dtype: int64

# %%
sent_an["Vrsta"].value_counts(sort=True).plot(kind ="pie")
# Out:
# <Axes: ylabel='count'>

# %%
sent_an.hist(bins=8, by="Vrsta", legend =True, column= ["POS", "NEG"] )
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["POS"]>.1].hist(bins=8, by="Vrsta", column="POS")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["POS"]>.2].hist(bins=8, by="Vrsta", column="POS")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["NEG"]>.1].hist(bins=8, by="Vrsta", column="NEG")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["NEG"]>.2].hist(bins=8, by="Vrsta", column="NEG")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %% [markdown]
# Ovde se prikazuje raspored vresnosti u odnsu na oba polariteta, ali bez vrednosti (0,0) zbog preglednosti

# %%
import numpy as np
import matplotlib.pyplot as plt

sent_bez0 = sent_an[np.logical_xor(((sent_an["POS"] ==0) & (sent_an["NEG"] == 0)), 1)]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
x, y = sent_bez0["POS"], sent_bez0["NEG"]
hist, xedges, yedges = np.histogram2d(x, y, bins=64, range=[[0, 1], [0, 1]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] , yedges[:-1] , indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 64 bars.
dx = dy = 0.125 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

plt.show()

# %%
((sent_an["POS"] ==0) & (sent_an["NEG"] == 0)).value_counts(sort=True).plot(kind ="pie")
# Out:
# <Axes: ylabel='count'>

# %%
sent_an["NEG"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='NEG'>

# %%
sent_an["POS"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='POS'>

# %%
a = sent_an[["POS","NEG"]].value_counts(sort=True)

# %%
a.plot(kind ="pie")
# Out:
# <Axes: ylabel='count'>

# %%
sent_an["Vrsta"].value_counts()
# Out:
# Vrsta
# n    20080
# v     2896
# a     2202
# b      142
# Name: count, dtype: int64

# %%
sent_an[sent_an["Vrsta"] == 'n']["NEG"].value_counts().plot(kind = "bar", title = "imenice-negativno")
# Out:
# <Axes: title={'center': 'imenice-negativno'}, xlabel='NEG'>

# %%
sent_an[sent_an["Vrsta"] == 'n']["POS"].value_counts().plot(kind = "bar", title = "imenica-positivno")
# Out:
# <Axes: title={'center': 'imenica-positivno'}, xlabel='POS'>

# %%
sent_an[sent_an["Vrsta"] == 'v']["NEG"].value_counts().plot(kind = "bar", title = "glagol-negativno")
# Out:
# <Axes: title={'center': 'glagol-negativno'}, xlabel='NEG'>

# %%
sent_an[sent_an["Vrsta"] == 'v']["POS"].value_counts().plot(kind = "bar", title = "glagol-positivno")
# Out:
# <Axes: title={'center': 'glagol-positivno'}, xlabel='POS'>

# %%
sent_an[sent_an["Vrsta"] == 'a']["NEG"].value_counts().plot(kind = "bar", title = "pridev-negativno")
# Out:
# <Axes: title={'center': 'pridev-negativno'}, xlabel='NEG'>

# %%
sent_an[sent_an["Vrsta"] == 'v']["POS"].value_counts().plot(kind = "bar", title = "pridev-positivno")
# Out:
# <Axes: title={'center': 'pridev-positivno'}, xlabel='POS'>

# %%
fig = plt.figure()
b =pd.DataFrame(a).reset_index()
ax = plt.axes(projection ='3d')
ax.scatter(b["POS"],b["NEG"],b[0], color ='green')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sasa5\anaconda3\envs\hugFace\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\sasa5\anaconda3\envs\hugFace\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\sasa5\anaconda3\envs\hugFace\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 4
#       2 b =pd.DataFrame(a).reset_index()
#       3 ax = plt.axes(projection ='3d')
# ----> 4 ax.scatter(b["POS"],b["NEG"],b[0], color ='green')
#
# File c:\Users\sasa5\anaconda3\envs\hugFace\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\sasa5\anaconda3\envs\hugFace\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 0

# %%
a = sent_an[["POS","NEG", "Vrsta"]].value_counts(sort=True)
a

# %%
fig = plt.figure()
c =pd.DataFrame(a).reset_index()
ax = plt.axes(projection ='3d')

b =c [c["Vrsta"]=="n"] 
ax.scatter(b["POS"],b["NEG"],b[0], color ='green')
b =c [c["Vrsta"]=="v"] 
ax.scatter(b["POS"],b["NEG"],b[0], color ='blue')
b =c [c["Vrsta"]=="a"] 
ax.scatter(b["POS"],b["NEG"],b[0], color ='red')

# %%
# srbsentiwordnet2.csv
# srbsentiwordnet_a2.csv
